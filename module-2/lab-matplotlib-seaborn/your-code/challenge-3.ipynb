# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(['int64','float64']).head(5)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here- categorical variable
titanic.select_dtypes('object').head(5)
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic') 
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
plt.hist(titanic.Age)
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here

plt.subplot(2,2,1), plt.hist(titanic.Age,bins=10)
plt.subplot(2,2,2), plt.hist(titanic.Age,bins=20)
plt.subplot(2,2,3), plt.hist(titanic.Age,bins=50)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x120b259b0>,
#  (array([ 22.,  19.,  10.,  11.,  10.,  13.,   8.,   8.,  23.,  26.,  20.,
#           75.,  29.,  93., 109.,  43.,  72.,  68., 111.,  53.,  71.,  47.,
#           35.,  24.,  43.,  26.,  29.,  15.,  35.,  31.,  15.,  26.,   7.,
#           14.,  13.,   5.,   9.,   8.,  11.,   9.,   3.,   2.,   0.,   2.,
#            3.,   0.,   1.,   1.,   0.,   1.]),
#   array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#          11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#          22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#          33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#          44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#          56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#          67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#          78.4034, 80.    ]),
#   <a list of 50 Patch objects>))

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

#Higher the number of bins, more information is showed because bins are the number or intervals you want to dive all 
#your data into.  In oposite, the values are gathered and thus not all information can be visualized.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.set()

sns.distplot(titanic.Age)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1rst way (using Matplotlib)

titanic.groupby('Gender').size().plot(kind='bar')

# %%
# your code here- 2nd way (using Seaborn)

titanic.Gender.value_counts().plot(kind='bar')
plt.show()

# %%
# your code here- 3th way (using just pandas)

titanic.groupby('Gender').size().plot(kind='bar')

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
sns.countplot(titanic['Pclass'])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
plt.boxplot(titanic.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12cee0358>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12e7b7240>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12326b668>],
#  'medians': [<matplotlib.lines.Line2D at 0x12d8c8470>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12d8c8240>],
#  'means': []}

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
#The median is arround 30 years old.  The majority is between 22 and 37.  It seems there were some newborn child.
#Beyond the 1.5 interquartile (59 years old) there are a lot of outliers centered between 60 and 67 years.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
num = len(titanic.Age) #adjusting the number of bins/divisions
num = int(num**(.5))

plt.hist(titanic.Age,bins=num)
# Out:
# (array([ 34.,  17.,  11.,  23.,   8.,  13.,  25.,  39., 103.,  93., 112.,
#          78., 103., 137.,  98.,  47.,  44.,  58.,  45.,  25.,  35.,  37.,
#          35.,  11.,  19.,   9.,  16.,  12.,   9.,   4.,   1.,   5.,   0.,
#           1.,   1.,   1.]),
#  array([ 0.17  ,  2.3875,  4.605 ,  6.8225,  9.04  , 11.2575, 13.475 ,
#         15.6925, 17.91  , 20.1275, 22.345 , 24.5625, 26.78  , 28.9975,
#         31.215 , 33.4325, 35.65  , 37.8675, 40.085 , 42.3025, 44.52  ,
#         46.7375, 48.955 , 51.1725, 53.39  , 55.6075, 57.825 , 60.0425,
#         62.26  , 64.4775, 66.695 , 68.9125, 71.13  , 73.3475, 75.565 ,
#         77.7825, 80.    ]),
#  <a list of 36 Patch objects>)

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here

#With the frequency is more easy to find the more common value for the age.  In this example, 30 years old

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way (using Seaborn)

sns.pairplot(titanic, vars=["Fare", "Age"])
plt.show()

# %%
# your code-2nd way

plt.scatter(titanic.Fare, titanic.Age)

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here

uniform_data = titanic.select_dtypes(['int64','float64'])

sns.heatmap(uniform_data, cmap='viridis')

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here

sns.boxplot(x='Pclass', y='Age', data=titanic)

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here

sns.boxplot(x='Gender', y='Age', data=titanic)
