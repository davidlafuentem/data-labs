# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# MAXIMUM DAY FOR DELIVER IS 8 July 2019
# import libraries here
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
states = pd.read_csv('./Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
states.head()
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
states.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
states.loc[states.State == "New York"]['State']
# Out:
# 0    New York
# 1    New York
# 2    New York
# Name: State, dtype: object

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
states.loc[states.State == "New York", 'Temperature'].median()
# Out:
# 9.444444444444443

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
states.loc[states.Temperature < 15, ['City', 'State']]
# Out:
#          City        State
# 1      Albany     New York
# 2     Buffalo     New York
# 4  Bridgeport  Connecticut

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
states.loc[states.Temperature < 15, 'City']
# Out:
# 1        Albany
# 2       Buffalo
# 4    Bridgeport
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
states.loc[(states.Temperature > 15) & (states.Temperature < 20), 'City']
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
print("Temperatures MEAN:\n")
print(states.groupby(['State'])['Temperature'].mean())

print("Temperatures STANDARD DEVIATION:\n")
print(states.groupby(['State'])['Temperature'].mean())
# Out:
# Temperatures MEAN:
#
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741
# Name: Temperature, dtype: float64
# Temperatures STANDARD DEVIATION:
#
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741
# Name: Temperature, dtype: float64

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('./Employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
employee.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b05cdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b0b5588>]],
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
print(employee.Salary.mean())
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
print(employee.Salary.max())
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
print(employee.Salary.min())
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee.Name.loc[employee.Salary == employee.Salary.min()].head()
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[(employee.Salary == employee.Salary.min()) & (employee.Name == 'David')].head()
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee.Name[(employee.Salary == employee.Salary.min()) & (employee.Name == 'David')].head()
# Out:
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee.Title == 'associate'].head(10)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.loc[:2].head()
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee.Title=='associate') & (employee.Salary > 50)].head(10)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
#employee.groupby(['Years'])['Salary'].mean()
employee.groupby(by = 'Years').agg({'Salary':['mean']})
# Out:
#           Salary
#             mean
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby(by = 'Title').agg({'Salary':['mean']})
# Out:
#               Salary
#                 mean
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot()

"""
REPEAT WITH THE NEW PLOT!!!!!

I notice that the minimum outlayer is quite near the first quartile, so the 25% of the poblation is near the 
minimum salary.  The mean is arroud a salary of 48.  The maximum outlayer is far from third quartile.  
It seems there is no scew
"""
# Out:
# '\nREPEAT WITH THE NEW PLOT!!!!!\n\nI notice that the minimum outlayer is quite near the first quartile, so the 25% of the poblation is near the \nminimum salary.  The mean is arroud a salary of 48.  The maximum outlayer is far from third quartile.  \nIt seems there is no scew\n'

# %%
# print first quartile here
employee.quantile([0.25])
# Out:
#       Years  Salary
# 0.25    2.0    35.0

# %%
# print third quartile here
employee.quantile([0.75])
# Out:
#       Years  Salary
# 0.75    7.0    60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby(by = 'Gender').agg({'Salary':['mean']})
# Out:
#        Salary
#          mean
# Gender
# F        47.5
# M        50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee.groupby(by = 'Department').agg({'Salary':['min','mean','max'],'Years':['min','mean','max'],})
# Out:
#            Salary            Years
#               min   mean max   min      mean max
# Department
# HR             30  45.00  70     2  4.666667   8
# IT             30  48.75  70     1  4.500000   8
# Sales          55  55.00  55     2  2.500000   3

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
employee.groupby('Department').agg({'Salary': lambda x: x.max() - x.min()})
# Out:
#             Salary
# Department
# HR              40
# IT              40
# Sales            0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('./Orders.csv')

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00
# 3       3.39       17850  United Kingdom         20.34
# 4       3.39       17850  United Kingdom         20.34

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.info()
print(orders.describe)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
# Unnamed: 0      397924 non-null int64
# InvoiceNo       397924 non-null int64
# StockCode       397924 non-null object
# year            397924 non-null int64
# month           397924 non-null int64
# day             397924 non-null int64
# hour            397924 non-null int64
# Description     397924 non-null object
# Quantity        397924 non-null int64
# InvoiceDate     397924 non-null object
# UnitPrice       397924 non-null float64
# CustomerID      397924 non-null int64
# Country         397924 non-null object
# amount_spent    397924 non-null float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB
# <bound method NDFrame.describe of         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# 5                5     536365     22752  2010     12    3     8
# 6                6     536365     21730  2010     12    3     8
# 7                7     536366     22633  2010     12    3     8
# 8                8     536366     22632  2010     12    3     8
# 9                9     536367     84879  2010     12    3     8
# 10              10     536367     22745  2010     12    3     8
# 11              11     536367     22748  2010     12    3     8
# 12              12     536367     22749  2010     12    3     8
# 13              13     536367     22310  2010     12    3     8
# 14              14     536367     84969  2010     12    3     8
# 15              15     536367     22623  2010     12    3     8
# 16              16     536367     22622  2010     12    3     8
# 17              17     536367     21754  2010     12    3     8
# 18              18     536367     21755  2010     12    3     8
# 19              19     536367     21777  2010     12    3     8
# 20              20     536367     48187  2010     12    3     8
# 21              21     536368     22960  2010     12    3     8
# 22              22     536368     22913  2010     12    3     8
# 23              23     536368     22912  2010     12    3     8
# 24              24     536368     22914  2010     12    3     8
# 25              25     536369     21756  2010     12    3     8
# 26              26     536370     22728  2010     12    3     8
# 27              27     536370     22727  2010     12    3     8
# 28              28     536370     22726  2010     12    3     8
# 29              29     536370     21724  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397894      541879     581585     22726  2011     12    5    12
# 397895      541880     581585     22727  2011     12    5    12
# 397896      541881     581585     16016  2011     12    5    12
# 397897      541882     581585     21916  2011     12    5    12
# 397898      541883     581585     84692  2011     12    5    12
# 397899      541884     581585     84946  2011     12    5    12
# 397900      541885     581585     21684  2011     12    5    12
# 397901      541886     581585     22398  2011     12    5    12
# 397902      541887     581585     23328  2011     12    5    12
# 397903      541888     581585     23145  2011     12    5    12
# 397904      541889     581585     22466  2011     12    5    12
# 397905      541890     581586     22061  2011     12    5    12
# 397906      541891     581586     23275  2011     12    5    12
# 397907      541892     581586     21217  2011     12    5    12
# 397908      541893     581586     20685  2011     12    5    12
# 397909      541894     581587     22631  2011     12    5    12
# 397910      541895     581587     22556  2011     12    5    12
# 397911      541896     581587     22555  2011     12    5    12
# 397912      541897     581587     22728  2011     12    5    12
# 397913      541898     581587     22727  2011     12    5    12
# 397914      541899     581587     22726  2011     12    5    12
# 397915      541900     581587     22730  2011     12    5    12
# 397916      541901     581587     22367  2011     12    5    12
# 397917      541902     581587     22629  2011     12    5    12
# 397918      541903     581587     23256  2011     12    5    12
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3       knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4            red woolly hottie white heart.         6  2010-12-01 08:26:00
# 5              set 7 babushka nesting boxes         2  2010-12-01 08:26:00
# 6         glass star frosted t-light holder         6  2010-12-01 08:26:00
# 7                    hand warmer union jack         6  2010-12-01 08:28:00
# 8                 hand warmer red polka dot         6  2010-12-01 08:28:00
# 9             assorted colour bird ornament        32  2010-12-01 08:34:00
# 10               poppy's playhouse bedroom          6  2010-12-01 08:34:00
# 11                poppy's playhouse kitchen         6  2010-12-01 08:34:00
# 12        feltcraft princess charlotte doll         8  2010-12-01 08:34:00
# 13                  ivory knitted mug cosy          6  2010-12-01 08:34:00
# 14       box of 6 assorted colour teaspoons         6  2010-12-01 08:34:00
# 15            box of vintage jigsaw blocks          3  2010-12-01 08:34:00
# 16           box of vintage alphabet blocks         2  2010-12-01 08:34:00
# 17                 home building block word         3  2010-12-01 08:34:00
# 18                 love building block word         3  2010-12-01 08:34:00
# 19              recipe box with metal heart         4  2010-12-01 08:34:00
# 20                      doormat new england         4  2010-12-01 08:34:00
# 21                 jam making set with jars         6  2010-12-01 08:34:00
# 22              red coat rack paris fashion         3  2010-12-01 08:34:00
# 23           yellow coat rack paris fashion         3  2010-12-01 08:34:00
# 24             blue coat rack paris fashion         3  2010-12-01 08:34:00
# 25                 bath building block word         3  2010-12-01 08:35:00
# 26                alarm clock bakelike pink        24  2010-12-01 08:45:00
# 27                alarm clock bakelike red         24  2010-12-01 08:45:00
# 28               alarm clock bakelike green        12  2010-12-01 08:45:00
# 29          panda and bunnies sticker sheet        12  2010-12-01 08:45:00
# ...                                     ...       ...                  ...
# 397894           alarm clock bakelike green         8  2011-12-09 12:31:00
# 397895            alarm clock bakelike red          4  2011-12-09 12:31:00
# 397896          large chinese style scissor        10  2011-12-09 12:31:00
# 397897      set 12 retro white chalk sticks        24  2011-12-09 12:31:00
# 397898          box of 24 cocktail parasols        25  2011-12-09 12:31:00
# 397899         antique silver t-light glass        12  2011-12-09 12:31:00
# 397900     small medina stamped metal bowl         12  2011-12-09 12:31:00
# 397901           magnets pack of 4 swallows        12  2011-12-09 12:31:00
# 397902   set 6 school milk bottles in crate         4  2011-12-09 12:31:00
# 397903       zinc t-light holder star large        12  2011-12-09 12:31:00
# 397904       fairy tale cottage night light        12  2011-12-09 12:31:00
# 397905  large cake stand  hanging strawbery         8  2011-12-09 12:49:00
# 397906     set of 3 hanging owls ollie beak        24  2011-12-09 12:49:00
# 397907        red retrospot round cake tins        24  2011-12-09 12:49:00
# 397908                doormat red retrospot        10  2011-12-09 12:49:00
# 397909             circus parade lunch box         12  2011-12-09 12:50:00
# 397910       plasters in tin circus parade         12  2011-12-09 12:50:00
# 397911            plasters in tin strongman        12  2011-12-09 12:50:00
# 397912            alarm clock bakelike pink         4  2011-12-09 12:50:00
# 397913            alarm clock bakelike red          4  2011-12-09 12:50:00
# 397914           alarm clock bakelike green         4  2011-12-09 12:50:00
# 397915           alarm clock bakelike ivory         4  2011-12-09 12:50:00
# 397916      childrens apron spaceboy design         8  2011-12-09 12:50:00
# 397917                  spaceboy lunch box         12  2011-12-09 12:50:00
# 397918          childrens cutlery spaceboy          4  2011-12-09 12:50:00
# 397919          pack of 20 spaceboy napkins        12  2011-12-09 12:50:00
# 397920         children's apron dolly girl          6  2011-12-09 12:50:00
# 397921        childrens cutlery dolly girl          4  2011-12-09 12:50:00
# 397922      childrens cutlery circus parade         4  2011-12-09 12:50:00
# 397923        baking set 9 piece retrospot          3  2011-12-09 12:50:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 0            2.55       17850  United Kingdom         15.30
# 1            3.39       17850  United Kingdom         20.34
# 2            2.75       17850  United Kingdom         22.00
# 3            3.39       17850  United Kingdom         20.34
# 4            3.39       17850  United Kingdom         20.34
# 5            7.65       17850  United Kingdom         15.30
# 6            4.25       17850  United Kingdom         25.50
# 7            1.85       17850  United Kingdom         11.10
# 8            1.85       17850  United Kingdom         11.10
# 9            1.69       13047  United Kingdom         54.08
# 10           2.10       13047  United Kingdom         12.60
# 11           2.10       13047  United Kingdom         12.60
# 12           3.75       13047  United Kingdom         30.00
# 13           1.65       13047  United Kingdom          9.90
# 14           4.25       13047  United Kingdom         25.50
# 15           4.95       13047  United Kingdom         14.85
# 16           9.95       13047  United Kingdom         19.90
# 17           5.95       13047  United Kingdom         17.85
# 18           5.95       13047  United Kingdom         17.85
# 19           7.95       13047  United Kingdom         31.80
# 20           7.95       13047  United Kingdom         31.80
# 21           4.25       13047  United Kingdom         25.50
# 22           4.95       13047  United Kingdom         14.85
# 23           4.95       13047  United Kingdom         14.85
# 24           4.95       13047  United Kingdom         14.85
# 25           5.95       13047  United Kingdom         17.85
# 26           3.75       12583          France         90.00
# 27           3.75       12583          France         90.00
# 28           3.75       12583          France         45.00
# 29           0.85       12583          France         10.20
# ...           ...         ...             ...           ...
# 397894       3.75       15804  United Kingdom         30.00
# 397895       3.75       15804  United Kingdom         15.00
# 397896       0.85       15804  United Kingdom          8.50
# 397897       0.42       15804  United Kingdom         10.08
# 397898       0.42       15804  United Kingdom         10.50
# 397899       1.25       15804  United Kingdom         15.00
# 397900       0.85       15804  United Kingdom         10.20
# 397901       0.39       15804  United Kingdom          4.68
# 397902       3.75       15804  United Kingdom         15.00
# 397903       0.95       15804  United Kingdom         11.40
# 397904       1.95       15804  United Kingdom         23.40
# 397905       2.95       13113  United Kingdom         23.60
# 397906       1.25       13113  United Kingdom         30.00
# 397907       8.95       13113  United Kingdom        214.80
# 397908       7.08       13113  United Kingdom         70.80
# 397909       1.95       12680          France         23.40
# 397910       1.65       12680          France         19.80
# 397911       1.65       12680          France         19.80
# 397912       3.75       12680          France         15.00
# 397913       3.75       12680          France         15.00
# 397914       3.75       12680          France         15.00
# 397915       3.75       12680          France         15.00
# 397916       1.95       12680          France         15.60
# 397917       1.95       12680          France         23.40
# 397918       4.15       12680          France         16.60
# 397919       0.85       12680          France         10.20
# 397920       2.10       12680          France         12.60
# 397921       4.15       12680          France         16.60
# 397922       4.15       12680          France         16.60
# 397923       4.95       12680          France         14.85
#
# [397924 rows x 14 columns]>

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders['amount_spent'].mean()
# Out:
# 22.394748504739596

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders['amount_spent'].min()
# Out:
# 0.0

# %%
# your answer here
orders['amount_spent'].max()
# Out:
# 168469.6

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
orders[orders['Country']=='Spain'].agg(['nunique','count'])
# Out:
#          Unnamed: 0  InvoiceNo  StockCode  year  month   day  hour  \
# nunique        2485         90       1091     2     12     6    11
# count          2485       2485       2485  2485   2485  2485  2485
#
#          Description  Quantity  InvoiceDate  UnitPrice  CustomerID  Country  \
# nunique         1105        35           90         78          30        1
# count           2485      2485         2485       2485        2485     2485
#
#          amount_spent
# nunique           316
# count            2485

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
print(orders['Unnamed: 0'][orders['Country'] == 'Spain'].agg(['value_counts']))
print(orders['Unnamed: 0'][orders['Country'] == 'Spain'].agg(['count']))

print(orders['CustomerID'][orders['Country'] == 'Spain'].agg(['value_counts']))
print(orders['CustomerID'][orders['Country'] == 'Spain'].agg(['count']))
# Out:
#         value_counts
# 221182             1
# 398628             1
# 398638             1
# 212269             1
# 398636             1
# 212267             1
# 398634             1
# 398632             1
# 398630             1
# 398626             1
# 355775             1
# 511502             1
# 535246             1
# 495928             1
# 437978             1
# 208147             1
# 437977             1
# 208145             1
# 212271             1
# 398640             1
# 212273             1
# 212275             1
# 52557              1
# 52555              1
# 440893             1
# 52553              1
# 52551              1
# 52549              1
# 52547              1
# 535226             1
# ...              ...
# 440909             1
# 78930              1
# 350537             1
# 258667             1
# 315732             1
# 258665             1
# 88910              1
# 258661             1
# 258659             1
# 258657             1
# 454192             1
# 277140             1
# 27288              1
# 449909             1
# 535260             1
# 27286              1
# 253786             1
# 27284              1
# 27282              1
# 27280              1
# 27278              1
# 27276              1
# 27274              1
# 404004             1
# 27272              1
# 27270              1
# 482538             1
# 121409             1
# 355756             1
# 221184             1
#
# [2485 rows x 1 columns]
# count    2485
# Name: Unnamed: 0, dtype: int64
#        value_counts
# 12540           478
# 12484           346
# 12539           273
# 17097           211
# 12597           206
# 12502           147
# 12556           121
# 12546            69
# 12462            62
# 12354            58
# 12550            57
# 12541            52
# 12545            50
# 12455            48
# 12421            45
# 12510            33
# 12557            33
# 12596            27
# 12417            23
# 12507            22
# 12448            22
# 12538            21
# 12544            19
# 12454            15
# 12442            12
# 12551            10
# 12547             8
# 12450             8
# 12548             5
# 12445             4
# count    2485
# Name: CustomerID, dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
print(orders['CustomerID'][orders['Quantity'] > 50])
print(orders['CustomerID'][orders['Quantity'] > 50].count())
# Out:
# 46        13748
# 83        15291
# 96        14688
# 102       14688
# 174       16029
# 175       16029
# 176       16029
# 177       16029
# 178       16029
# 179       16029
# 180       16029
# 215       17511
# 217       17511
# 218       17511
# 219       17511
# 222       17511
# 223       17511
# 225       17511
# 231       17511
# 232       17511
# 245       13408
# 246       13408
# 247       13408
# 248       13408
# 376       12791
# 406       14045
# 673       13255
# 718       13694
# 719       13694
# 720       13694
#           ...
# 397113    18102
# 397114    18102
# 397115    18102
# 397116    18102
# 397117    18102
# 397118    18102
# 397119    17949
# 397120    17949
# 397155    13077
# 397330    12433
# 397336    12433
# 397344    12433
# 397351    12433
# 397371    12433
# 397372    12433
# 397380    12433
# 397448    17490
# 397451    16446
# 397454    17389
# 397471    15694
# 397563    12985
# 397572    12985
# 397586    12985
# 397622    17754
# 397630    17754
# 397720    18102
# 397721    16626
# 397729    16626
# 397761    15311
# 397882    13777
# Name: CustomerID, Length: 11609, dtype: int64
# 11609

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
selection = orders['InvoiceNo'][(orders['Country'] == 'Spain') & (orders['Quantity'] > 50)]

print("Selected quantity:",selection.count(), "\n")
print("Selection: \n",selection)
# Out:
# Selected quantity: 39
#
# Selection:
#  4250      536944
# 4251      536944
# 4252      536944
# 4253      536944
# 4254      536944
# 32454     540785
# 32455     540785
# 32456     540785
# 32457     540785
# 91155     547972
# 91156     547972
# 91159     547972
# 174442    558871
# 174443    558871
# 174444    558871
# 174445    558871
# 174446    558871
# 174447    558871
# 174448    558871
# 174449    558871
# 197167    561669
# 197168    561669
# 197169    561669
# 197170    561669
# 197171    561669
# 224881    564734
# 254097    567968
# 289129    571255
# 289134    571255
# 289142    571255
# 289143    571255
# 295956    571851
# 312655    573362
# 312656    573362
# 312657    573362
# 366326    578321
# 366327    578321
# 366328    578321
# 366329    578321
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
selection = orders['InvoiceNo'][orders['amount_spent'] == 0]

print("Selected quantity:",selection.count(), "\n")
print("Selection: \n",selection)
# Out:
# Selected quantity: 40
#
# Selection:
#  6914      537197
# 22539     539263
# 25379     539722
# 29080     540372
# 29082     540372
# 34494     541109
# 53788     543599
# 85671     547417
# 92875     548318
# 97430     548871
# 107192    550188
# 128641    553000
# 137127    554037
# 194648    561284
# 197173    561669
# 199711    561916
# 208950    562973
# 223931    564651
# 223932    564651
# 223933    564651
# 223934    564651
# 256263    568158
# 259399    568384
# 273926    569716
# 286507    571035
# 307092    572893
# 319882    574138
# 320049    574175
# 320407    574252
# 322279    574469
# 328385    574879
# 329006    574920
# 329007    574920
# 334242    575579
# 334243    575579
# 352746    577129
# 353097    577168
# 354170    577314
# 358629    577696
# 370473    578841
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
import re
orders.head(100)
# Out:
#     Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0            0     536365    85123A  2010     12    3     8
# 1            1     536365     71053  2010     12    3     8
# 2            2     536365    84406B  2010     12    3     8
# 3            3     536365    84029G  2010     12    3     8
# 4            4     536365    84029E  2010     12    3     8
# 5            5     536365     22752  2010     12    3     8
# 6            6     536365     21730  2010     12    3     8
# 7            7     536366     22633  2010     12    3     8
# 8            8     536366     22632  2010     12    3     8
# 9            9     536367     84879  2010     12    3     8
# 10          10     536367     22745  2010     12    3     8
# 11          11     536367     22748  2010     12    3     8
# 12          12     536367     22749  2010     12    3     8
# 13          13     536367     22310  2010     12    3     8
# 14          14     536367     84969  2010     12    3     8
# 15          15     536367     22623  2010     12    3     8
# 16          16     536367     22622  2010     12    3     8
# 17          17     536367     21754  2010     12    3     8
# 18          18     536367     21755  2010     12    3     8
# 19          19     536367     21777  2010     12    3     8
# 20          20     536367     48187  2010     12    3     8
# 21          21     536368     22960  2010     12    3     8
# 22          22     536368     22913  2010     12    3     8
# 23          23     536368     22912  2010     12    3     8
# 24          24     536368     22914  2010     12    3     8
# 25          25     536369     21756  2010     12    3     8
# 26          26     536370     22728  2010     12    3     8
# 27          27     536370     22727  2010     12    3     8
# 28          28     536370     22726  2010     12    3     8
# 29          29     536370     21724  2010     12    3     8
# ..         ...        ...       ...   ...    ...  ...   ...
# 70          70     536375     37370  2010     12    3     9
# 71          71     536375     21871  2010     12    3     9
# 72          72     536375     21071  2010     12    3     9
# 73          73     536375     21068  2010     12    3     9
# 74          74     536375     82483  2010     12    3     9
# 75          75     536375     82486  2010     12    3     9
# 76          76     536375     82482  2010     12    3     9
# 77          77     536375    82494L  2010     12    3     9
# 78          78     536375    84029G  2010     12    3     9
# 79          79     536375    84029E  2010     12    3     9
# 80          80     536375     22752  2010     12    3     9
# 81          81     536375     21730  2010     12    3     9
# 82          82     536376     22114  2010     12    3     9
# 83          83     536376     21733  2010     12    3     9
# 84          84     536377     22632  2010     12    3     9
# 85          85     536377     22633  2010     12    3     9
# 86          86     536378     22386  2010     12    3     9
# 87          87     536378    85099C  2010     12    3     9
# 88          88     536378     21033  2010     12    3     9
# 89          89     536378     20723  2010     12    3     9
# 90          90     536378    84997B  2010     12    3     9
# 91          91     536378    84997C  2010     12    3     9
# 92          92     536378     21094  2010     12    3     9
# 93          93     536378     20725  2010     12    3     9
# 94          94     536378     21559  2010     12    3     9
# 95          95     536378     22352  2010     12    3     9
# 96          96     536378     21212  2010     12    3     9
# 97          97     536378     21975  2010     12    3     9
# 98          98     536378     21977  2010     12    3     9
# 99          99     536378     84991  2010     12    3     9
#
#                             Description  Quantity          InvoiceDate  \
# 0    white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                   white metal lantern         6  2010-12-01 08:26:00
# 2        cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3   knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4        red woolly hottie white heart.         6  2010-12-01 08:26:00
# 5          set 7 babushka nesting boxes         2  2010-12-01 08:26:00
# 6     glass star frosted t-light holder         6  2010-12-01 08:26:00
# 7                hand warmer union jack         6  2010-12-01 08:28:00
# 8             hand warmer red polka dot         6  2010-12-01 08:28:00
# 9         assorted colour bird ornament        32  2010-12-01 08:34:00
# 10           poppy's playhouse bedroom          6  2010-12-01 08:34:00
# 11            poppy's playhouse kitchen         6  2010-12-01 08:34:00
# 12    feltcraft princess charlotte doll         8  2010-12-01 08:34:00
# 13              ivory knitted mug cosy          6  2010-12-01 08:34:00
# 14   box of 6 assorted colour teaspoons         6  2010-12-01 08:34:00
# 15        box of vintage jigsaw blocks          3  2010-12-01 08:34:00
# 16       box of vintage alphabet blocks         2  2010-12-01 08:34:00
# 17             home building block word         3  2010-12-01 08:34:00
# 18             love building block word         3  2010-12-01 08:34:00
# 19          recipe box with metal heart         4  2010-12-01 08:34:00
# 20                  doormat new england         4  2010-12-01 08:34:00
# 21             jam making set with jars         6  2010-12-01 08:34:00
# 22          red coat rack paris fashion         3  2010-12-01 08:34:00
# 23       yellow coat rack paris fashion         3  2010-12-01 08:34:00
# 24         blue coat rack paris fashion         3  2010-12-01 08:34:00
# 25             bath building block word         3  2010-12-01 08:35:00
# 26            alarm clock bakelike pink        24  2010-12-01 08:45:00
# 27            alarm clock bakelike red         24  2010-12-01 08:45:00
# 28           alarm clock bakelike green        12  2010-12-01 08:45:00
# 29      panda and bunnies sticker sheet        12  2010-12-01 08:45:00
# ..                                  ...       ...                  ...
# 70           retro coffee mugs assorted         6  2010-12-01 09:32:00
# 71                  save the planet mug         6  2010-12-01 09:32:00
# 72       vintage billboard drink me mug         6  2010-12-01 09:32:00
# 73      vintage billboard love/hate mug         6  2010-12-01 09:32:00
# 74   wood 2 drawer cabinet white finish         2  2010-12-01 09:32:00
# 75    wood s/3 cabinet ant white finish         4  2010-12-01 09:32:00
# 76    wooden picture frame white finish         6  2010-12-01 09:32:00
# 77          wooden frame antique white          6  2010-12-01 09:32:00
# 78  knitted union flag hot water bottle         6  2010-12-01 09:32:00
# 79       red woolly hottie white heart.         6  2010-12-01 09:32:00
# 80         set 7 babushka nesting boxes         2  2010-12-01 09:32:00
# 81    glass star frosted t-light holder         6  2010-12-01 09:32:00
# 82    hot water bottle tea and sympathy        48  2010-12-01 09:32:00
# 83     red hanging heart t-light holder        64  2010-12-01 09:32:00
# 84            hand warmer red polka dot         6  2010-12-01 09:34:00
# 85               hand warmer union jack         6  2010-12-01 09:34:00
# 86              jumbo bag pink polkadot        10  2010-12-01 09:37:00
# 87       jumbo  bag baroque black white        10  2010-12-01 09:37:00
# 88      jumbo bag charlie and lola toys        10  2010-12-01 09:37:00
# 89             strawberry charlotte bag        10  2010-12-01 09:37:00
# 90    red 3 piece retrospot cutlery set        12  2010-12-01 09:37:00
# 91    blue 3 piece polkadot cutlery set         6  2010-12-01 09:37:00
# 92        set/6 red spotty paper plates        12  2010-12-01 09:37:00
# 93              lunch bag red retrospot        10  2010-12-01 09:37:00
# 94    strawberry lunch box with cutlery         6  2010-12-01 09:37:00
# 95    lunch box with cutlery retrospot          6  2010-12-01 09:37:00
# 96      pack of 72 retrospot cake cases       120  2010-12-01 09:37:00
# 97       pack of 60 dinosaur cake cases        24  2010-12-01 09:37:00
# 98   pack of 60 pink paisley cake cases        24  2010-12-01 09:37:00
# 99          60 teatime fairy cake cases        24  2010-12-01 09:37:00
#
#     UnitPrice  CustomerID         Country  amount_spent
# 0        2.55       17850  United Kingdom         15.30
# 1        3.39       17850  United Kingdom         20.34
# 2        2.75       17850  United Kingdom         22.00
# 3        3.39       17850  United Kingdom         20.34
# 4        3.39       17850  United Kingdom         20.34
# 5        7.65       17850  United Kingdom         15.30
# 6        4.25       17850  United Kingdom         25.50
# 7        1.85       17850  United Kingdom         11.10
# 8        1.85       17850  United Kingdom         11.10
# 9        1.69       13047  United Kingdom         54.08
# 10       2.10       13047  United Kingdom         12.60
# 11       2.10       13047  United Kingdom         12.60
# 12       3.75       13047  United Kingdom         30.00
# 13       1.65       13047  United Kingdom          9.90
# 14       4.25       13047  United Kingdom         25.50
# 15       4.95       13047  United Kingdom         14.85
# 16       9.95       13047  United Kingdom         19.90
# 17       5.95       13047  United Kingdom         17.85
# 18       5.95       13047  United Kingdom         17.85
# 19       7.95       13047  United Kingdom         31.80
# 20       7.95       13047  United Kingdom         31.80
# 21       4.25       13047  United Kingdom         25.50
# 22       4.95       13047  United Kingdom         14.85
# 23       4.95       13047  United Kingdom         14.85
# 24       4.95       13047  United Kingdom         14.85
# 25       5.95       13047  United Kingdom         17.85
# 26       3.75       12583          France         90.00
# 27       3.75       12583          France         90.00
# 28       3.75       12583          France         45.00
# 29       0.85       12583          France         10.20
# ..        ...         ...             ...           ...
# 70       1.06       17850  United Kingdom          6.36
# 71       1.06       17850  United Kingdom          6.36
# 72       1.06       17850  United Kingdom          6.36
# 73       1.06       17850  United Kingdom          6.36
# 74       4.95       17850  United Kingdom          9.90
# 75       6.95       17850  United Kingdom         27.80
# 76       2.10       17850  United Kingdom         12.60
# 77       2.55       17850  United Kingdom         15.30
# 78       3.39       17850  United Kingdom         20.34
# 79       3.39       17850  United Kingdom         20.34
# 80       7.65       17850  United Kingdom         15.30
# 81       4.25       17850  United Kingdom         25.50
# 82       3.45       15291  United Kingdom        165.60
# 83       2.55       15291  United Kingdom        163.20
# 84       1.85       17850  United Kingdom         11.10
# 85       1.85       17850  United Kingdom         11.10
# 86       1.95       14688  United Kingdom         19.50
# 87       1.95       14688  United Kingdom         19.50
# 88       2.95       14688  United Kingdom         29.50
# 89       0.85       14688  United Kingdom          8.50
# 90       3.75       14688  United Kingdom         45.00
# 91       3.75       14688  United Kingdom         22.50
# 92       0.85       14688  United Kingdom         10.20
# 93       1.65       14688  United Kingdom         16.50
# 94       2.55       14688  United Kingdom         15.30
# 95       2.55       14688  United Kingdom         15.30
# 96       0.42       14688  United Kingdom         50.40
# 97       0.55       14688  United Kingdom         13.20
# 98       0.55       14688  United Kingdom         13.20
# 99       0.55       14688  United Kingdom         13.20
#
# [100 rows x 14 columns]

# %%
# your answer here
selection = orders[orders['Description'].str.match('lunch bag')]
print("Selected quantity:",selection.count(),"\n")

orders[orders['Description'].str.match('lunch bag')].head()
# Out:
# Selected quantity: Unnamed: 0      11556
# InvoiceNo       11556
# StockCode       11556
# year            11556
# month           11556
# day             11556
# hour            11556
# Description     11556
# Quantity        11556
# InvoiceDate     11556
# UnitPrice       11556
# CustomerID      11556
# Country         11556
# amount_spent    11556
# dtype: int64
#      Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93           93     536378     20725  2010     12    3     9
# 172         174     536385     22662  2010     12    3     9
# 354         363     536401     22662  2010     12    3    11
# 359         368     536401     20725  2010     12    3    11
# 360         369     536401     22382  2010     12    3    11
#
#                      Description  Quantity          InvoiceDate  UnitPrice  \
# 93       lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# 172  lunch bag dolly girl design        10  2010-12-01 09:56:00       1.65
# 354  lunch bag dolly girl design         1  2010-12-01 11:21:00       1.65
# 359      lunch bag red retrospot         1  2010-12-01 11:21:00       1.65
# 360   lunch bag spaceboy design          2  2010-12-01 11:21:00       1.65
#
#      CustomerID         Country  amount_spent
# 93        14688  United Kingdom         16.50
# 172       17420  United Kingdom         16.50
# 354       15862  United Kingdom          1.65
# 359       15862  United Kingdom          1.65
# 360       15862  United Kingdom          3.30

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
selection = orders[(orders['Description'].str.match('lunch bag')) & (orders['year']==2011)]
print("Selected quantity:",selection.count(),"\n")

orders[(orders['Description'].str.match('lunch bag')) & (orders['year']==2011)].head()
# Out:
# Selected quantity: Unnamed: 0      11234
# InvoiceNo       11234
# StockCode       11234
# year            11234
# month           11234
# day             11234
# hour            11234
# Description     11234
# Quantity        11234
# InvoiceDate     11234
# UnitPrice       11234
# CustomerID      11234
# Country         11234
# amount_spent    11234
# dtype: int64
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340       42678     540015     20725  2011      1    2    11
# 26341       42679     540015     20726  2011      1    2    11
# 26512       42851     540023     22382  2011      1    2    12
# 26513       42852     540023     20726  2011      1    2    12
# 26860       43616     540098     22384  2011      1    2    15
#
#                       Description  Quantity          InvoiceDate  UnitPrice  \
# 26340     lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# 26341          lunch bag woodland        10  2011-01-04 11:40:00       1.65
# 26512  lunch bag spaceboy design          2  2011-01-04 12:58:00       1.65
# 26513          lunch bag woodland         1  2011-01-04 12:58:00       1.65
# 26860     lunch bag pink polkadot         1  2011-01-04 15:50:00       1.65
#
#        CustomerID         Country  amount_spent
# 26340       13319  United Kingdom         16.50
# 26341       13319  United Kingdom         16.50
# 26512       15039  United Kingdom          3.30
# 26513       15039  United Kingdom          1.65
# 26860       16241  United Kingdom          1.65

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
print(orders['amount_spent'].value_counts())
# Out:
# 15.00      20082
# 19.80      11033
# 17.70       9174
# 16.50       8490
# 10.20       8028
# 1.25        7552
# 3.75        6847
# 1.65        6228
# 10.50       5550
# 20.80       5524
# 2.95        5432
# 5.04        5284
# 2.50        5242
# 30.00       5226
# 7.50        5163
# 8.50        4953
# 17.00       4899
# 9.90        4810
# 3.30        4754
# 17.40       4394
# 14.85       4246
# 2.10        4041
# 4.95        4014
# 15.30       3951
# 5.90        3669
# 2.55        3661
# 15.90       3562
# 13.20       3517
# 10.08       3248
# 0.85        3143
#            ...
# 622.08         1
# 3315.00        1
# 202.37         1
# 114.55         1
# 630.80         1
# 0.25           1
# 2610.00        1
# 146.56         1
# 0.06           1
# 26.64          1
# 232.32         1
# 81.50          1
# 852.80         1
# 6.82           1
# 139.30         1
# 66.30          1
# 462.58         1
# 149.46         1
# 650.25         1
# 57.00          1
# 116.41         1
# 417.50         1
# 649.50         1
# 833.25         1
# 10.85          1
# 176.28         1
# 61.95          1
# 17.73          1
# 308.89         1
# 77.50          1
# Name: amount_spent, Length: 2811, dtype: int64

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders[orders['month']==8].head()
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
#
#                               Description  Quantity          InvoiceDate  \
# 199475       6 ribbons elegant christmas         96  2011-08-01 08:30:00
# 199476          scandinavian reds ribbons       156  2011-08-01 08:30:00
# 199477    ivory hanging decoration  heart        24  2011-08-01 09:31:00
# 199478   single heart zinc t-light holder        12  2011-08-01 09:31:00
# 199479  hanging heart zinc t-light holder        12  2011-08-01 09:31:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 199475       1.45       17941  United Kingdom        139.20
# 199476       1.06       17941  United Kingdom        165.36
# 199477       0.85       14947  United Kingdom         20.40
# 199478       0.95       14947  United Kingdom         11.40
# 199479       0.85       14947  United Kingdom         10.20

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders.groupby(by = 'Country').agg({'InvoiceNo':['count']})
# Out:
#                      InvoiceNo
#                          count
# Country
# Australia                 1185
# Austria                    398
# Bahrain                     17
# Belgium                   2031
# Brazil                      32
# Canada                     151
# Channel Islands            748
# Cyprus                     614
# Czech Republic              25
# Denmark                    380
# EIRE                      7238
# European Community          60
# Finland                    685
# France                    8342
# Germany                   9042
# Greece                     145
# Iceland                    182
# Israel                     248
# Italy                      758
# Japan                      321
# Lebanon                     45
# Lithuania                   35
# Malta                      112
# Netherlands               2363
# Norway                    1072
# Poland                     330
# Portugal                  1462
# RSA                         58
# Saudi Arabia                 9
# Singapore                  222
# Spain                     2485
# Sweden                     451
# Switzerland               1842
# USA                        179
# United Arab Emirates        68
# United Kingdom          354345
# Unspecified                244

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby(by = ['Country']).agg({'amount_spent':['mean']})
# Out:
#                      amount_spent
#                              mean
# Country
# Australia              116.895620
# Austria                 25.624824
# Bahrain                 32.258824
# Belgium                 20.283772
# Brazil                  35.737500
# Canada                  24.280662
# Channel Islands         27.340160
# Cyprus                  22.134169
# Czech Republic          33.069600
# Denmark                 49.882474
# EIRE                    36.687745
# European Community      21.670833
# Finland                 32.913985
# France                  25.056827
# Germany                 25.311562
# Greece                  32.831172
# Iceland                 23.681319
# Israel                  29.119718
# Italy                   23.064960
# Japan                  116.561900
# Lebanon                 37.641778
# Lithuania               47.458857
# Malta                   24.335625
# Netherlands            120.798282
# Norway                  33.736418
# Poland                  22.226212
# Portugal                22.872702
# RSA                     17.281207
# Saudi Arabia            16.213333
# Singapore               95.852658
# Spain                   24.779521
# Sweden                  85.096075
# Switzerland             30.642752
# USA                     20.002179
# United Arab Emirates    27.974706
# United Kingdom          20.625073
# Unspecified             10.930615

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
print(orders['Description'].agg({'amount_spent':['max']}))
orders[['Description','amount_spent']].agg({'amount_spent':['max']})

#orders.groupby(by=['Description']).agg({'amount_spent':['max']})

#orders.pivot_table('amount_spent','Description', aggfunc='max')

#what is it "dict".  how to show also the amount
# Out:
# amount_spent  max    zinc wire sweetheart letter tray
# Name: Description, dtype: object
# /usr/local/Cellar/ipython/7.3.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#      amount_spent
# max      168469.6

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here

# %%
orders.groupby(by=['year']).agg({'amount_spent':['mean']})
# Out:
#      amount_spent
#              mean
# year
# 2010    21.892733
# 2011    22.430074
