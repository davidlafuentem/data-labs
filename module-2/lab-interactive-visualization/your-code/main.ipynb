# %% [markdown]
# # Interactive Visualization Lab
#
# Complete the following set of exercises to solidify your knowledge of interactive visualization using Plotly, Cufflinks, and IPyWidgets.

# %%
import pandas as pd
import plotly.plotly as py
import cufflinks as cf
import numpy as np
from ipywidgets import interact

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_excel('../Data/Online Retail.xlsx')
data.head(10)
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
# 5     536396 2010-12-01 10:51:00    85123A
# 6     536401 2010-12-01 11:21:00    85123A
# 7     536406 2010-12-01 11:33:00    85123A
# 8     536502 2010-12-01 12:36:00    85123A
# 9     536520 2010-12-01 12:43:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55   163.20
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55    81.60
# 5  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55    15.30
# 6  CREAM HANGING HEART T-LIGHT HOLDER         4       2.95    11.80
# 7  CREAM HANGING HEART T-LIGHT HOLDER         8       2.55    20.40
# 8  CREAM HANGING HEART T-LIGHT HOLDER         6       2.95    17.70
# 9  CREAM HANGING HEART T-LIGHT HOLDER         3       2.95     8.85
#
#    CustomerID         Country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom
# 5       17850  United Kingdom
# 6       15862  United Kingdom
# 7       17850  United Kingdom
# 8       16552  United Kingdom
# 9       14729  United Kingdom

# %% [markdown]
# ## 1. Create an interactive bar chart showing total quantity and revenue by country (excluding United Kingdom) for the month of April 2011.

# %%
data_reveneu = data[data.Country != 'United Kingdom'].groupby(by='Country')\
            .agg({'Revenue':'sum'}).sort_values(by='Revenue', ascending=False).reset_index()

data_reveneu.iplot(kind='bar',x='Country', xTitle='Countries', 
                   y='Revenue', yTitle='Revenue', 
                   title='Reveneus by country (United Kingdom not included)')
# Out:
# <div>
#
#
#             <div id="8b136e9f-89ea-45fa-bc75-1662f084c807" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plotly.your-company.com';
#
#                 if (document.getElementById("8b136e9f-89ea-45fa-bc75-1662f084c807")) {
#                     Plotly.newPlot(
#                         '8b136e9f-89ea-45fa-bc75-1662f084c807',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Revenue", "orientation": "v", "text": "", "type": "bar", "uid": "06e5e4ee-e08d-46ac-8468-4360b1712be2", "x": ["Netherlands", "EIRE", "Germany", "France", "Australia", "Spain", "Switzerland", "Japan", "Belgium", "Sweden", "Norway", "Portugal", "Channel Islands", "Finland", "Denmark", "Italy", "Cyprus", "Singapore", "Austria", "Israel", "Poland", "Greece", "Iceland", "USA", "Canada", "Malta", "United Arab Emirates", "Lebanon", "Lithuania", "Brazil", "South Africa", "Czech Republic", "Bahrain", "Saudi Arabia"], "y": [283889.3400000007, 257296.5599999964, 205569.889999996, 183891.6799999972, 138171.31, 55725.11000000001, 52441.950000000084, 37416.36999999997, 36927.34000000007, 36839.32999999998, 32454.64000000007, 26707.950000000023, 20007.439999999937, 18344.879999999994, 18211.33999999999, 15820.239999999996, 13254.689999999993, 9120.39, 8742.679999999991, 7221.690000000003, 6974.649999999999, 4425.52, 4309.999999999998, 3580.390000000002, 3115.44, 2070.5899999999997, 1864.7800000000004, 1693.88, 1661.0600000000004, 1143.6000000000001, 1002.3099999999997, 786.74, 548.4, 145.92]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Reveneus by country (United Kingdom not included)"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Countries"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Revenue"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plotly.your-company.com", "plotlyServerURL": "https://plotly.your-company.com", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8b136e9f-89ea-45fa-bc75-1662f084c807');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## 2. Create an interactive line chart showing quantity and revenue sold to France between January 1st and May 31st 2011.

# %%
data_france = data[(data.Country == 'France') & (data.InvoiceDate >= '2011-01-01 00:00:00')\
                   & (data.InvoiceDate <= '2011-02-1 00:00:00')].sort_values(by='InvoiceDate',ascending=False)

data_france.iplot(kind='line',x='InvoiceDate', xTitle='Timeframe for France', y='Revenue', yTitle='Revenue')
# Out:
# <div>
#
#
#             <div id="95465fa8-cfc9-40ce-9977-3409842ac5d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plotly.your-company.com';
#
#                 if (document.getElementById("95465fa8-cfc9-40ce-9977-3409842ac5d6")) {
#                     Plotly.newPlot(
#                         '95465fa8-cfc9-40ce-9977-3409842ac5d6',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Revenue", "text": "", "type": "scatter", "uid": "544f1a67-9bab-474b-875c-a79cab30a19e", "x": ["2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 15:36:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-31 09:57:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 13:37:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 10:45:00", "2011-01-28 09:20:00", "2011-01-28 09:20:00", "2011-01-28 09:20:00", "2011-01-28 09:20:00", "2011-01-28 09:20:00", "2011-01-28 09:20:00", "2011-01-28 09:20:00", "2011-01-28 09:20:00", "2011-01-28 09:20:00", "2011-01-28 09:20:00", "2011-01-24 15:32:00", "2011-01-24 15:32:00", "2011-01-24 15:32:00", "2011-01-24 15:32:00", "2011-01-24 15:32:00", "2011-01-24 15:32:00", "2011-01-24 15:32:00", "2011-01-24 15:32:00", "2011-01-24 15:32:00", "2011-01-23 15:17:00", "2011-01-23 15:17:00", "2011-01-23 15:17:00", "2011-01-23 15:17:00", "2011-01-23 15:17:00", "2011-01-23 15:17:00", "2011-01-23 15:17:00", "2011-01-23 15:17:00", "2011-01-23 15:17:00", "2011-01-23 15:17:00", "2011-01-23 15:17:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01-20 10:48:00", "2011-01- ...

# %% [markdown]
# ## 3. Create an interactive scatter plot showing the relationship between average quantity (x-axis) and average unit price (y-axis) for the product PARTY BUNTING with the plot points color-coded by country (categories).

# %%
data_party = data[data.Description=='PARTY BUNTING'].groupby(by='Country').agg({'Quantity':np.mean,'UnitPrice':np.mean}).reset_index()


data_party.iplot(kind='scatter', mode='markers', x='Quantity', y='UnitPrice', categories='Country', text='Country', showlegend=True)
# Out:
# <div>
#
#
#             <div id="f85721ef-baa4-48b0-8c66-fc677bdf16f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plotly.your-company.com';
#
#                 if (document.getElementById("f85721ef-baa4-48b0-8c66-fc677bdf16f8")) {
#                     Plotly.newPlot(
#                         'f85721ef-baa4-48b0-8c66-fc677bdf16f8',
#                         [{"marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Australia", "text": ["Australia"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "60c2f958-b80e-4127-a76b-10bd92f7478b", "x": [33.125], "y": [4.7125]}, {"marker": {"color": "rgba(55, 128, 191, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Austria", "text": ["Austria"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "3b1fea20-37f5-42d1-9392-208c08ea7b87", "x": [8.0], "y": [4.95]}, {"marker": {"color": "rgba(50, 171, 96, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Belgium", "text": ["Belgium"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "1d51ed09-f046-46c3-b03c-6d5fb502248f", "x": [4.0], "y": [4.95]}, {"marker": {"color": "rgba(128, 0, 128, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Channel Islands", "text": ["Channel Islands"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "d230706d-027e-4053-a6e8-9d96a5c3bd20", "x": [13.333333333333334], "y": [4.95]}, {"marker": {"color": "rgba(219, 64, 82, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Cyprus", "text": ["Cyprus"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "7af0cd26-3063-4380-ab90-b6b1e3fde3d4", "x": [2.3333333333333335], "y": [4.75]}, {"marker": {"color": "rgba(0, 128, 128, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Denmark", "text": ["Denmark"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "14737421-93ba-43ae-8ec1-4df867bb8703", "x": [12.0], "y": [4.95]}, {"marker": {"color": "rgba(255, 255, 51, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "EIRE", "text": ["EIRE"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "9eb91eed-2176-468a-8fc5-3653699b017c", "x": [21.210526315789473], "y": [4.739473684210528]}, {"marker": {"color": "rgba(128, 128, 0, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Finland", "text": ["Finland"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "6a8da65c-0dec-40ac-9dd0-886411e18ba5", "x": [6.0], "y": [4.95]}, {"marker": {"color": "rgba(251, 128, 114, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "France", "text": ["France"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "4ec8b950-ff63-4ebc-b9b4-1f4c939b90ce", "x": [5.7272727272727275], "y": [4.922727272727275]}, {"marker": {"color": "rgba(128, 177, 211, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Germany", "text": ["Germany"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "3cad5094-4b87-45ea-9fec-3e30a3ca81b1", "x": [6.8], "y": [4.89]}, {"marker": {"color": "rgba(128, 177, 211, 0.8999999999999999)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Israel", "text": ["Israel"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "ae2066a0-b711-466c-8595-a6bd34abb8bd", "x": [1.0], "y": [4.95]}, {"marker": {"color": "rgba(255, 153, 51, 0.8999999999999999)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Japan", "text": ["Japan"], "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "e2abb28e-6fb4-42ad-8719-581a52059f19", "x": [56.666666666666664], "y": [4.183333333333334]}, {"marker": {"color": "rgba(55, 128, 191, 0.8999999999999999)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "marker ...
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "showlegend": true, "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plotly.your-company.com", "plotlyServerURL": "https://plotly.your-company.com", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f85721ef-baa4-48b0-8c66-fc677bdf16f8');
# var x = new MutationObserver(function (mutations, observer) {{

# %% [markdown]
# ## 4. Create a set of interactive histograms showing the distributions of quantity per invoice for the following countries: EIRE, Germany, France, and Netherlands.

# %% [markdown]
# ## 5. Create an interactive side-by-side bar chart showing the revenue by country listed below (bars) for each of the products listed below.

# %%
product_list = ['JUMBO BAG RED RETROSPOT', 
                'CREAM HANGING HEART T-LIGHT HOLDER',
                'REGENCY CAKESTAND 3 TIER']

country_list = ['EIRE', 'Germany', 'France', 'Netherlands']

# %% [markdown]
# ## 6. Create an interactive line chart showing quantity sold by day for the United Kingdom. Add drop-down boxes for Year and Month that allow you to filter the date range that appears in the chart.

# %%
data['Year'] = pd.DatetimeIndex(data['InvoiceDate']).year
data['Month'] = pd.DatetimeIndex(data['InvoiceDate']).month
data['Day'] = pd.DatetimeIndex(data['InvoiceDate']).day
uk = data[data['Country']=='United Kingdom']

# %% [markdown]
# ## 7. Create an interactive scatter plot that plots number of invoices (x-axis) vs. number of customers (y-axis) and the plot points represent individual products. Add two sliders that control the x and y axis ranges.

# %%
agg_func = {'InvoiceNo':'nunique',
            'Quantity':'sum',
            'UnitPrice':'mean',
            'Revenue':'sum',
            'CustomerID':'nunique'}

products = uk.groupby('Description').agg(agg_func)

# %% [markdown]
# ## 8. Creat an interactive bar chart that shows revenue by product description. Add a text field widget that filters the results to show the product that contain the text entered in their description.
