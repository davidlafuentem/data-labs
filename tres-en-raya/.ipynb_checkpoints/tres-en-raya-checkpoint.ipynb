# %%
"""
# Reglas
Rama: tres-en-raya
carpeta: modulo-x (literalmente una x)
Se entrega en un .py (NO EN UN JUPYTER NOTEBOOK)
~Premio~: Bono 6 meses HBO ;););)

## Requisitos para que se dé por buena una solución
* Uso de funciones (*obvio*, estamos en el lab de funciones)
* Debe permitir como mínimo dos jugadores
* Debe detectar cuando gana un jugador
* Debe detectar cuando pierde un jugador (en el caso de un jugador)
* Debe pintar un tablero
## Cosas que se valorarán
* Código limpio
* Que sea bonito (visualmente)
* Que tenga modo un jugador (y que no sea puto aleatorio)
* Cuantos menos petes mejor
* Sorprendedme!
## Dudas raras
* ¿Es de estos tres en raya de gravedad? **NO**, es como este, el de toda la vida: ![](https://i.ytimg.com/vi/4LBxriJ__U8/maxresdefault.jpg)
"""

import random

#table follow this schema: ([rowup_1,rowup_2,rowup_3],[rowmid_1,rowmid_2,rowmid_3],[rowdown_1,rowdown_2,rowdown_3]) 
tablero = ([,,],[,,],[,,])
def limpiar_tablero(tablero):
    tablero = (['-','-','-'],[,,],[,,])
    return tablero

#this function print the play board and also the position occupied by the players. Player 1 will write an "X", 2 and "O"
def dibuja_tablero(tablero)

def selec_players():
    listJugadores = []
    listJugadores.append(input("Introduzca el nombre del jugador \"X\""))
    listJugadores.append(input("Introduzca el nombre del jugador \"O\""))
    return listJugadores

def who_play_first(listJugadores):
    if random(0,1) == 0:
        return 0
    else:
        return 1

def print_board


def jugada_valida(casilla):
    if tablero:
        
        

        

def input_jugada()
