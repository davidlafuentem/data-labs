# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
#### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# This is the url you will scrape in this exercise
URL_DEVELOPERS = 'https://github.com/trending/developers'

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
URL_DEVELOPERS = 'https://github.com/trending/developers'

#your code
#search for   <a class="js-selected-navigation-item selected tabnav-tab" aria-current="page" data-selected-links="trending_developers /trending/developers" href="/trending/developers">Developers</a>
response = requests.get(URL_DEVELOPERS)
soup = BeautifulSoup(response.text, "html.parser")

# %%
developers_cont = soup.find_all('article',{'class','Box-row d-flex'})
print(developers_cont)
# Out:
# [<article class="Box-row d-flex" id="pa-phil-opp">
# <a class="text-gray f6 text-center" href="#pa-phil-opp" style="width: 16px;">
#     1
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/phil-opp/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/phil-opp"><img alt="@phil-opp" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/1131315?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/phil-opp">
#             Philipp Oppermann
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/phil-opp">
#               phil-opp
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/phil-opp/blog_os" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       blog_os
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Writing an OS in Rust
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="mr-2">
# <a class="btn btn-sm btn-block" href="/sponsors/phil-opp">
# <svg aria-label="heart" class="octicon octicon-heart icon-sponsor v-align-middle" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12"><path d="M9 2c-.97 0-1.69.42-2.2 1-.51.58-.78.92-.8 1-.02-.08-.28-.42-.8-1-.52-.58-1.17-1-2.2-1-1.632.086-2.954 1.333-3 3 0 .52.09 1.52.67 2.67C1.25 8.82 3.01 10.61 6 13c2.98-2.39 4.77-4.17 5.34-5.33C11.91 6.51 12 5.5 12 5c-.047-1.69-1.342-2.913-3-3z" fill-rule="evenodd"></path></svg>
# <span class="ml-1">
#               Sponsor
# </span>
# </a>
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-fzaninotto">
# <a class="text-gray f6 text-center" href="#pa-fzaninotto" style="width: 16px;">
#     2
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/fzaninotto/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/fzaninotto"><img alt="@fzaninotto" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/99944?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/fzaninotto">
#             Francois Zaninotto
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/fzaninotto">
#               fzaninotto
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/fzaninotto/Faker" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       Faker
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Faker is a PHP library that generates fake data for you
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-samuelcolvin">
# <a class="text-gray f6 text-center" href="#pa-samuelcolvin" style="width: 16px;">
#     3
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/samuelcolvin/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/samuelcolvin"><img alt="@samuelcolvin" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/4039449?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/samuelcolvin">
#             Samuel Colvin
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/samuelcolvin">
#               samuelcolvin
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/samuelcolvin/pydantic" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       pydantic
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Data parsing and validation using Python type hints
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-rakannimer">
# <a class="text-gray f6 text-center" href="#pa-rakannimer" style="width: 16px;">
#     4
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/rakannimer/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/rakannimer"><img alt="@rakannimer" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/1270909?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/rakannimer">
#             Rakan Nimer
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/rakannimer">
#               rakannimer
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/rakannimer/react-google-charts" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       react-google-charts
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A thin, typed, React wrapper over Google Charts Visualization and Charts API.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-ianstormtaylor">
# <a class="text-gray f6 text-center" href="#pa-ianstormtaylor" style="width: 16px;">
#     5
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/ianstormtaylor/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/ianstormtaylor"><img alt="@ianstormtaylor" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/311752?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/ianstormtaylor">
#             Ian Storm Taylor
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/ianstormtaylor">
#               ianstormtaylor
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/ianstormtaylor/slate" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       slate
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A completely customizable framework for building rich text editors. (Currently in beta.)
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-groue">
# <a class="text-gray f6 text-center" href="#pa-groue" style="width: 16px;">
#     6
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/groue/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/groue"><img alt="@groue" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/54219?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/groue">
#             Gwendal Roué
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/groue">
#               groue
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/groue/GRDB.swift" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       GRDB.swift
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A toolkit for SQLite databases, with a focus on application development
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="mr-2">
# <a class="btn btn-sm btn-block" href="/sponsors/groue">
# <svg aria-label="heart" class="octicon octicon-heart icon-sponsor v-align-middle" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12"><path d="M9 2c-.97 0-1.69.42-2.2 1-.51.58-.78.92-.8 1-.02-.08-.28-.42-.8-1-.52-.58-1.17-1-2.2-1-1.632.086-2.954 1.333-3 3 0 .52.09 1.52.67 2.67C1.25 8.82 3.01 10.61 6 13c2.98-2.39 4.77-4.17 5.34-5.33C11.91 6.51 12 5.5 12 5c-.047-1.69-1.342-2.913-3-3z" fill-rule="evenodd"></path></svg>
# <span class="ml-1">
#               Sponsor
# </span>
# </a>
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-tamalsaha">
# <a class="text-gray f6 text-center" href="#pa-tamalsaha" style="width: 16px;">
#     7
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/tamalsaha/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/tamalsaha"><img alt="@tamalsaha" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/94814?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/tamalsaha">
#             Tamal Saha
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/tamalsaha">
#               tamalsaha
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/tamalsaha/kubectl-plugin-demo" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       kubectl-plugin-demo
#     </a>
# </h1>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-bwplotka">
# <a class="text-gray f6 text-center" href="#pa-bwplotka" style="width: 16px;">
#     8
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/bwplotka/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/bwplotka"><img alt="@bwplotka" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/6950331?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/bwplotka">
#             Bartlomiej Plotka
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/bwplotka">
#               bwplotka
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/bwplotka/mimic" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       mimic
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       mimic: Define your Deployments, Infrastructure and Configuration as a Go Code
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-normanmaurer">
# <a class="text-gray f6 text-center" href="#pa-normanmaurer" style="width: 16px;">
#     9
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/normanmaurer/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/normanmaurer"><img alt="@normanmaurer" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/439362?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/normanmaurer">
#             Norman Maurer
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/normanmaurer">
#               normanmaurer
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/normanmaurer/netty-in-action" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       netty-in-action
#     </a>
# </h1>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-ccrisan">
# <a class="text-gray f6 text-center" href="#pa-ccrisan" style="width: 16px;">
#     10
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/ccrisan/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/ccrisan"><img alt="@ccrisan" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/76639?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/ccrisan">
#             Calin Crisan
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/ccrisan">
#               ccrisan
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/ccrisan/motioneyeos" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       motioneyeos
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A Video Surveillance OS For Single-board Computers
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-stof">
# <a class="text-gray f6 text-center" href="#pa-stof" style="width: 16px;">
#     11
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/stof/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/stof"><img alt="@stof" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/439401?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/stof">
#             Christophe Coevoet
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/stof">
#               stof
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/stof/StofDoctrineExtensionsBundle" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       StofDoctrineExtensionsBundle
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Integration bundle for DoctrineExtensions by l3pp4rd in Symfony
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="mr-2">
# <a class="btn btn-sm btn-block" href="/sponsors/stof">
# <svg aria-label="heart" class="octicon octicon-heart icon-sponsor v-align-middle" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12"><path d="M9 2c-.97 0-1.69.42-2.2 1-.51.58-.78.92-.8 1-.02-.08-.28-.42-.8-1-.52-.58-1.17-1-2.2-1-1.632.086-2.954 1.333-3 3 0 .52.09 1.52.67 2.67C1.25 8.82 3.01 10.61 6 13c2.98-2.39 4.77-4.17 5.34-5.33C11.91 6.51 12 5.5 12 5c-.047-1.69-1.342-2.913-3-3z" fill-rule="evenodd"></path></svg>
# <span class="ml-1">
#               Sponsor
# </span>
# </a>
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-felixrieseberg">
# <a class="text-gray f6 text-center" href="#pa-felixrieseberg" style="width: 16px;">
#     12
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/felixrieseberg/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/felixrieseberg"><img alt="@felixrieseberg" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/1426799?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/felixrieseberg">
#             Felix Rieseberg
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/felixrieseberg">
#               felixrieseberg
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/felixrieseberg/windows95" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       windows95
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
# <g-emoji alias="hankey" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f4a9.png">💩</g-emoji><g-emoji alias="rocket" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f680.png">🚀</g-emoji> Windows 95 in Electron. Runs on macOS, Linux, and Windows.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-carllerche">
# <a class="text-gray f6 text-center" href="#pa-carllerche" style="width: 16px;">
#     13
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/carllerche/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/carllerche"><img alt="@carllerche" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/6180?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/carllerche">
#             Carl Lerche
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/carllerche">
#               carllerche
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/carllerche/tower-web" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       tower-web
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A fast, boilerplate free, web framework for Rust
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-nschloe">
# <a class="text-gray f6 text-center" href="#pa-nschloe" style="width: 16px;">
#     14
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/nschloe/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/nschloe"><img alt="@nschloe" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/181628?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/nschloe">
#             Nico Schlömer
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/nschloe">
#               nschloe
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/nschloe/tikzplotlib" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       tikzplotlib
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Convert matplotlib figures to TikZ/PGFplots for smooth integration into LaTeX.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-rimusz">
# <a class="text-gray f6 text-center" href="#pa-rimusz" style="width: 16px;">
#     15
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/rimusz/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/rimusz"><img alt="@rimusz" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/5215395?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/rimusz">
#             Rimas Mocevicius
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/rimusz">
#               rimusz
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/rimusz/helm-tiller" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       helm-tiller
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Helm v2 Tiller plugin aka Tillerless Helm
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-mdlayher">
# <a class="text-gray f6 text-center" href="#pa-mdlayher" style="width: 16px;">
#     16
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/mdlayher/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/mdlayher"><img alt="@mdlayher" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/1926905?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/mdlayher">
#             Matt Layher
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/mdlayher">
#               mdlayher
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# ...
#     21
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/daffl/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/daffl"><img alt="@daffl" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/338316?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/daffl">
#             David Luecke
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/daffl">
#               daffl
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/daffl/jquery.dform" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       jquery.dform
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A flexible JavaScript Object and JSON to HTML converter with a focus on forms
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="mr-2">
# <a class="btn btn-sm btn-block" href="/sponsors/daffl">
# <svg aria-label="heart" class="octicon octicon-heart icon-sponsor v-align-middle" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12"><path d="M9 2c-.97 0-1.69.42-2.2 1-.51.58-.78.92-.8 1-.02-.08-.28-.42-.8-1-.52-.58-1.17-1-2.2-1-1.632.086-2.954 1.333-3 3 0 .52.09 1.52.67 2.67C1.25 8.82 3.01 10.61 6 13c2.98-2.39 4.77-4.17 5.34-5.33C11.91 6.51 12 5.5 12 5c-.047-1.69-1.342-2.913-3-3z" fill-rule="evenodd"></path></svg>
# <span class="ml-1">
#               Sponsor
# </span>
# </a>
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-arturbosch">
# <a class="text-gray f6 text-center" href="#pa-arturbosch" style="width: 16px;">
#     22
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/arturbosch/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/arturbosch"><img alt="@arturbosch" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/20924106?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/arturbosch">
#             Artur Bosch
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/arturbosch">
#               arturbosch
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/arturbosch/detekt" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       detekt
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Static code analysis for Kotlin
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-alvarotrigo">
# <a class="text-gray f6 text-center" href="#pa-alvarotrigo" style="width: 16px;">
#     23
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/alvarotrigo/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/alvarotrigo"><img alt="@alvarotrigo" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/1706326?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/alvarotrigo">
#             Álvaro
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/alvarotrigo">
#               alvarotrigo
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/alvarotrigo/fullPage.js" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       fullPage.js
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       fullPage plugin by Alvaro Trigo. Create full screen pages fast and simple
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-streamich">
# <a class="text-gray f6 text-center" href="#pa-streamich" style="width: 16px;">
#     24
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/streamich/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/streamich"><img alt="@streamich" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/9773803?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/streamich">
#             Vadim Dalecky
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/streamich">
#               streamich
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/streamich/react-use" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       react-use
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       React Hooks — <g-emoji alias="+1" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f44d.png">👍</g-emoji>
# </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="mr-2">
# <a class="btn btn-sm btn-block" href="/sponsors/streamich">
# <svg aria-label="heart" class="octicon octicon-heart icon-sponsor v-align-middle" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12"><path d="M9 2c-.97 0-1.69.42-2.2 1-.51.58-.78.92-.8 1-.02-.08-.28-.42-.8-1-.52-.58-1.17-1-2.2-1-1.632.086-2.954 1.333-3 3 0 .52.09 1.52.67 2.67C1.25 8.82 3.01 10.61 6 13c2.98-2.39 4.77-4.17 5.34-5.33C11.91 6.51 12 5.5 12 5c-.047-1.69-1.342-2.913-3-3z" fill-rule="evenodd"></path></svg>
# <span class="ml-1">
#               Sponsor
# </span>
# </a>
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-hugovk">
# <a class="text-gray f6 text-center" href="#pa-hugovk" style="width: 16px;">
#     25
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/hugovk/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/hugovk"><img alt="@hugovk" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/1324225?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/hugovk">
#             Hugo van Kemenade
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/hugovk">
#               hugovk
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/hugovk/meow.py" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       meow.py
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       50,000 Meows: Replace all words with meows, preserving punctuation. For NaNoGenMo 2014.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"0BA8:3D531:3759FDB:52C0DE6:5DE29ABE","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="92b15f2ebcbad7963ef57c4ead82b20680c013f347993f2658a42f6a87024642" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>]

# %%
developers_info = [developers_cont[i]['id'].replace("pa-","") for i in range(len(developers_cont))]

pprint(developers_info)
# Out:
# ['phil-opp',
#  'fzaninotto',
#  'samuelcolvin',
#  'rakannimer',
#  'ianstormtaylor',
#  'groue',
#  'tamalsaha',
#  'bwplotka',
#  'normanmaurer',
#  'ccrisan',
#  'stof',
#  'felixrieseberg',
#  'carllerche',
#  'nschloe',
#  'rimusz',
#  'mdlayher',
#  'luanpotter',
#  'sameersbn',
#  'tombuildsstuff',
#  'JohnSundell',
#  'daffl',
#  'arturbosch',
#  'alvarotrigo',
#  'streamich',
#  'hugovk']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
URL_REPOSITORIES = 'https://github.com/trending/python?since=daily'

# %%
#your code
response = requests.get(URL_REPOSITORIES)
soup = BeautifulSoup(response.text, "html.parser")

repositories_cont = soup.find_all('h1',{'class',"h3 lh-condensed"})

repositories_info = [repositories_cont[i].find('a')['href'] for i in range(len(repositories_cont))]
pprint(repositories_info)
# Out:
# ['/521xueweihan/HelloGitHub',
#  '/sherlock-project/sherlock',
#  '/sebastianruder/NLP-progress',
#  '/odoo/odoo',
#  '/quantumblacklabs/kedro',
#  '/s0md3v/Corsy',
#  '/Linzaer/Ultra-Light-Fast-Generic-Face-Detector-1MB',
#  '/heucoder/dimensionality_reduction_alo_codes',
#  '/khd2019/khd2019',
#  '/python/cpython',
#  '/deepmind/graph_nets',
#  '/Smerity/sha-rnn',
#  '/Netflix/vmaf',
#  '/fighting41love/funNLP',
#  '/explosion/spaCy',
#  '/harismuneer/Ultimate-Facebook-Scraper',
#  '/fizyr/keras-retinanet',
#  '/celery/celery',
#  '/wangzheng0822/algo',
#  '/aws/sagemaker-python-sdk',
#  '/luka1199/geo-heatmap',
#  '/ageitgey/face_recognition',
#  '/pytorch/ignite',
#  '/docker/compose',
#  '/opencv/cvat']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
URL_WALTDISNEY = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
response = requests.get(URL_WALTDISNEY)
soup = BeautifulSoup(response.text, "html.parser")

images_cont = soup.find_all('img')

source = ["https:"+images.get('src') for images in images_cont]
pprint(source)
# Out:
# ['https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg/220px-Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/15/Disney_drawing_goofy.jpg/170px-Disney_drawing_goofy.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/13/DisneySchiphol1951.jpg/220px-DisneySchiphol1951.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/WaltDisneyplansDisneylandDec1954.jpg/220px-WaltDisneyplansDisneylandDec1954.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Walt_disney_portrait_right.jpg/170px-Walt_disney_portrait_right.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Walt_Disney_Grave.JPG/170px-Walt_Disney_Grave.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Roy_O._Disney_with_Company_at_Press_Conference.jpg/170px-Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Disney_Display_Case.JPG/170px-Disney_Display_Case.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Disney1968.jpg/170px-Disney1968.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/The_Walt_Disney_Company_Logo.svg/120px-The_Walt_Disney_Company_Logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Animation_disc.svg/30px-Animation_disc.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/6/69/P_vip.svg/29px-P_vip.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Magic_Kingdom_castle.jpg/24px-Magic_Kingdom_castle.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Video-x-generic.svg/30px-Video-x-generic.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a3/Flag_of_Los_Angeles_County%2C_California.svg/30px-Flag_of_Los_Angeles_County%2C_California.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Blank_television_set.svg/30px-Blank_television_set.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/30px-Flag_of_the_United_States.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/22px-Commons-logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/25px-Wikiquote-logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/30px-Wikidata-logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  'https://en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1',
#  'https:/static/images/wikimedia-button.png',
#  'https:/static/images/poweredby_mediawiki_88x31.png']

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
URL_PYTHON ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
linksPython = []

response = requests.get(URL_PYTHON)
soup = BeautifulSoup(response.text, "html.parser")

links = soup.find_all('a')
linksPython = [link.get('href') for link in links]
print("These are all kind of links on this page: \n",linksPython)
# Out:
# These are all kind of links on this page:
#  [None, '#mw-head', '#p-search', 'https://en.wiktionary.org/wiki/Python', 'https://en.wiktionary.org/wiki/python', '#Snakes', '#Ancient_Greece', '#Media_and_entertainment', '#Computing', '#Engineering', '#Roller_coasters', '#Vehicles', '#Weaponry', '#People', '#Other_uses', '#See_also', '/w/index.php?title=Python&action=edit&section=1', '/wiki/Pythonidae', '/wiki/Python_(genus)', '/w/index.php?title=Python&action=edit&section=2', '/wiki/Python_(mythology)', '/wiki/Python_of_Aenus', '/wiki/Python_(painter)', '/wiki/Python_of_Byzantium', '/wiki/Python_of_Catana', '/w/index.php?title=Python&action=edit&section=3', '/wiki/Python_(film)', '/wiki/Pythons_2', '/wiki/Monty_Python', '/wiki/Python_(Monty)_Pictures', '/w/index.php?title=Python&action=edit&section=4', '/wiki/Python_(programming_language)', '/wiki/CPython', '/wiki/CMU_Common_Lisp', '/wiki/PERQ#PERQ_3', '/w/index.php?title=Python&action=edit&section=5', '/w/index.php?title=Python&action=edit&section=6', '/wiki/Python_(Busch_Gardens_Tampa_Bay)', '/wiki/Python_(Coney_Island,_Cincinnati,_Ohio)', '/wiki/Python_(Efteling)', '/w/index.php?title=Python&action=edit&section=7', '/wiki/Python_(automobile_maker)', '/wiki/Python_(Ford_prototype)', '/w/index.php?title=Python&action=edit&section=8', '/wiki/Colt_Python', '/wiki/Python_(missile)', '/wiki/Python_(nuclear_primary)', '/w/index.php?title=Python&action=edit&section=9', '/wiki/Python_Anghelo', '/w/index.php?title=Python&action=edit&section=10', '/wiki/PYTHON', '/w/index.php?title=Python&action=edit&section=11', '/wiki/Cython', '/wiki/Pyton', '/wiki/File:Disambig_gray.svg', '/wiki/Help:Disambiguation', 'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Python&namespace=0', 'https://en.wikipedia.org/w/index.php?title=Python&oldid=927409302', '/wiki/Help:Category', '/wiki/Category:Disambiguation_pages', '/wiki/Category:Disambiguation_pages_with_short_description', '/wiki/Category:All_article_disambiguation_pages', '/wiki/Category:All_disambiguation_pages', '/wiki/Category:Animal_common_name_disambiguation_pages', '/wiki/Special:MyTalk', '/wiki/Special:MyContributions', '/w/index.php?title=Special:CreateAccount&returnto=Python', '/w/index.php?title=Special:UserLogin&returnto=Python', '/wiki/Python', '/wiki/Talk:Python', '/wiki/Python', '/w/index.php?title=Python&action=edit', '/w/index.php?title=Python&action=history', '/wiki/Main_Page', '/wiki/Main_Page', '/wiki/Wikipedia:Contents', '/wiki/Portal:Featured_content', '/wiki/Portal:Current_events', '/wiki/Special:Random', 'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en', '//shop.wikimedia.org', '/wiki/Help:Contents', '/wiki/Wikipedia:About', '/wiki/Wikipedia:Community_portal', '/wiki/Special:RecentChanges', '//en.wikipedia.org/wiki/Wikipedia:Contact_us', '/wiki/Special:WhatLinksHere/Python', '/wiki/Special:RecentChangesLinked/Python', '/wiki/Wikipedia:File_Upload_Wizard', '/wiki/Special:SpecialPages', '/w/index.php?title=Python&oldid=927409302', '/w/index.php?title=Python&action=info', 'https://www.wikidata.org/wiki/Special:EntityPage/Q747452', '/w/index.php?title=Special:CiteThisPage&page=Python&id=927409302', 'https://commons.wikimedia.org/wiki/Category:Python', '/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Python', '/w/index.php?title=Special:ElectronPdf&page=Python&action=show-download-screen', '/w/index.php?title=Python&printable=yes', 'https://af.wikipedia.org/wiki/Python', 'https://als.wikipedia.org/wiki/Python', 'https://az.wikipedia.org/wiki/Python', 'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)', 'https://be.wikipedia.org/wiki/Python', 'https://bg.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%BF%D0%BE%D1%8F%D1%81%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5)', 'https://cs.wikipedia.org/w ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
URL_CODE = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
count_codes = 0
input_codes = []

response = requests.get(URL_CODE)
soup = BeautifulSoup(response.text, "html.parser")

#print(soup)
uscitem_container = soup.find_all('div', {'class', 'uscitem'})#
#pprint(uscitem_container[:4])

for index, uscitem in enumerate(uscitem_container):
    #print(uscitem.text.find('Appendix'))
    if (index != 0 and uscitem.text.find('Appendix') == -1): #reject first item and all with text containing "Appendix"
        input_codes.append(uscitem.text.replace('\n','').replace('[XML]\xa0[XHTML]\xa0[PCC]\xa0[PDF]','').replace('[XML]\xa0','').replace('116-21',''))
        count_codes += 1
    
print("The total number of versions is ",count_codes)
pprint(input_codes[:9])
# Out:
# The total number of versions is  54
# ['          Title 1 - General Provisions ٭          116-68u1        ',
#  '          Title 2 - The Congress                  116-68u1        ',
#  '          Title 3 - The President ٭          116-68u1        ',
#  '          Title 4 - Flag and Seal, Seat of Government, and the States '
#  '٭          116-68u1        ',
#  '          Title 5 - Government Organization and Employees ٭          '
#  '116-68u1        ',
#  '          Title 6 - Domestic Security                  116-68u1        ',
#  '          Title 7 - Agriculture                  116-68u1        ',
#  '          Title 8 - Aliens and Nationality                  116-68u1        ',
#  '          Title 9 - Arbitration ٭          116-68u1        ']

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
URL_FBI = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
response = requests.get(URL_FBI)
soup = BeautifulSoup(response.text, "html.parser")

#print(soup)
wanted_container = soup.find_all('li', {'class', 'portal-type-person castle-grid-block-item'})#

items = [lines.find('h3', {'class','title'}) for lines in wanted_container]
list_of_wanteds = [wanted.text.replace('\n','') for wanted in items]

print("Top 10 most FBI wanted:\n", list_of_wanteds)
# Out:
# Top 10 most FBI wanted:
#  ['ALEJANDRO ROSALES CASTILLO', 'YASER ABDEL SAID', 'JASON DEREK BROWN', 'ALEXIS FLORES', 'EUGENE PALMER', 'SANTIAGO VILLALBA MEDEROS', 'RAFAEL CARO-QUINTERO', 'ROBERT WILLIAM FISHER', 'BHADRESHKUMAR CHETANBHAI PATEL', 'ARNOLDO JIMENEZ']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
URL_EARTHQUAKE = 'https://www.emsc-csem.org/Earthquake/'

# %%
# data is where the final information will be store
#Every td label has a datum, some positions are useful (3,4,6 and 11)
#Thus, we have to jump 13 positions till next useful datums
#jump allow to jump till the correct index, and them record the datum

data = []
temp = []
jump = 0
    
response = requests.get(URL_EARTHQUAKE)
soup = BeautifulSoup(response.text, 'html.parser')
container = soup.find('tbody',{'id':'tbody'})

readings = container.find_all('td') 

for index,reading in enumerate(readings):
    if(index == 3+jump):
        temp.append(reading.text[10:20])
        temp.append(reading.text[23:31])
    if(index == 4+jump):
        temp.append(reading.text.replace('\xa0',''))
    if(index == 6+jump):
        temp.append(reading.text.replace('\xa0',''))
    if(index == 11+jump):   
        temp.append(reading.text.replace('\xa0',''))
        jump+=13
        data.append(temp[0:5])
        temp = []

earthquake_df = pd.DataFrame(data, columns=['Date', 'Time', 'Lat', 'Long', 'Region'])
earthquake_df.head(20)
# Out:
#           Date      Time    Lat    Long                            Region
# 0   2019-11-30  16:20:39  66.33  157.47                   NORTHERN ALASKA
# 1   2019-11-30  16:10:24  31.80   71.32                   COQUIMBO, CHILE
# 2   2019-11-30  16:04:08  41.54   19.53                           ALBANIA
# 3   2019-11-30  15:33:25  29.86   71.67          OFFSHORE COQUIMBO, CHILE
# 4   2019-11-30  15:29:55  38.81   27.19                    WESTERN TURKEY
# 5   2019-11-30  15:17:12  16.86   96.57                    OAXACA, MEXICO
# 6   2019-11-30  15:10:15  36.10  117.85                CENTRAL CALIFORNIA
# 7   2019-11-30  15:06:23  36.10  117.86                CENTRAL CALIFORNIA
# 8   2019-11-30  14:50:10  34.80   71.87       LIBERTADOR O'HIGGINS, CHILE
# 9   2019-11-30  14:46:18  31.52   71.65          OFFSHORE COQUIMBO, CHILE
# 10  2019-11-30  14:16:44  42.43   13.17                     CENTRAL ITALY
# 11  2019-11-30  14:11:56  39.32   20.85                            GREECE
# 12  2019-11-30  14:05:36  40.06  144.45            BASS STRAIT, AUSTRALIA
# 13  2019-11-30  13:29:04  34.97  119.43                CENTRAL CALIFORNIA
# 14  2019-11-30  12:54:38  35.99   23.02                     CRETE, GREECE
# 15  2019-11-30  12:39:31  21.15   69.02                   TARAPACA, CHILE
# 16  2019-11-30  12:19:28  41.48   19.51                      ADRIATIC SEA
# 17  2019-11-30  12:11:55  59.75  152.54                   SOUTHERN ALASKA
# 18  2019-11-30  11:33:48   1.24  134.31  NEAR N COAST OF PAPUA, INDONESIA
# 19  2019-11-30  11:16:16  42.80   13.10                     CENTRAL ITALY

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
URL_HACKATHON ='https://hackevents.co/hackathons'
URL_CONSTRUCTOR = 'https://hackevents.co'

# %%
# All nesserary information about events should be gathered from the links of the events
# Thus, we find the lines that start with "/event", them we get the link stored in the label
# href in order to build the correct url adding the URL_CONSTRUCTOR (the root url)
# Them we have to interate through the correct links, and get the data

data = []
links = []
    
response = requests.get(URL_HACKATHON)
soup = BeautifulSoup(response.text, 'html.parser')
containers = soup.find_all('a')

# loop to get the links for all events
for container in containers:
    if (container.get('href')[0:6] == '/event'):
        links.append(URL_CONSTRUCTOR + container.get('href'))

# loop to scrap every event page
for link in links:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    container = soup.find('div',{'class','row'})

    #title
    title = container.find('h2').text
    
    #the rest of the datums
    datums = container.find_all('p')
    
    city = datums[0].text.replace('\u2003 ','').split(',')[0]        
    country = datums[0].text.replace('\u2003 ','').split(',')[2] 
    start_date = datums[1].text.split(' ')[-1]
    start_day = int(start_date.split('/')[1])

    end_date = datums[2].text.split(' ')[-1] 
    end_day = int(end_date.split('/')[1])
    gape = end_day - start_day
    days = [start_day+day for day in range(gape+1)]
    
    data.append([start_day,days,title,city,country])

hackathons_df = pd.DataFrame(data, columns=['start_day', 'days', 'title', 'city', 'country'])
hackathons_df.head(25)
# Out:
# Empty DataFrame
# Columns: [start_day, days, title, city, country]
# Index: []

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
URL_TWITTER_CONSTRUCTOR = 'https://twitter.com/'

# %%
import tweepy
import twitter

from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from twitter import Twitter, OAuth
from tweepy import OAuthHandler

# Authentication
key = '77IFGcGHEKVTjFt2AF5tDs3nF'
key_secret = '1uUq6LKES6MsZr7UMWrSCfuKhdC0M458ec47CnJ5YpOoQ0BRTH'
token = '1180090135372861442-9YMk9w6MY55AgvjJqn0pLraGJzNguR'
token_secret = '6VjEEFQZvjixJ34bpVo8r6NcWYmHBqtrhM5EwI7AAfVG5'
 
auth = OAuthHandler(key, key_secret)
auth.set_access_token(token, token_secret)
api = tweepy.API(auth)

# Read tweets from user
name = 'cordeiro'

count=0

# Using "Cursor" we can reed more than 200 tweets, the limit 3200
try:
    for tweet in tweepy.Cursor(api.user_timeline, id=name).items():
        #print(tweet.text,"\n")
        count+=1
    print("Total tweets:", count)
    
except:
    print("An exception occurred. The user does not exist")
# Out:
# Total tweets: 1165

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
import tweepy
import twitter

from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from twitter import Twitter, OAuth
from tweepy import OAuthHandler


# Authentication
key = '77IFGcGHEKVTjFt2AF5tDs3nF'
key_secret = '1uUq6LKES6MsZr7UMWrSCfuKhdC0M458ec47CnJ5YpOoQ0BRTH'
token = '1180090135372861442-9YMk9w6MY55AgvjJqn0pLraGJzNguR'
token_secret = '6VjEEFQZvjixJ34bpVo8r6NcWYmHBqtrhM5EwI7AAfVG5'
 
auth = OAuthHandler(key, key_secret)
auth.set_access_token(token, token_secret)
api = tweepy.API(auth)

# target to be check
account = 'cordeiro'

ids = []

# Using "Cursor" we can reed more than 200 tweets, the limit 3200
try:
    for page in api.followers_ids(screen_name=account):
        ids.append(page)

    print("Total folowers:", len(ids))
    
except:
    print("An exception occurred. The user does not exist")
# Out:
# Total folowers: 3121

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
URL_WIKIPEDIA = 'https://www.wikipedia.org/'

# %%
#your code
# All nesserary information about events should be gathered from the links of the events
# Thus, we find the lines that start with "/event", them we get the link stored in the label
# href in order to build the correct url adding the URL_CONSTRUCTOR (the root url)
# Them we have to interate through the correct links, and get the data

data = []
links = []
    
response = requests.get(URL_WIKIPEDIA)
soup = BeautifulSoup(response.text, 'html.parser')

#container = soup.find_all('div',{'class','central-featured'})
container = soup.find_all('a',{'class','link-box'})

for item in container:
    language=item.find("strong")
    print(language.text)
    article=item.find("small")
    pos=article.text.find('+')
    print(article.text[:pos])
# Out:
# English
# 5 964 000
# EspaÃ±ol
# 1 554 000
# æ¥æ¬èª
# 1 175 000
# Deutsch
# 2 361 000
# Ð ÑÑÑÐºÐ¸Ð¹
# 1 576 000
# FranÃ§ais
# 2 152 000
# Italiano
# 1 562 000
# ä¸­æ
# 1 080 000
# PortuguÃªs
# 1 014 000
# Polski
# 1 367 000

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
URL_DATAGOVUK = 'https://data.gov.uk'

# %%
#your code 
data = []
links = []

response = requests.get(URL_DATAGOVUK)
soup = BeautifulSoup(response.text, 'html.parser')

container = soup.find_all('div',{'class','column-one-third'})

# There are three "column-one-third", so we go through and concatenate with extend to have a one dimension list
for index, item in enumerate(container):
    data.extend(item.find_all('a'))

links = [URL_DATAGOVUK+item.get('href') for item in data]

pprint(links)
# Out:
# ['https://data.gov.uk/search?filters%5Btopic%5D=Business+and+economy',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Crime+and+justice',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Defence',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Education',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Environment',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Government',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Government+spending',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Health',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Mapping',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Society',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Towns+and+cities',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Transport']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
URL_SPEAKERS = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code 
data = []
links = []

response = requests.get(URL_SPEAKERS)
soup = BeautifulSoup(response.text, 'html.parser')

container = soup.find_all('tbody')

data = []
data = [item.find_all('a') for item in container]

# Find languages and avoid to get the language family
forget = ['languages','Varieties']
languages = [item.text for item in data[0] \
    if ((str(item.get('href')).find('languages') == -1) \
    and (str(item.get('href')).find('Varieties') == -1) \
    and (str(item.get('href')).find('#') == -1) )]

pprint(languages)
# Out:
# ['Mandarin Chinese',
#  'Spanish',
#  'English',
#  'Hindi',
#  'Hindustani',
#  'Bengali',
#  'Portuguese',
#  'Russian',
#  'Japanese',
#  'Japanese',
#  'Western Punjabi',
#  'Marathi',
#  'Telugu',
#  'Wu Chinese',
#  'Turkish',
#  'Korean',
#  'language isolate',
#  'French',
#  'German',
#  'Vietnamese',
#  'Tamil',
#  'Yue Chinese',
#  'Urdu',
#  'Hindustani',
#  'Javanese',
#  'Italian',
#  'Egyptian Arabic',
#  'Gujarati',
#  'Iranian Persian',
#  'Bhojpuri',
#  'Min Nan Chinese',
#  'Hakka Chinese',
#  'Jin Chinese',
#  'Hausa',
#  'Kannada',
#  'Indonesian',
#  'Malay',
#  'Polish',
#  'Yoruba',
#  'Xiang Chinese',
#  'Malayalam',
#  'Odia',
#  'Maithili',
#  'Burmese',
#  'Eastern Punjabi',
#  'Sunda',
#  'Sudanese Arabic',
#  'Algerian Arabic',
#  'Moroccan Arabic',
#  'Ukrainian',
#  'Igbo',
#  'Northern Uzbek',
#  'Sindhi',
#  'North Levantine Arabic',
#  'Romanian',
#  'Tagalog',
#  'Dutch',
#  'Saʽidi Arabic',
#  'Gan Chinese',
#  'Amharic',
#  'Northern Pashto',
#  'Magahi',
#  'Thai',
#  'Saraiki',
#  'Khmer',
#  'Khmer',
#  'Chhattisgarhi',
#  'Somali',
#  'Malay',
#  'Malay',
#  'Cebuano',
#  'Nepali',
#  'Mesopotamian Arabic',
#  'Assamese',
#  'Sinhala',
#  'Northern Kurdish',
#  'Hejazi Arabic',
#  'Nigerian Fulfulde',
#  'Bavarian',
#  'Greek',
#  'Chittagonian',
#  'Kazakh',
#  'Deccan',
#  'Hungarian',
#  'Kinyarwanda',
#  'Zulu',
#  'South Levantine Arabic',
#  'Tunisian Arabic',
#  'Sanaani Spoken Arabic',
#  'Min Bei Chinese',
#  'Southern Pashto',
#  'Rundi',
#  'Czech',
#  'Taʽizzi-Adeni Arabic',
#  'Uyghur',
#  'Min Dong Chinese',
#  'Sylheti']

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
URL_TWITTER = 'https://twitter.com/'
username = 'cordeiro'

# %%
import requests
import sys
import json

#your code 
data = []
links = []

response = requests.get(URL_TWITTER+username)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
pprint(soup)
# Out:
# <!DOCTYPE html>
#
# <html data-scribe-reduced-action-queue="true" lang="es">
# <head>
# <meta charset="utf-8"/>
# <script nonce="ZuApFPfHDHKqhxut9asWAA==">
#         !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#       </script>
# <script id="bouncer_terminate_iframe" nonce="ZuApFPfHDHKqhxut9asWAA==">
#     if (window.top != window) {
#   window.top.postMessage({'bouncer': true, 'event': 'complete'}, '*');
# }
#   </script>
# <script id="swift_action_queue" nonce="ZuApFPfHDHKqhxut9asWAA==">
#     !function(){function e(e){if(e||(e=window.event),!e)return!1;if(e.timestamp=(new Date).getTime(),!e.target&&e.srcElement&&(e.target=e.srcElement),document.documentElement.getAttribute("data-scribe-reduced-action-queue"))for(var t=e.target;t&&t!=document.body;){if("A"==t.tagName)return;t=t.parentNode}return i("all",o(e)),a(e)?(document.addEventListener||(e=o(e)),e.preventDefault=e.stopPropagation=e.stopImmediatePropagation=function(){},y?(v.push(e),i("captured",e)):i("ignored",e),!1):(i("direct",e),!0)}function t(e){n();for(var t,r=0;t=v[r];r++){var a=e(t.target),i=a.closest("a")[0];if("click"==t.type&&i){var o=e.data(i,"events"),u=o&&o.click,c=!i.hostname.match(g)||!i.href.match(/#$/);if(!u&&c){window.location=i.href;continue}}a.trigger(e.event.fix(t))}window.swiftActionQueue.wasFlushed=!0}function r(){for(var e in b)if("all"!=e)for(var t=b[e],r=0;r<t.length;r++)console.log("actionQueue",c(t[r]))}function n(){clearTimeout(w);for(var e,t=0;e=h[t];t++)document["on"+e]=null}function a(e){if(!e.target)return!1;var t=e.target,r=(t.tagName||"").toLowerCase();if(e.metaKey)return!1;if(e.shiftKey&&"a"==r)return!1;if(t.hostname&&!t.hostname.match(g))return!1;if(e.type.match(p)&&s(t))return!1;if("label"==r){var n=t.getAttribute("for");if(n){var a=document.getElementById(n);if(a&&f(a))return!1}else for(var i,o=0;i=t.childNodes[o];o++)if(f(i))return!1}return!0}function i(e,t){t.bucket=e,b[e].push(t)}function o(e){var t={};for(var r in e)t[r]=e[r];return t}function u(e){for(;e&&e!=document.body;){if("A"==e.tagName)return e;e=e.parentNode}}function c(e){var t=[];e.bucket&&t.push("["+e.bucket+"]"),t.push(e.type);var r,n,a=e.target,i=u(a),o="",c=e.timestamp&&e.timestamp-d;return"click"===e.type&&i?(r=i.className.trim().replace(/\s+/g,"."),n=i.id.trim(),o=/[^#]$/.test(i.href)?" ("+i.href+")":"",a='"'+i.innerText.replace(/\n+/g," ").trim()+'"'):(r=a.className.trim().replace(/\s+/g,"."),n=a.id.trim(),a=a.tagName.toLowerCase(),e.keyCode&&(a=String.fromCharCode(e.keyCode)+" : "+a)),t.push(a+o+(n&&"#"+n)+(!n&&r?"."+r:"")),c&&t.push(c),t.join(" ")}function f(e){var t=(e.tagName||"").toLowerCase();return"input"==t&&"checkbox"==e.getAttribute("type")}function s(e){var t=(e.tagName||"").toLowerCase();return"textarea"==t||"input"==t&&"text"==e.getAttribute("type")||"true"==e.getAttribute("contenteditable")}for(var m,d=(new Date).getTime(),l=1e4,g=/^([^\.]+\.)*twitter\.com$/,p=/^key/,h=["click","keydown","keypress","keyup"],v=[],w=null,y=!0,b={captured:[],ignored:[],direct:[],all:[]},k=0;m=h[k];k++)document["on"+m]=e;w=setTimeout(function(){y=!1},l),window.swiftActionQueue={buckets:b,flush:t,logActions:r,wasFlushed:!1}}();
#   </script>
# <script id="composition_state" nonce="ZuApFPfHDHKqhxut9asWAA==">
#     !function(){function t(t){t.target.setAttribute("data-in-composition","true")}function n(t){t.target.removeAttribute("data-in-composition")}document.addEventListener&&(document.addEventListener("compositionstart",t,!1),document.addEventListener("compositionend",n,!1))}();
#   </script>
# <link class="coreCSSBundles" href="https://abs.twimg.com/a/1574716928/css/t1/twitter_core.bundle.css" rel="stylesheet"/>
# <link class="moreCSSBundles" href="https://abs.twimg.com/a/1574716928/css/t1/twitter_more_1.bundle.css" rel="stylesheet"/>
# <link class="moreCSSBundles" href="https://abs.twimg.com/a/1574716928/css/t1/twitter_more_2.bundle.css" rel="stylesheet"/>
# <link href="https://pbs.twimg.com" rel="dns-prefetch"/>
# <link href="https://t.co" rel="dns-prefetch"/>
# <link as="script" href="https://abs.twimg.com/k/es/init.es.60f58fd3186b2e398094.js" rel="preload"/>
# <link as="script" href="https://abs.twimg.com/k/es/0.commons.es.db1356329b6e4ff88e45.js" rel="preload"/>
# <link as="script" href="https://abs.twimg.com/k/es/3.pages_profile.es.5c0fc4b2aa1c615d5f5c.js" rel="preload"/>
# <title>JoséCordeiro (@cordeiro) | Twitter</title>
# <meta content="NOODP" name="robots"/>
# <meta content="Los Tweets más recientes de JoséCordeiro (@cordeiro). Candidato #EuroLatino al Parlamento Europeo por @SomosMiel2019. Ciudadano del Mundo" name="description"/>
# <meta content="//abs.twimg.com/favicons/win8-tile-144.png" name="msapplication-TileImage">
# <meta content="#00aced" name="msapplication-TileColor">
# <link color="#1da1f2" href="https://abs.twimg.com/a/1574716928/icons/favicon.svg" rel="mask-icon" sizes="any"/>
# <link href="//abs.twimg.com/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://abs.twimg.com/icons/apple-touch-icon-192x192.png" rel="apple-touch-icon" sizes="192x192"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="profile" id="swift-page-name" name="swift-page-name"/>
# <meta content="profile" id="swift-section-name" name="swift-page-section"/>
# <link href="https://twitter.com/cordeiro" rel="canonical"/>
# <link href="https://twitter.com/cordeiro" hreflang="x-default" rel="alternate"/>
# <link href="https://twitter.com/cordeiro?lang=fr" hreflang="fr" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=en" hreflang="en" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=ar" hreflang="ar" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=ja" hreflang="ja" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=es" hreflang="es" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=de" hreflang="de" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=it" hreflang="it" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=id" hreflang="id" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=pt" hreflang="pt" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=ko" hreflang="ko" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=tr" hreflang="tr" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=ru" hreflang="ru" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=nl" hreflang="nl" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=fil" hreflang="fil" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=ms" hreflang="ms" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=zh-tw" hreflang="zh-tw" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=zh-cn" hreflang="zh-cn" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=hi" hreflang="hi" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=no" hreflang="no" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=sv" hreflang="sv" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=fi" hreflang="fi" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=da" hreflang="da" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=pl" hreflang="pl" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=hu" hreflang="hu" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=fa" hreflang="fa" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=he" hreflang="he" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=ur" hreflang="ur" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=th" hreflang="th" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=uk" hreflang="uk" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=ca" hreflang="ca" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=ga" hreflang="ga" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=el" hreflang="el" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=eu" hreflang="eu" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=cs" hreflang="cs" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=gl" hreflang="gl" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=ro" hreflang="ro" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=hr" hreflang="hr" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=en-gb" hreflang="en-gb" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=vi" hreflang="vi" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=bn" hreflang="bn" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=bg" hreflang="bg" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=sr" hreflang="sr" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=sk" hreflang="sk" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=gu" hreflang="gu" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=mr" hreflang="mr" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=ta" hreflang="ta" rel="alternate"/><link href="https://twitter.com/cordeiro?lang=kn" hreflang="kn" rel="alternate"/>
# <link href="https://publish.twitter.com/oembed?url=https://twitter.com/cordeiro" rel="alternate" title="JoséCordeiro (@cordeiro) | Twitter" type="application/json+oembed"/>
# <link href="https://mobile.twitter.com/cordeiro" media="handheld, only screen and (max-width: 640px)" rel="alternate"/>
# <link href="android-app://com.twitter.android/twitter/user?screen_name=cordeiro&amp;ref_src=twsrc%5Egoogle%7Ctwcamp%5Eandroidseo%7Ctwgr%5Eprofile" rel="alternate"/>
# <link href="/opensearch.xml" rel="search" title="Twitter" type="application/opensearchdescription+xml"/>
# <link id="async-css-placeholder"/>
# <meta content="twitter://user?screen_name=cordeiro" property="al:ios:url"/>
# <meta content="333903271" property="al:ios:app_store_id"/>
# <meta content="Twitter" property="al:ios:app_name"/>
# <meta content="twitter://user?screen_name=cordeiro" property="al:android:url"/>
# <meta content="com.twitter.android" property="al:android:package"/>
# <meta content="Twitter" property="al:android:app_name"/>
# </meta></meta></head>
# <body class="three-col logged-out user-style-cordeiro western es enhanced-mini-profile ProfilePage ProfilePage--withWarning" data-fouc-class-names="swift-loading" dir="ltr">
# <script id="swift_loading_indicator" nonce="ZuApFPfHDHKqhxut9asWAA==">
#         document.body.className=document.body.className+" "+document.body.getAttribute("data-fouc-class-names");
#       </script>
# <noscript>
# <form action="https://mobile.twitter.com/i/nojs_router?path=%2Fcordeiro" class="NoScriptForm" method="POST">
# <input name="authenticity_token" type="hidden" value="786d2c6a824242172cdaccc26e65a5cd3d1b10c1"/>
# <div class="NoScriptForm-content">
# <span class="NoScriptForm-logo Icon Icon--logo Icon--extraLarge"></span>
# <p>Detectamos que JavaScript está desactivado en tu navegador. ¿Quieres continuar con la versión antigua de Twitter?</p>
# <p class="NoScriptForm-buttonContainer"><button class="EdgeButton EdgeButton--primary" type="submit">Sí</button></p>
# </div>
# </form>
# </noscript>
# <a class="u-hiddenVisually focusable" href="#timeline">Saltar al contenido</a>
# <div class="route-profile" data-at-shortcutkeys='{"Enter":"Abrir detalles del Tweet","o":"Expandir foto","/":"Buscar","?":"Este men\u00fa","j":"Siguiente Tweet","k":"Tweet anterior","Space":"Desplazar hacia abajo",".":"Cargar Tweets nuevos","gu":"Ir al usuario\u2026"}' id="doc">
# <div class="topbar js-topbar">
# <div class="js-banners" id="banners">
# <div class="Banner Banner--aboveNav eu-cookie-notice">
# <div class="Banner-contentContainer">
# <div class="Banner-textContent">
#       Al usar los servicios de Twitter, aceptas nuestra política de <a href="https://help.twitter.com/rules-and-policies/twitter-cookies" rel="noopener">uso de cookies</a>. Twitter y sus socios operan a nivel global y utilizan cookies para análisis, personalización y anuncios, entre otras cosas.
#     </div>
# <div class="Banner-actions">
# <button type="button"><span class="Icon Icon--close"><span class="visuallyhidden">Cerrar</span></span></button>
# </div>
# </div>
# </div>
# </div>
# <div class="global-nav global-nav--newLoggedOut" data-section-term="top_nav">
# <div class="global-nav-inner">
# <div class="container">
# <ul class="nav js-global-actions" id="global-actions" role="navigation">
# <li class="home" data-global-action="home" id="global-nav-home">
# <a class="js-nav js-tooltip js-dynamic-tooltip" data-component-context="home_nav" data-nav="home" data-placement="bottom" href="/">
# <span class="Icon Icon--bird Icon--large"></span>
# <span aria-hidden="true" class="text">Inicio</span>
# <span class="u-hiddenVisually a11y-inactive-page-text">Inicio</span>
# <span class="u-hiddenVisually a11y-active-page-text">Inicio, página actual.</span>
# </a>
# </li>
# <li class="moments" data-global-action="moments" id="global-nav-moments">
# <a class="js-nav js-tooltip js-dynamic-tooltip" data-component-context="moments_nav" data-nav="moments" data-placement="bottom" href="/i/moments">
# <span class="Icon Icon--lightning Icon--large"></span>
# <span class="Icon Icon--lightningFilled Icon--large"></span>
# <span aria-hidden="true" class="text">Momentos</span>
# <span class="u-hiddenVisually a11y-inactive-page-text">Momentos</span>
# <span class="u-hiddenVisually a11y-active-page-text">Momentos, página actual.</span>
# </a>
# </li>
# </ul>
# <div class="pull-right nav-extras">
# <div role="search">
# <form action="/search" class="t1-form form-search js-search-form" id="global-nav-search">
# <label class="visuallyhidden" for="search-query">Consulta de búsqueda</label>
# <input autocomplete="off" class="search-input" id="search-query" name="q" placeholder="Buscar en Twitter" spellcheck="false" type="text"/>
# <span class="search-icon js-search-action">
# <button class="Icon Icon--medium Icon--search nav-search" type="submit">
# <span class="visuallyhidden">Buscar en Twitter</span>
# </button>
# </span>
# <div class="dropdown-menu typeahead" role="listbox">
# <div aria-hidden="true" class="dropdown-caret">
# <div class="caret-outer"></div>
# <div class="caret-inner"></div>
# </div>
# <div class="dropdown-inner js-typeahead-results" role="presentation">
# <div class="typeahead-saved-searches" role="presentation">
# <h3 class="typeahead-category-title saved-searches-title" id="saved-searches-heading">Búsquedas guardadas</h3>
# <ul class="typeahead-items saved-searches-list" role="presentation">
# <li class="typeahead-item typeahead-saved-search-item" role="presentation">
# <span aria-hidden="true" class="Icon Icon--close"><span class="visuallyhidden">Eliminar</span></span>
# <a aria-describedby="saved-searches-heading" class="js-nav" data-ds="saved_search" data-query-source="" data-search-query="" href="" role="option" tabindex="-1"></a>
# </li>
# </ul>
# </div>
# <ul class="typeahead-items typeahead-topics" role="presentation">
# <li class="typeahead-item typeahead-topic-item" role="presentation">
# <a class="js-nav" data-ds="topics" data-query-source="typeahead_click" data-search-query="" href="" role="option" tabindex="-1"></a>
# </li>
# </ul>
# <ul class="typeahead-items typeahead-accounts social-context js-typeahead-accounts" role="presentation">
# <li class="typeahead-item typeahead-account-item js-selectable" data-remote="true" data-score="" data-user-id="" data-user-screenname="" role="presentation">
# <a class="js-nav" data-ds="account" data-query-source="typeahead_click" data-search-query="" role="option">
# <div class="js-selectable typeahead-in-conversation hidden">
# <span class="Icon Icon--follower Icon--small"></span>
# <span class="typeahead-in-conversation-text">En esta conversación</span>
# </div>
# <img alt="" class="avatar size32"/>
# <span class="typeahead-user-item-info account-group">
# <span class="fullname"></span><span class="UserBadges"><span class="Icon Icon--verified js-verified hidden"><span class="u-hiddenVisually">Cuenta verificada</span></span><span class="Icon Icon--protected js-protected hidden"><span class="u-hiddenVisually">Tweets Protegidos</span></span></span><span class="UserNameBreak"> </span><span class="username u-dir" dir="ltr">@<b></b></span>
# </span>
# <span class="typeahead-social-context"></span>
# </a>
# </li>
# <li class="js-selectable typeahead-accounts-shortcut js-shortcut" role="presentation"><a class="js-nav" data-ds="account_search" data-query-source="typeahead_click" data-search-query="" data-shortcut="true" href="" role="option"></a></li>
# </ul>
# <ul class="typeahead-items typeahead-trend-locations-list" role="presentation">
# <li class="typeahead-item typeahead-trend-locations-item" role="presentation"><a class="js-nav" data-ds="trend_location" data-search-query="" href="" role="option" tabindex="-1"></a></li>
# </ul>
# <div class="typeahead-user-select" role="presentation">
# <div class="typeahead-empty-suggestions" role="presentation">
#     Usuarios recomendados
#   </div>
# <ul class="typeahead-items typeahead-selected js-typeahead-selected" role="presentation">
# <li class="typeahead-item typeahead-selected-item js-selectable" data-remote="true" data-score="" data-user-id="" data-user-screenname="" role="presentation">
# <a class="js-nav" data-ds="account" data-query-source="typeahead_click" data-search-query="" role="option">
# <img alt="" class="avatar size32"/>
# <span class="typeahead-user-item-info account-group">
# <span class="select-status deselect-user js-deselect-user Icon Icon--check"></span>
# <span class="select-status select-disabled Icon Icon--unfollow"></span>
# <span class="fullname"></span><span class="UserBadges"><span class="Icon Icon--verified js-verified hidden"><span class="u-hiddenVisually">Cuenta verificada</span></span><span class="Icon Icon--protected js-protected hidden"><span class="u-hiddenVisually">Tweets Protegidos</span></span></span><span class="UserNameBreak"> </span><span class="username u-dir" dir="ltr">@<b></b></span>
# </span>
# </a>
# </li>
# <li class="typeahead-selected-end" role="presentation"></li>
# </ul>
# <ul class="typeahead-items typeahead-accounts js-typeahead-accounts" role="presentation">
# <li class="typeahead-item typeahead-account-item js-selectable" data-remote="true" data-score="" data-user-id="" data-user-screenname="" role="presentation">
# <a class="js-nav" data-ds="account" data-query-source="typeahead_click" data-search-query="" role="option">
# <img alt="" class="avatar size32"/>
# <span class="typeahead-user-item-info account-group">
# <span class="select-status deselect-user js-deselect-user Icon Icon--check"></span>
# <span class="select-status select-disabled Icon Icon--unfollow"></span>
# <span class="fullname"></span><span class="UserBadges"><span class="Icon Icon--verified js-verified hidden"><span class="u-hiddenVisually">Cuenta verificada</span></span><span class="Icon Icon--protected js-protected hidden"><span class="u-hiddenVisually">Tweets Protegidos</span></span></span><span class="UserNameBreak"> </span><span class="username u-dir" dir="ltr">@<b></b></span>
# </span>
# </a>
# </li>
# <li class="typeahead-accounts-end" role="presentation"></li>
# </ul>
# </div>
# <div class="typeahead-dm-conversations" role="presentation">
# <ul class="typeahead-items typeahead-dm-conversation-items" role="presentation">
# <li class="typeahead-item typeahead-dm-conversation-item" role="presentation">
# <a role="option" tabindex="-1"></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </form>
# </div>
# <ul class="nav secondary-nav language-dropdown">
# <li class="dropdown js-language-dropdown">
# <a class="dropdown-toggle js-dropdown-toggle" href="#supported_languages">
# <small>Idioma:</small> <span class="js-current-language">Español</span> <b class="caret"></b>
# </a>
# <div class="dropdown-menu dropdown-menu--rightAlign is-forceRight">
# <div class="dropdown-caret right">
# <span class="caret-outer"> </span>
# <span class="caret-inner"></span>
# </div>
# <ul id="supported_languages">
# <li><a class="js-language-link js-tooltip" data-lang-code="id" href="?lang=id" rel="noopener" title="indonesio">Bahasa Indonesia</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="msa" href="?lang=msa" rel="noopener" title="malayo">Bahasa Melayu</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="ca" href="?lang=ca" rel="noopener" title="catalán">Català</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="cs" href="?lang=cs" rel="noopener" title="checo">Čeština</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="da" href="?lang=da" rel="noopener" title="danés">Dansk</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="de" href="?lang=de" rel="noopener" title="alemán">Deutsch</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="en" href="?lang=en" rel="noopener" title="inglés">English</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="en-gb" href="?lang=en-gb" rel="noopener" title="inglés británico">English UK</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="fil" href="?lang=fil" rel="noopener" title="filipino">Filipino</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="fr" href="?lang=fr" rel="noopener" title="francés">Français</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="hr" href="?lang=hr" rel="noopener" title="croata">Hrvatski</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="it" href="?lang=it" rel="noopener" title="italiano">Italiano</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="hu" href="?lang=hu" rel="noopener" title="húngaro">Magyar</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="nl" href="?lang=nl" rel="noopener" title="neerlandés">Nederlands</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="no" href="?lang=no" rel="noopener" title="noruego">Norsk</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="pl" href="?lang=pl" rel="noopener" title="polaco">Polski</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="pt" href="?lang=pt" rel="noopener" title="portugués">Português</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="ro" href="?lang=ro" rel="noopener" title="rumano">Română</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="sk" href="?lang=sk" rel="noopener" title="eslovaco">Slovenčina</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="fi" href="?lang=fi" rel="noopener" title="finés">Suomi</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="sv" href="?lang=sv" rel="noopener" title="sueco">Svenska</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="vi" href="?lang=vi" rel="noopener" title="vietnamita">Tiếng Việt</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="tr" href="?lang=tr" rel="noopener" title="turco">Türkçe</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="el" href="?lang=el" rel="noopener" title="griego">Ελληνικά</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="bg" href="?lang=bg" rel="noopener" title="búlgaro">Български език</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="ru" href="?lang=ru" rel="noopener" title="ruso">Русский</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="sr" href="?lang=sr" rel="noopener" title="serbio">Српски</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="uk" href="?lang=uk" rel="noopener" title="ucraniano">Українська мова</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="he" href="?lang=he" rel="noopener" title="hebreo">עִבְרִית</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="ar" href="?lang=ar" rel="noopener" title="árabe">العربية</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="fa" href="?lang=fa" rel="noopener" title="persa">فارسی</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="mr" href="?lang=mr" rel="noopener" title="maratí">मराठी</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="hi" href="?lang=hi" rel="noopener" title="hindi">हिन्दी</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="bn" href="?lang=bn" rel="noopener" title="bengalí">বাংলা</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="gu" href="?lang=gu" rel="noopener" title="guyaratí">ગુજરાતી</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="ta" href="?lang=ta" rel="noopener" title="tamil">தமிழ்</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="kn" href="?lang=kn" rel="noopener" title="canarés">ಕನ್ನಡ</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="th" href="?lang=th" rel="noopener" title="tailandés">ภาษาไทย</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="ko" href="?lang=ko" rel="noopener" title="coreano">한국어</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="ja" href="?lang=ja" rel="noopener" title="japonés">日本語</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="zh-cn" href="?lang=zh-cn" rel="noopener" title="chino simplificado">简体中文</a></li>
# <li><a class="js-language-link js-tooltip" data-lang-code="zh-tw" href="?lang=zh-tw" rel="noopener" title="chino tradicional">繁體中文</a></li>
# </ul>
# </div>
# <div class="js-front-language">
# <form action="/sessions/change_locale" class="t1-form language" method="POST">
# <input name="lang" type="hidden"/> <input name="redirect" type="hidden"/>
# <input name="authenticity_token" type="hidden" value="786d2c6a824242172cdaccc26e65a5cd3d1b10c1"/>
# </form>
# </div>
# </li>
# </ul>
# <ul class="nav secondary-nav session-dropdown" id="session">
# <li class="dropdown js-session">
# <a class="dropdown-toggle js-dropdown-toggle dropdown-signin" data-nav="login" href="/login" id="signin-link" role="button">
# <small>¿Tienes cuenta?</small> <span class="emphasize"> Iniciar sesión</span><span class="caret"></span>
# </a>
# <div class="dropdown-menu dropdown-form dropdown-menu--rightAlign is-forceRight" id="signin-dropdown">
# <div class="dropdown-caret right"> <span class="caret-outer"></span> <span class="caret-inner"></span> </div>
# <div class="signin-dialog-body">
# <div>¿Tienes cuenta?</div>
# <form action="https://twitter.com/sessions" class="LoginForm js-front-signin" data-component="login_callout" data-element="form" method="post">
# <div class="LoginForm-input LoginForm-username">
# <input autocomplete="username" class="text-input email-input js-signin-email" name="session[username_or_email]" placeholder="Teléfono, correo electrónico o nombre de usuario" type="text">
# </input></div>
# <div class="LoginForm-input LoginForm-password">
# <input autocomplete="current-password" class="text-input" name="session[password]" placeholder="Contraseña" type="password"/>
# </div>
# <div class="LoginForm-rememberForgot">
# <label>
# <input checked="checked" name="remember_me" type="checkbox" value="1"/>
# <span>Recordar mis datos</span>
# </label>
# <span class="separator">·</span>
# <a class="forgot" href="/account/begin_password_reset" rel="noopener">¿Olvidaste tu contraseña?</a>
# </div>
# <input class="EdgeButton EdgeButton--primary EdgeButton--medium submit js-submit" type="submit" value="Iniciar sesión"/>
# <input name="return_to_ssl" type="hidden" value="true"/>
# <input name="scribe_log" type="hidden"/>
# <input name="redirect_after_login" type="hidden" value="/cordeiro"/>
# <input name="authenticity_token" type="hidden" value="786d2c6a824242172cdaccc26e65a5cd3d1b10c1"/>
# <input autocomplete="off" name="ui_metrics" type="hidden"/>
# <script async="" src="/i/js_inst?c_name=ui_metrics"></script>
# </form>
# <hr/>
# <div class="signup SignupForm">
# <div class="SignupForm-header">¿Nuevo en Twitter?</div>
# <a class="EdgeButton EdgeButton--secondary EdgeButton--medium u-block js-signup" data-component="signup_callout" data-element="dropdown" href="https://twitter.com/signup" role="button">Regístrate
#                 </a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="topbar-spacer" style="padding-top: 108px;">
# </div>
# <div id="page-outer">
# <div class="AppContent" id="page-container">
# <style id="user-style-cordeiro">
#
#
#
#
#
#
#   a,
#   a:hover,
#   a:focus,
#   a:active {
#     color: #1B95E0;
#   }
#
#   .u-textUserColor,
#   .u-textUserColorHover:hover,
#   .u-textUserColorHover:hover .ProfileTweet-actionCount,
#   .u-textUserColorHover:focus {
#     color: #1B95E0 !important;
#   }
#
#   .u-borderUserColor,
#   .u-borderUserColorHover:hover,
#   .u-borderUserColorHover:focus {
#     border-color: #1B95E0 !important;
#   }
#
#   .u-bgUserColor,
#   .u-bgUserColorHover:hover,
#   .u-bgUserColorHover:focus {
#     background-color: #1B95E0 !important;
#   }
#
#   .u-dropdownUserColor > li:hover,
#   .u-dropdownUserColor > li:focus,
#   .u-dropdownUserColor > li > button:hover,
#   .u-dropdownUserColor > li > button:focus,
#   .u-dropdownUserColor > li > a:focus,
#   .u-dropdownUserColor > li > a:hover {
#     color: #fff !important;
#     background-color: #1B95E0 !important;
#   }
#
#   .u-boxShadowInsetUserColorHover:hover,
#   .u-boxShadowInsetUserColorHover:focus {
#     box-shadow: inset 0 0 0 5px #1B95E0 !important;
#   }
#
#   .u-dropdownOpenUserColor.dropdown.open .dropdown-toggle {
#     color: #1B95E0;
#   }
#
#
#   .u-textUserColorLight {
#     color: #A3D4F2 !important;
#   }
#
#   .u-borderUserColorLight,
#   .u-borderUserColorLightFocus:focus,
#   .u-borderUserColorLightHover:hover,
#   .u-borderUserColorLightHover:focus {
#     border-color: #A3D4F2 !important;
#   }
#
#   .u-bgUserColorLight {
#     background-color: #A3D4F2 !important;
#   }
#
#
#   .u-boxShadowUserColorLighterFocus:focus {
#     box-shadow: 0 0 8px rgba(0, 0, 0, 0.05), inset 0 1px 2px rgba(27,149,224,0.25) !important;
#   }
#
#
#   .u-textUserColorLightest {
#     color: #E8F4FB !important;
#   }
#
#   .u-borderUserColorLightest {
#     border-color: #E8F4FB !important;
#   }
#
#   .u-bgUserColorLightest {
#     background-color: #E8F4FB !important;
#   }
#
#
#   .u-textUserColorLighter {
#     color: #C6E4F7 !important;
#   }
#
#   .u-borderUserColorLighter {
#     border-color: #C6E4F7 !important;
#   }
#
#   .u-bgUserColorLighter {
#     background-color: #C6E4F7 !important;
#   }
#
#
#   .u-bgUserColorDarkHover:hover {
#     background-color: #1B7FBE !important;
#   }
#
#   .u-borderUserColorDark {
#     border-color: #1B7FBE !important;
#   }
#
#
#   .u-bgUserColorDarkerActive:active {
#     background-color: #1B699C !important;
#   }
#
#
#
#
#
#
#
#
#
#
#
#
#
# a,
# .btn-link,
# .btn-link:focus,
# .icon-btn,
#
#
#
# .pretty-link b,
# .pretty-link:hover s,
# .pretty-link:hover b,
# .pretty-link:focus s,
# .pretty-link:focus b,
#
# .metadata a:hover,
# .metadata a:focus,
#
# a.account-group:hover .fullname,
# a.account-group:focus .fullname,
# .account-summary:focus .fullname,
#
# .message .message-text a,
# .message .message-text button,
# .stats a strong,
# .plain-btn:hover,
# .plain-btn:focus,
# .dropdown.open .user-dropdown.plain-btn,
# .open > .plain-btn,
# #global-actions .new:before,
# .module .list-link:hover,
# .module .list-link:focus,
#
# .stats a:hover,
# .stats a:hover strong,
# .stats a:focus,
# .stats a:focus strong,
#
# .find-friends-sources li:hover .source,
#
#
#
#
#
# .stream-item a:hover .fullname,
# .stream-item a:focus .fullname,
#
# .stream-item .view-all-supplements:hover,
# .stream-item .view-all-supplements:focus,
#
# .tweet .time a:hover,
# .tweet .time a:focus,
# .tweet .details.with-icn b,
# .tweet .details.with-icn .Icon,
#
# .stream-item:hover .original-tweet .details b,
# .stream-item .original-tweet.focus .details b,
# .stream-item.open .original-tweet .details b,
#
# .client-and-actions a:hover,
# .client-and-actions a:focus,
#
# .dismiss-btn:hover b,
#
# .tweet .context .pretty-link:hover s,
# .tweet .context .pretty-link:hover b,
# .tweet .context .pretty-link:focus s,
# .tweet .context .pretty-link:focus b,
#
# .list .username a:hover,
# .list .username a:focus,
# .list-membership-container .create-a-list,
# .list-membership-container .create-a-list:hover,
# .new-tweets-bar,
#
#
#
# .card .list-details a:hover,
# .card .list-details a:focus,
# .card .card-body:hover .attribution,
# .card .card-body .attribution:focus {
#   color: #1B95E0;
# }
#
#
#
#
#
#   .FoundMediaSearch--keyboard .FoundMediaSearch-focusable.is-focused {
#     border-color: #1B95E0;
#   }
#
#
#   .photo-selector:hover .btn,
#   .icon-btn:hover,
#   .icon-btn:active,
#   .icon-btn.active,
#   .icon-btn.enabled {
#     border-color: #1B95E0;
#     border-color: rgba(27,149,224,0.4);
#     color: #1B95E0;
#   }
#
#
#   .photo-selector:hover .btn,
#   .icon-btn:hover {
#     background-image: linear-gradient(rgba(255,255,255,0), rgba(27,149,224,0.1));
#   }
#
#   .icon-btn.disabled,
#   .icon-btn.disabled:hover,
#   .icon-btn[disabled],
#   .icon-btn[aria-disabled=true] {
#     color: #1B95E0;
#   }
#
#
#
#
#   .EdgeButton--primary,
#   .EdgeButton--primary:focus {
#     background-color: #48AAE6;
#     border-color: transparent;
#   }
#
#   .EdgeButton--primary:hover,
#   .EdgeButton--primary:active {
#     background-color: #1B95E0;
#     border-color: #1B95E0;
#   }
#
#   .EdgeButton--primary:focus {
#     box-shadow:
#       0 0 0 2px #FFFFFF,
#       0 0 0 4px #A3D4F2;
#   }
#
#   .EdgeButton--primary:active {
#     box-shadow:
#       0 0 0 2px #FFFFFF,
#       0 0 0 4px #48AAE6;
#   }
#
#
#
#
#   .EdgeButton--secondary,
#   .EdgeButton--secondary:hover,
#   .EdgeButton--secondary:focus,
#   .EdgeButton--secondary:active {
#     border-color: #1B95E0;
#     color: #1B95E0;
#   }
#
#   .EdgeButton--secondary:hover,
#   .EdgeButton--secondary:active {
#     background-color: #E8F4FB;
#   }
#
#   .EdgeButton--secondary:focus {
#     box-shadow:
#       0 0 0 2px #FFFFFF,
#       0 0 0 4px rgba(27,149,224,0.4);
#   }
#
#   .EdgeButton--secondary:active {
#     box-shadow:
#       0 0 0 2px #FFFFFF,
#       0 0 0 4px #1B95E0;
#   }
#
#
#
#
#   .EdgeButton--invertedPrimary {
#     color: #1B95E0 !important;
#   }
#
#   .EdgeButton--invertedPrimary:focus {
#     box-shadow:
#       0 0 0 2px #1B95E0,
#       0 0 0 4px #A3D4F2;
#   }
#
#   .EdgeButton--invertedPrimary:active {
#     box-shadow:
#       0 0 0 2px #1B95E0,
#       0 0 0 4px #FFFFFF;
#   }
#
#
#
#
#   .EdgeButton--invertedSecondary {
#     background-color: #1B95E0;
#   }
#
#   .EdgeButton--invertedSecondary:hover {
#     background-color: #48AAE6;
#   }
#
#   .EdgeButton--invertedSecondary:focus {
#     box-shadow:
#       0 0 0 2px #1B95E0,
#       0 0 0 4px #A3D4F2;
#   }
#
#   .EdgeButton--invertedSecondary:active {
#     box-shadow:
#       0 0 0 2px #1B95E0,
#       0 0 0 4px #FFFFFF;
#   }
#
#
#
#   .btn:focus,
#   .btn.focus,
#   .Button:focus,
#   .EmojiPicker-item.is-focused,
#   .EmojiPicker .EmojiCategoryIcon:focus,
#   .EmojiPicker-skinTone:focus + .EmojiPicker-skinToneSwatch,
#   a:focus > img:first-child:last-child,
#   button:focus {
#     box-shadow:
#       0 0 0 2px #FFFFFF,
#       0 0 2px 4px rgba(27,149,224,0.4);
#   }
#
#   .selected-stream-item:focus {
#     box-shadow: 0 0 0 3px rgba(27,149,224,0.4);
#   }
#
#
#   .js-navigable-stream.stream-table-view .selected-stream-item[tabindex="-1"]:focus {
#     outline: 3px solid rgba(27,149,224,0.4) !important;
#   }
#
#
#   .js-navigable-stream.stream-table-view .selected-stream-item:focus {
#     box-shadow: none;
#   }
#
#
#
#   .global-dm-nav.new.with-count .dm-new .count-inner {
#     background: #1B95E0;
#   }
#
#   .global-nav .people .count .count-inner {
#     background: #1B95E0;
#   }
#
#   .dropdown-menu li > a:hover,
#   .dropdown-menu li > a:focus,
#   .dropdown-menu .dropdown-link:hover,
#   .dropdown-menu .dropdown-link:focus,
#   .dropdown-menu .dropdown-link.is-focused,
#   .dropdown-menu li:hover .dropdown-link,
#   .dropdown-menu li:focus .dropdown-link,
#   .dropdown-menu .selected a,
#   .dropdown-menu .dropdown-link.selected {
#     background-color: #1B95E0 !important;
#   }
#
#   /* for items in typeahead dropdown menu on logged in pages */
#   .dropdown-menu .typeahead-items li > a:focus,
#   .dropdown-menu .typeahead-items li > a:hover,
#   .dropdown-menu .typeahead-items .selected,
#   .dropdown-menu .typeahead-items .selected a {
#     background-color: #E8F4FB !important;
#     color: #1B95E0 !important;
#   }
#
#   .typeahead a:hover,
#   .typeahead a:hover strong,
#   .typeahead a:hover .fullname,
#   .typeahead .selected a,
#   .typeahead .selected strong,
#   .typeahead .selected .fullname,
#   .typeahead .selected .Icon--close {
#     color: #1B95E0 !important;
#   }
#
#
# .home-tweet-box,
# .LiveVideo-tweetBox,
# .RetweetDialog-commentBox {
#   background-color: #E8F4FB;
# }
#
# .top-timeline-tweetbox .timeline-tweet-box .tweet-form.condensed .tweet-box {
#   color: #1B95E0;
# }
#
# .RichEditor,
# .TweetBoxAttachments {
#   border-color: #C6E4F7;
# }
#
# input:focus,
# textarea:focus,
# div[contenteditable="true"]:focus,
# div[contenteditable="true"].fake-focus,
# div[contenteditable="plaintext-only"]:focus,
# div[contenteditable="plaintext-only"].fake-focus {
#   border-color: #A3D4F2;
#   box-shadow: inset 0 0 0 1px rgba(27,149,224,0.7);
# }
#
# .tweet-box textarea:focus,
# .tweet-box input[type=text],
# .currently-dragging .tweet-form.is-droppable .tweet-drag-help,
# .tweet-box[contenteditable="true"]:focus,
# .RichEditor.is-fakeFocus,
# .RichEditor.is-fakeFocus ~ .TweetBoxAttachments {
#   border-color: #A3D4F2;
#   box-shadow: 0 0 0 1px #A3D4F2;
# }
#
# .MomentCapsuleItem.selected-stream-item:focus {
#   box-shadow: 0 0 0 3px rgba(27,149,224,0.4);
# }
#
#
#
#
# s,
# .pretty-link:hover s,
# .pretty-link:focus s,
# .stream-item-activity-notification .latest-tweet .tweet-row a:hover s,
# .stream-item-activity-notification .latest-tweet .tweet-row a:focus s {
#     color: #1B95E0;
# }
#
#
#
# .vellip,
# .vellip:before,
# .vellip:after,
# .conversation-module > li:after,
# .conversation-module > li:before,
# .ThreadedConversation--loneTweet:after,
# .ThreadedConversation-tweet:not(.is-hiddenAncestor) ~ .ThreadedConversation-tweet:before,
# .ThreadedConversation-tweet:after,
# .ThreadedConversation-moreReplies:before,
# .ThreadedConversation-viewOther:before,
# .ThreadedConversation-unavailableTweet:before,
# .ThreadedConversation-unavailableTweet:after,
# .ThreadedConversation--permalinkTweetWithAncestors:before,
# .mini-avatar-with-thread:before,
# .permalink.self-thread-permalink-with-descendant .permalink-tweet-container:after,
# .permalink.self-thread-permalink-with-descendant .inline-reply-tweetbox-container:after {
#     border-color: #A3D4F2;
# }
#
#
#
#
# .tweet .sm-reply,
# .tweet .sm-rt,
# .tweet .sm-fav,
# .tweet .sm-image,
# .tweet .sm-video,
# .tweet .sm-audio,
# .tweet .sm-geo,
# .tweet .sm-in,
# .tweet .sm-trash,
# .tweet .sm-more,
# .tweet .sm-page,
# .tweet .sm-embed,
# .tweet .sm-summary,
# .tweet .sm-chat,
#
# .timelines-navigation .active .profile-nav-icon,
# .timelines-navigation .profile-nav-icon:hover,
# .timelines-navigation .profile-nav-link:focus .profile-nav-icon,
#
# .sm-top-tweet {
#     background-color: #1B95E0;
# }
#
# .enhanced-mini-profile .mini-profile .profile-summary {
#   background-image: url(https://pbs.twimg.com/profile_banners/14068117/1558973614/mobile);
# }
#
#   #global-tweet-dialog .modal-header,
#   #Tweetstorm-dialog .modal-header {
#     border-bottom: solid 1px rgba(27,149,224,0.25);
#   }
#
#   #global-tweet-dialog .modal-tweet-form-container,
#   #Tweetstorm-dialog .modal-body {
#     background-color: #1B95E0;
#     background: rgba(27,149,224,0.1);
#   }
#
#   .TweetstormDialog-reply-context .tweet-box-avatar:after,
#   .TweetstormDialog-reply-context .tweet-box-avatar:before,
#   .TweetstormDialog-tweet-box .tweet-box-avatar:after,
#   .TweetstormDialog-tweet-box .tweet-box-avatar:before {
#     border-color: #A3D4F2;
#   }
#
#   .global-nav .search-input:focus,
#   .global-nav .search-input.focus {
#     border: 2px solid #1B95E0;
#   }
# }
#
#   .inline-reply-tweetbox {
#     background-color: #E8F4FB;
#   }
#
# </style>
# <div class="ProfileCanopy ProfileCanopy--withNav ProfileCanopy--large js-variableHeightTopBar">
# <div class="ProfileCanopy-inner">
# <div class="ProfileCanopy-header u-bgUserColor">
# <div class="ProfileCanopy-headerBg">
# <img alt="" src="https://pbs.twimg.com/profile_banners/14068117/1558973614/1500x500"/>
# </div>
# <div class="AppContainer">
# <div class="ProfileCanopy-avatar">
# <div class="ProfileAvatar">
# <a class="ProfileAvatar-container u-block js-tooltip profile-picture" data-resolved-url-large="https://pbs.twimg.com/profile_images/1078408329045725184/ix0-gmNx_400x400.jpg" data-url="https://pbs.twimg.com/profile_images/1078408329045725184/ix0-gmNx_400x400.jpg" href="https://pbs.twimg.com/profile_images/1078408329045725184/ix0-gmNx_400x400.jpg" rel="noopener" target="_blank" title="JoséCordeiro">
# <img alt="JoséCordeiro" class="ProfileAvatar-image" src="https://pbs.twimg.com/profile_images/1078408329045725184/ix0-gmNx_400x400.jpg"/>
# </a>
# </div>
# </div>
# <div class="ProfileCanopy-headerPromptAnchor"></div>
# </div>
# </div>
# <div class="ProfileCanopy-navBar u-boxShadow">
# <div class="AppContainer">
# <div class="Grid Grid--withGutter">
# <div class="Grid-cell u-size1of3 u-lg-size1of4">
# <div class="ProfileCanopy-card" role="presentation">
# <div class="ProfileCardMini">
# <a class="ProfileCardMini-avatar profile-picture js-tooltip" data-resolved-url-large="https://pbs.twimg.com/profile_images/1078408329045725184/ix0-gmNx.jpg" data-url="https://pbs.twimg.com/profile_images/1078408329045725184/ix0-gmNx.jpg" href="https://pbs.twimg.com/profile_images/1078408329045725184/ix0-gmNx.jpg" rel="noopener" target="_blank" title="JoséCordeiro">
# <img alt="JoséCordeiro" class="ProfileCardMini-avatarImage" src="https://pbs.twimg.com/profile_images/1078408329045725184/ix0-gmNx_normal.jpg"/>
# </a>
# <div class="ProfileCardMini-details">
# <div class="ProfileNameTruncated account-group">
# <div class="u-textTruncate u-inlineBlock">
# <a class="fullname ProfileNameTruncated-link u-textInheritColor js-nav" data-aria-label-part="" href="/cordeiro">
#       JoséCordeiro</a></div><span class="UserBadges"></span>
# </div>
# <div class="ProfileCardMini-screenname">
# <a class="ProfileCardMini-screennameLink u-linkComplex js-nav u-dir" dir="ltr" href="/cordeiro">
# <span class="username u-dir" dir="ltr">@<b class="u-linkComplex-target">cordeiro</b></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Grid-cell u-size2of3 u-lg-size3of4">
# <div class="ProfileCanopy-nav">
# <div class="ProfileNav" data-user-id="14068117" role="navigation">
# <ul class="ProfileNav-list">
# <li class="ProfileNav-item ProfileNav-item--tweets is-active">
# <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-nav" data-nav="tweets" tabindex="0" title="1.173 Tweets">
# <span aria-hidden="true" class="ProfileNav-label">Tweets</span>
# <span class="u-hiddenVisually">Tweets, página actual.</span>
# <span class="ProfileNav-value" data-count="1173" data-is-compact="false">1.173
#             </span>
# </a>
# </li><li class="ProfileNav-item ProfileNav-item--following">
# <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="following" href="/cordeiro/following" title="1.663 Siguiendo">
# <span aria-hidden="true" class="ProfileNav-label">Siguiendo</span>
# <span class="u-hiddenVisually">Siguiendo</span>
# <span class="ProfileNav-value" data-count="1663" data-is-compact="false">1.663</span>
# </a>
# </li><li class="ProfileNav-item ProfileNav-item--followers">
# <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="followers" href="/cordeiro/followers" title="3.116 Seguidores">
# <span aria-hidden="true" class="ProfileNav-label">Seguidores</span>
# <span class="u-hiddenVisually">Seguidores</span>
# <span class="ProfileNav-value" data-count="3116" data-is-compact="false">3.116</span>
# </a>
# </li><li class="ProfileNav-item ProfileNav-item--favorites" data-more-item=".ProfileNav-dropdownItem--favorites">
# <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="favorites" href="/cordeiro/likes" title="5.241 Me gusta">
# <span aria-hidden="true" class="ProfileNav-label">Me gusta</span>
# <span class="u-hiddenVisually">Me gusta</span>
# <span class="ProfileNav-value" data-count="5241" data-is-compact="false">5.241</span>
# </a>
# </li><li class="ProfileNav-item ProfileNav-item--more dropdown is-hidden"> <a class="ProfileNav-stat ProfileNav-stat--link ProfileNav-stat--moreLink js-openSignupDialog js-nonNavigable" href="#more" role="button">
# <span class="ProfileNav-label"> </span>
# <span class="ProfileNav-value">Más <span class="ProfileNav-dropdownCaret Icon Icon--medium Icon--caretDown"></span></span>
# </a>
# <div class="dropdown-menu">
# <div class="dropdown-caret">
# <span class="caret-outer"></span>
# <span class="caret-inner"></span>
# </div>
# <ul><li>
# <a class="ProfileNav-dropdownItem ProfileNav-dropdownItem--favorites is-hidden u-bgUserColorHover u-bgUserColorFocus u-linkClean js-nav" href="/cordeiro/likes">Me gusta</a></li></ul>
# </div>
# </li><li class="ProfileNav-item ProfileNav-item--userActions u-floatRight u-textRight with-rightCaret">
# <div class="UserActions u-textLeft">
# <div class="user-actions btn-group not-following" data-name="JoséCordeiro" data-protected="false" data-screen-name="cordeiro" data-user-id="14068117">
# <span class="UserActions-moreActions u-inlineBlock">
# <button class="js-tooltip unmute-button btn small plain-btn" data-placement="top" title="Dejar de silenciar a @cordeiro" type="button">
# <span class="Icon Icon--muted Icon--medium"><span class="visuallyhidden">Dejar de silenciar a <span class="username u-dir u-textTruncate" dir="ltr">@<b>cordeiro</b></span></span></span>
# </button><button class="first-load js-tooltip mute-button btn small plain-btn" data-placement="top" title="Silenciar a @cordeiro" type="button">
# <span class="Icon Icon--unmuted Icon--medium"><span class="visuallyhidden">Silenciar a <span class="username u-dir u-textTruncate" dir="ltr">@<b>cordeiro</b></span></span></span>
# </button></span><span class="user-actions-follow-button js-follow-btn follow-button">
# <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text follow-text" type="button">
# <span aria-hidden="true">Seguir</span>
# <span class="u-hiddenVisually">Seguir a <span class="username u-dir u-textTruncate" dir="ltr">@<b>cordeiro</b></span></span>
# </button>
# <button class="EdgeButton EdgeButton--primary EdgeButton--medium button-text following-text" type="button">
# <span aria-hidden="true">Siguiendo</span>
# <span class="u-hiddenVisually">Siguiendo a <span class="username u-dir u-textTruncate" dir="ltr">@<b>cordeiro</b></span></span>
# </button>
# <button class="EdgeButton EdgeButton--danger EdgeButton--medium button-text unfollow-text" type="button">
# <span aria-hidden="true">Dejar de seguir</span>
# <span class="u-hiddenVisually">Dejar de seguir a <span class="username u-dir u-textTruncate" dir="ltr">@<b>cordeiro</b></span></span>
# </button>
# <button class="EdgeButton EdgeButton--invertedDanger EdgeButton--medium button-text blocked-text" type="button">
# <span aria-hidden="true">Bloqueado</span>
# <span class="u-hiddenVisually"><span class="username u-dir u-textTruncate" dir="ltr">@<b>cordeiro</b></span> está bloqueado</span>
# </button>
# <button class="EdgeButton EdgeButton--danger EdgeButton--medium button-text unblock-text" type="button">
# <span aria-hidden="true">Desbloquear</span>
# <span class="u-hiddenVisually">Desbloquear a <span class="username u-dir u-textTruncate" dir="ltr">@<b>cordeiro</b></span></span>
# </button>
# <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text pending-text" type="button">
# <span aria-hidden="true">Pendiente</span>
# <span class="u-hiddenVisually">Solicitud de seguimiento de <span class="username u-dir u-textTruncate" dir="ltr">@<b>cordeiro</b></span> pendiente</span>
# </button>
# <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text cancel-text" type="button">
# <span aria-hidden="true">Cancelar</span>
# <span class="u-hiddenVisually">Cancelar tu solicitud de seguimiento a <span class="username u-dir u-textTruncate" dir="ltr">@<b>cordeiro</b></span></span>
# </button>
# </span>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="AppContainer">
# <div aria-labelledby="content-main-heading" class="AppContent-main content-main u-cf" role="main">
# <div class="Grid Grid--withGutter">
# <div class="Grid-cell u-size1of3 u-lg-size1of4">
# <div class="Grid Grid--withGutter">
# <div class="Grid-cell">
# ...
# </div>
# <iframe aria-hidden="true" class="hidden" id="why-this-ad-frame" scrolling="auto">
# </iframe>
# </div>
# </div>
# </div>
# </div>
# <div class="LoginDialog modal-container u-textCenter" id="login-dialog">
# <div class="modal modal-large draggable">
# <div class="LoginDialog-content modal-content">
# <button class="modal-btn modal-close js-close" type="button">
# <span class="Icon Icon--close Icon--medium">
# <span class="visuallyhidden">Cerrar</span>
# </span>
# </button>
# <div class="modal-header">
# <h3 class="modal-title">Inicia sesión en Twitter</h3>
# </div>
# <div class="LoginDialog-body modal-body">
# <div class="LoginDialog-bird">
# <span class="Icon Icon--bird Icon--large"></span>
# </div>
# <div class="LoginDialog-form">
# <form action="https://twitter.com/sessions" class="LoginForm js-front-signin" data-component="dialog" data-element="login" method="post">
# <div class="LoginForm-input LoginForm-username">
# <input autocomplete="username" class="text-input email-input js-signin-email" name="session[username_or_email]" placeholder="Teléfono, correo electrónico o nombre de usuario" type="text">
# </input></div>
# <div class="LoginForm-input LoginForm-password">
# <input autocomplete="current-password" class="text-input" name="session[password]" placeholder="Contraseña" type="password"/>
# </div>
# <div class="LoginForm-rememberForgot">
# <label>
# <input checked="checked" name="remember_me" type="checkbox" value="1"/>
# <span>Recordar mis datos</span>
# </label>
# <span class="separator">·</span>
# <a class="forgot" href="/account/begin_password_reset" rel="noopener">¿Olvidaste tu contraseña?</a>
# </div>
# <input class="EdgeButton EdgeButton--primary EdgeButton--medium submit js-submit" type="submit" value="Iniciar sesión"/>
# <input name="return_to_ssl" type="hidden" value="true"/>
# <input name="scribe_log" type="hidden"/>
# <input name="redirect_after_login" type="hidden" value="/cordeiro"/>
# <input name="authenticity_token" type="hidden" value="786d2c6a824242172cdaccc26e65a5cd3d1b10c1"/>
# <input autocomplete="off" name="ui_metrics" type="hidden"/>
# <script async="" src="/i/js_inst?c_name=ui_metrics"></script>
# </form>
# </div>
# </div>
# <div class="LoginDialog-footer modal-footer u-textCenter">
#         ¿No tienes una cuenta? <a class="LoginDialog-signupLink" href="https://twitter.com/signup" rel="noopener">Regístrate »</a>
# </div>
# </div>
# </div>
# </div>
# <div class="SignupDialog modal-container u-textCenter" id="signup-dialog">
# <div class="modal modal-large draggable">
# <div class="SignupDialog-content modal-content">
# <button class="modal-btn modal-close js-close" type="button">
# <span class="Icon Icon--close Icon--medium">
# <span class="visuallyhidden">Cerrar</span>
# </span>
# </button>
# <div class="modal-header">
# <h3 class="modal-title">Regístrate en Twitter</h3>
# </div>
# <div class="SignupDialog-body modal-body">
# <div class="SignupDialog-icon">
# <span class="Icon Icon--bird Icon--extraLarge"></span>
# </div>
# <h2 class="SignupDialog-heading">¿No estás en Twitter? Regístrate, ponte al día con las cosas que te importan y recibe actualizaciones inmediatas.</h2>
# <div class="SignupDialog-form">
# <div class="signup SignupForm">
# <a class="EdgeButton EdgeButton--large EdgeButton--primary SignupForm-submit u-block js-signup" data-component="dialog" data-element="signup" href="https://twitter.com/signup" role="button">Regístrate</a>
# </div>
# </div>
# </div>
# <div class="SignupDialog-footer modal-footer u-textCenter">
#         ¿Tienes cuenta? <a class="SignupDialog-signinLink" href="/login" rel="noopener">Iniciar sesión »</a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal-container" id="sms-codes-dialog">
# <div class="modal modal-medium draggable">
# <div class="modal-content">
# <button class="modal-btn modal-close js-close" type="button">
# <span class="Icon Icon--close Icon--medium">
# <span class="visuallyhidden">Cerrar</span>
# </span>
# </button>
# <div class="modal-header">
# <h3 class="modal-title">Códigos cortos</h3>
# </div>
# <div class="modal-body">
# <table cellpadding="0" cellspacing="0" id="sms_codes">
# <thead>
# <tr>
# <th>País</th>
# <th>Código</th>
# <th>Para clientes de</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Estados Unidos</td>
# <td>40404</td>
# <td>(cualquiera)</td>
# </tr>
# <tr>
# <td>Canadá</td>
# <td>21212</td>
# <td>(cualquiera)</td>
# </tr>
# <tr>
# <td>Reino Unido</td>
# <td>86444</td>
# <td>Vodafone, Orange, 3, O2</td>
# </tr>
# <tr>
# <td>Brasil</td>
# <td>40404</td>
# <td>Nextel, TIM</td>
# </tr>
# <tr>
# <td>Haití</td>
# <td>40404</td>
# <td>Digicel, Voila</td>
# </tr>
# <tr>
# <td>Irlanda</td>
# <td>51210</td>
# <td>Vodafone, O2</td>
# </tr>
# <tr>
# <td>India</td>
# <td>53000</td>
# <td>Bharti Airtel, Videocon, Reliance</td>
# </tr>
# <tr>
# <td>Indonesia</td>
# <td>89887</td>
# <td>AXIS, 3, Telkomsel, Indosat, XL Axiata</td>
# </tr>
# <tr>
# <td rowspan="2">Italia</td>
# <td>4880804</td>
# <td>Wind</td>
# </tr>
# <tr>
# <td>3424486444</td>
# <td>Vodafone</td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <td colspan="3">
#         » <a class="js-initial-focus" href="http://support.twitter.com/articles/14226-how-to-find-your-twitter-short-code-or-long-code" rel="noopener" target="_blank">Ver códigos cortos de SMS para otros países</a>
# </td>
# </tr>
# </tfoot>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="modal-container" id="leadgen-confirm-dialog">
# <div class="modal draggable">
# <div class="modal-content">
# <button class="modal-btn modal-close js-close" type="button">
# <span class="Icon Icon--close Icon--medium">
# <span class="visuallyhidden">Cerrar</span>
# </span>
# </button>
# <div class="modal-header">
# <h3 class="modal-title">Confirmación</h3>
# </div>
# <div class="modal-body">
# <div class="leadgen-card-container">
# <div class="media">
# <iframe class="cards2-promotion-iframe" frameborder="0" scrolling="no" src="">
# </iframe>
# </div>
# </div>
# <div class="js-macaw-cards-iframe-container" data-card-name="promotion">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="AuthWebViewDialog modal-container" id="auth-webview-dialog">
# <div class="modal draggable">
# <div class="modal-content">
# <button class="modal-btn modal-close modal-close-fixed js-close" type="button">
# <span class="Icon Icon--close Icon--large">
# <span class="visuallyhidden">Cerrar</span>
# </span>
# </button>
# <div class="modal-header">
# <h3 class="modal-title"> </h3>
# </div>
# <div class="modal-body">
# <div class="auth-webview-view-container">
# <div class="media">
# <iframe class="auth-webview-card-iframe js-initial-focus" frameborder="0" height="500px" scrolling="no" src="" width="590px">
# </iframe>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal-container" id="promptbird-modal-prompt">
# <div class="modal">
# <button class="modal-btn js-promptDismiss modal-close js-close" type="button">
# <span class="Icon Icon--close Icon--medium">
# <span class="visuallyhidden">Cerrar</span>
# </span>
# </button>
# <div class="modal-content"></div>
# </div>
# </div>
# <div class="modal-container UIWalkthrough" id="ui-walkthrough-dialog">
# <div class="UIWalkthrough-clickBlocker"></div>
# <div class="modal modal-small">
# <div class="UIWalkthrough-caret"></div>
# <div class="modal-content">
# <div class="modal-body">
# <div class="UIWalkthrough-header">
# <span class="UIWalkthrough-stepProgress"></span>
# <button class="UIWalkthrough-skip js-close">
#             Omitir todo
#           </button>
# </div>
# <div class="UIWalkthrough-step UIWalkthrough-step--welcome">
# <h3 class="UIWalkthrough-title">
# <span class="Icon Icon--home UIWalkthrough-icon"></span>
#     ¡Bienvenido a casa!
#   </h3>
# <p class="UIWalkthrough-message">En esta cronología pasarás la mayoría de tu tiempo recibiendo actualizaciones sobre lo que más te interesa.</p>
# </div>
# <div class="UIWalkthrough-step UIWalkthrough-step--unfollow">
# <h3 class="UIWalkthrough-title">
# <span class="Icon Icon--smileRating1Fill UIWalkthrough-icon"></span>
#     ¿Ninguno de los Tweets te interesa?
#   </h3>
# <p class="UIWalkthrough-message">
#     Posiciona tu puntero sobre la imagen de perfil y haz clic en el botón Siguiendo para dejar de seguir a cualquier cuenta.
#   </p>
# </div>
# <div class="UIWalkthrough-step UIWalkthrough-step--like">
# <h3 class="UIWalkthrough-title">
# <span class="Icon Icon--heart UIWalkthrough-icon"></span>
#     Di mucho con poco
#   </h3>
# <p class="UIWalkthrough-message">
#     Cuando te guste un Tweet, pulsa el corazón: le hará saber a la persona que lo escribió que compartiste el amor.
#   </p>
# </div>
# <div class="UIWalkthrough-step UIWalkthrough-step--retweet">
# <h3 class="UIWalkthrough-title">
# <span class="Icon Icon--retweet UIWalkthrough-icon"></span>
#     Difunde el mensaje
#   </h3>
# <p class="UIWalkthrough-message">
#     La manera más rápida de compartir el Tweet de alguien con tus seguidores es con un Retweet. Pulsa el icono para enviarlo instantáneamente.
#   </p>
# </div>
# <div class="UIWalkthrough-step UIWalkthrough-step--reply">
# <h3 class="UIWalkthrough-title">
# <span class="Icon Icon--reply UIWalkthrough-icon"></span>
#     Únete a la conversación
#   </h3>
# <p class="UIWalkthrough-message">
#     Di lo que opinas sobre cualquier Tweet con una respuesta. Encuentra un tema que te apasione, y únete a la conversación.
#   </p>
# </div>
# <div class="UIWalkthrough-step UIWalkthrough-step--trends">
# <h3 class="UIWalkthrough-title">
# <span class="Icon Icon--discover UIWalkthrough-icon"></span>
#     Infórmate de lo más reciente
#   </h3>
# <p class="UIWalkthrough-message">
#     Consigue información instantánea sobre lo que las personas están hablando en este momento.
#   </p>
# </div>
# <div class="UIWalkthrough-step UIWalkthrough-step--wtf">
# <h3 class="UIWalkthrough-title">
# <span class="Icon Icon--follow UIWalkthrough-icon"></span>
#     Consigue más de lo que te encanta
#   </h3>
# <p class="UIWalkthrough-message">
#     Sigue a más cuentas para recibir actualizaciones instantáneas sobre los temas que te interesan.
#   </p>
# </div>
# <div class="UIWalkthrough-step UIWalkthrough-step--search">
# <h3 class="UIWalkthrough-title">
# <span class="Icon Icon--search UIWalkthrough-icon"></span>
#     Encuentra lo que está sucediendo
#   </h3>
# <p class="UIWalkthrough-message">
#     Ve las conversaciones más recientes sobre cualquier tema instantáneamente.
#   </p>
# </div>
# <div class="UIWalkthrough-step UIWalkthrough-step--moments">
# <h3 class="UIWalkthrough-title">
# <span class="Icon Icon--lightning UIWalkthrough-icon"></span>
#     Nunca te pierdas un Momento
#   </h3>
# <p class="UIWalkthrough-message">
#     Infórmate de las mejores historias instantáneamente mientras están sucediendo.
#   </p>
# </div>
# </div>
# <div class="modal-footer">
# <button class="EdgeButton EdgeButton--tertiary u-floatLeft plain-btn UIWalkthrough-button js-previous-step">Regresar</button>
# <button class="EdgeButton EdgeButton--secondary UIWalkthrough-button js-next-step js-initial-focus">Siguiente</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal-container" id="create-custom-timeline-dialog"></div>
# <div class="modal-container" id="edit-custom-timeline-dialog"></div>
# <div class="modal-container" id="curate-dialog"></div>
# <div class="modal-container" id="media-edit-dialog"></div>
# <div class="PermalinkOverlay PermalinkOverlay-with-background" id="permalink-overlay">
# <div class="PermalinkProfile-dismiss modal-close-fixed">
# <span class="Icon Icon--close"></span>
# </div>
# <button class="PermalinkOverlay-next PermalinkOverlay-button u-posFixed js-next" type="button">
# <span class="Icon Icon--caretLeft Icon--large"></span>
# <span class="u-hiddenVisually">Siguiente Tweet del usuario</span>
# </button>
# <div class="PermalinkOverlay-modal">
# <div class="PermalinkOverlay-spinnerContainer u-hidden">
# <div class="PermalinkOverlay-spinner"></div>
# </div>
# <div class="PermalinkOverlay-content">
# <div class="PermalinkOverlay-body">
# </div>
# </div>
# </div>
# </div>
# <div class="hidden" id="hidden-content">
# <iframe aria-hidden="true" class="tweet-post-iframe" name="tweet-post-iframe"></iframe>
# <iframe aria-hidden="true" class="dm-post-iframe" name="dm-post-iframe"></iframe>
# </div>
# <input class="json-data" id="init-data" type="hidden" value='{"keyboardShortcuts":[{"name":"Acciones","description":"Atajos para acciones comunes.","shortcuts":[{"keys":["Enter"],"description":"Abrir detalles del Tweet"},{"keys":["o"],"description":"Expandir foto"},{"keys":["\/"],"description":"Buscar"}]},{"name":"Navegaci\u00f3n","description":"Atajos para navegar entre elementos en las cronolog\u00edas.","shortcuts":[{"keys":["?"],"description":"Este men\u00fa"},{"keys":["j"],"description":"Siguiente Tweet"},{"keys":["k"],"description":"Tweet anterior"},{"keys":["Space"],"description":"Desplazar hacia abajo"},{"keys":["."],"description":"Cargar Tweets nuevos"}]},{"name":"Cronolog\u00edas","description":"Atajos para navegar a diferentes cronolog\u00edas o p\u00e1ginas.","shortcuts":[{"keys":["g","u"],"description":"Ir al usuario\u2026"}]}],"baseFoucClass":"swift-loading","bodyFoucClassNames":"swift-loading","assetsBasePath":"https:\/\/abs.twimg.com\/a\/1574716928\/","assetVersionKey":"9acc6c","emojiAssetsPath":"https:\/\/abs.twimg.com\/emoji\/v2\/72x72\/","environment":"production","formAuthenticityToken":"786d2c6a824242172cdaccc26e65a5cd3d1b10c1","loggedIn":false,"screenName":null,"fullName":null,"userId":null,"guestId":"157537927165881906","createdAt":null,"needsPhoneVerification":false,"allowAdsPersonalization":true,"scribeBufferSize":3,"pageName":"profile","sectionName":"profile","scribeParameters":{},"recaptchaApiUrl":"https:\/\/www.google.com\/recaptcha\/api\/js\/recaptcha_ajax.js","internalReferer":null,"geoEnabled":false,"typeaheadData":{"accounts":{"enabled":true,"localQueriesEnabled":false,"remoteQueriesEnabled":true,"limit":6},"trendLocations":{"enabled":true},"dmConversations":{"enabled":false},"followedSearches":{"enabled":false},"savedSearches":{"enabled":false,"items":[]},"dmAccounts":{"enabled":false,"localQueriesEnabled":false,"remoteQueriesEnabled":false,"onlyDMable":true},"mediaTagAccounts":{"enabled":false,"localQueriesEnabled":false,"remoteQueriesEnabled":false,"onlyShowUsersWithCanMediaTag":false,"currentUserId":-1},"selectedUsers":{"enabled":false},"prefillUsers":{"enabled":false},"topics":{"enabled":true,"localQueriesEnabled":false,"remoteQueriesEnabled":true,"prefetchLimit":500,"limit":4},"concierge":{"enabled":false,"localQueriesEnabled":false,"remoteQueriesEnabled":false,"prefetchLimit":500,"limit":6},"recentSearches":{"enabled":false},"hashtags":{"enabled":false,"localQueriesEnabled":false,"remoteQueriesEnabled":true,"prefetchLimit":500},"useIndexedDB":false,"showSearchAccountSocialContext":false,"showDebugInfo":false,"useThrottle":true,"accountsOnTop":false,"remoteDebounceInterval":300,"remoteThrottleInterval":300,"tweetContextEnabled":false,"fullNameMatchingInCompose":true,"topicsWithFiltersEnabled":false},"shellReferrer":null,"rwebOptInCookieName":"rweb_optin","rwebOptInCookieNewValue":"on","dm":{"notifications":false,"usePushForNotifications":false,"participant_max":50,"welcome_message_add_to_conversation_enabled":true,"poll_options":{"foreground_poll_interval":3000,"burst_poll_interval":3000,"burst_poll_duration":300000,"max_poll_interval":60000},"card_prefetch":true,"card_prefetch_interval_in_seconds":2000,"dm_quick_reply_options_panel_dismiss_in_ms":2000,"open_dm_enabled":false},"autoplayDisabled":false,"pushStatePageLimit":500000,"routes":{"profile":"\/"},"pushState":true,"viewContainer":"#page-container","href":"\/cordeiro","searchPathWithQuery":"\/search?q=query&amp;src=typd","composeAltText":false,"night_mode_activated":false,"user_color":null,"deciders":{"gdprAgeGateDialog":true,"gdprSoftBounceDialog":true,"geo_picker_incident_reset":true,"custom_timeline_curation":false,"native_notifications":true,"disable_ajax_datatype_default_to_text":false,"dm_polling_frequency_in_seconds":3000,"dm_granular_mute_controls":true,"enable_media_tag_prefetch":true,"enableMacawNymizerConversionLanding":false,"hqImageUploads":false,"live_pipeline_consume":true,"mqImageUploads":false,"partnerIdSyncEnabled": ...
# <input class="swift-boot-module" type="hidden" value="app/pages/profile/highline_landing"/>
# <input id="swift-module-path" type="hidden" value="https://abs.twimg.com/k/swift/es"/>
# <script async="" src="https://abs.twimg.com/k/es/init.es.60f58fd3186b2e398094.js"></script>
# </body>
# </html>

# %%
def start(username = None):

    url = "http://www.twitter.com/" + username
    print("\n\nDownloading tweets for " + username)
    response = None
    
    try:
        response = requests.get(url)
    
    except Exception as e:
        print(repr(e))
        sys.exit(1)
    
    if response.status_code != 200:
        print("Non success status code returned "+str(response.status_code))
        sys.exit(1)

    soup = BeautifulSoup(response.text, 'lxml')

    if soup.find("div", {"class": "errorpage-topbar"}):
        print("\n\n Error: Invalid username.")
        sys.exit(1)

    tweets = get_tweets_data(username, soup)


def get_tweet_text(tweet):
    #tweet_text_box = tweet.find("p", {"class": "TweetTextSize TweetTextSize--normal js-tweet-text tweet-text"})
    tweet_text_box = tweet.find("p", {"class": "tweet-text"})
    images_in_tweet_tag = tweet_text_box.find_all("a", {"class": "twitter-timeline-link u-hidden"})
    tweet_text = tweet_text_box.text
    for image_in_tweet_tag in images_in_tweet_tag:
        tweet_text = tweet_text.replace(image_in_tweet_tag.text, '')

    return tweet_text  
    
    
def get_this_page_tweets(soup):
    tweets_list = list()
    tweets = soup.find_all("li", {"data-item-type": "tweet"})

    for tweet in tweets:
        tweet_data = None
        try:
            tweet_data = get_tweet_text(tweet)
        except Exception as e:
            continue
            #ignore if there is any loading or tweet error

        if tweet_data:
            tweets_list.append(tweet_data)
            #forcing printing by flushing the buffer
            print(".", end="")
            sys.stdout.flush()
    print("\n")
    return tweets_list


def get_tweets_data(username, soup):
    tweets_list = list()
    tweets_list.extend(get_this_page_tweets(soup))
    pprint(tweets_list)

# %%
start('cordeiro')
# Out:
# Downloading tweets for cordeiro
# ....................
#
# ['UNIBES, BRASIL: #AMorteDaMorte #LaMuertedeLaMuerte #TheDeathOfDeath '
#  '@UnibesOficial @UnibesCultural @singularityu @HumanityPlus @cordeiro '
#  '@josephteperman '
#  'https://www.facebook.com/UnibesCultural/videos/425508464750335/\xa0…',
#  'Y que esperábamos si a la mayoría de nuestros alumnos excelentes les tenemos '
#  'aburridos desmotivados y acosados en la escuela gracias a una malentendida '
#  'inclusión que les hace ir a todos al mismo ritmo: superdotados, '
#  'discapacitados, por edades. Ridiculo',
#  'PRAÇA DA ALEGRIA, PORTUGAL: #AMorteDaMorte #LaMuerteDeLaMuerte '
#  '#TheDeathOfDeath no Portugal @RTP1 @rtppt @cordeiro',
#  'PORTO, PORTUGAL: Segunda-feira, 2 de dezembro, 18h30 #AMorteDaMorte '
#  '#LaMuerteDeLaMuerte #TheDeathOfDeath @portoio @RTP1 @MillenniumProj '
#  '@singularityu @HumanityPlus @cordeiro @visitportugal',
#  'HEALTHY MASTERS, PORTUGAL: #TheDeathOfDeath #LaMuerteDeLaMuerte '
#  '#AMorteDaMorte @cordeiro @portoio @HumanityPlus @MillenniumProj '
#  '@singularityu '
#  'https://www.facebook.com/healthymasters/photos/a.704007513123422/1159588400898662/?type=3&theater\xa0'
#  '…',
#  'EL UNIVERSAL, VENEZUELA: !Dolarización ya! @ElUniversal @EUEconomia '
#  '@EUPolitica @EUCaracas #Dolarizacion #DolarizarYA #DolarizacionYA',
#  'Para los que creen que haciendo constituciones nuevas a cada ratico llevarán '
#  'a los países al desarrollo, típico error latinoamericano.\n'
#  '\n'
#  'Alerta #Chile  (y toda Latinoamérica), no se dejen embaucar.\n'
#  '\n'
#  'Del libro "La segunda muerte de Bolívar" de @cordeiro editado por @CEDICE ',
#  'PORTO, PORTUGAL: Segunda-feira, 2 de dezembro, 18h30 #AMorteDaMorte '
#  '#LaMuerteDeLaMuerte #TheDeathOfDeath @portoio @RTP1 @cordeiro @visitportugal',
#  'HEALTHY MASTERS, PORTUGAL: #AMorteDaMorte #LaMuerteDeLaMuerte '
#  '#TheDeathOfDeath Saturday November 30, Sunday December 1, Porto, Portugal \n'
#  '@cordeiro @visitportugal @RTP1',
#  'HEALTHY MASTERS, PORTUGAL: #AMorteDaMorte #LaMuerteDeLaMuerte '
#  '#TheDeathOfDeath Saturday November 30, Sunday December 1, Porto, Portugal '
#  '@cordeiro @visitportugal',
#  'EUROPEAN COMMISSION, BRUSSELS: study on building and piloting a strategic '
#  'intelligence foresight system for future research and innovation (R&I) '
#  'framework programmes at the @EU_Commission @MillenniumProj @cordeiro '
#  '@JeromeCGlenn',
#  'HIGHER SCHOOL OF ECONOMICS, RUSSIA: Foresight and STI Policy @cordeiro '
#  '@ibonzugasti @higherschoolE '
#  'https://issek.hse.ru/mirror/pubs/share/direct/318619554\xa0…',
#  'Форсайт и научно-техническая и инновационная политика, Росси́я: IX '
#  'Международная научная конференция\n'
#  ' #TheDeathOfDeath\n'
#  '@cordeiro',
#  'Бессмертие / IMMORTALITY, Москва / MOSCOW: #TheDeathOfDeath @cordeiro '
#  '@dmedvedev @MikhailBatin @singularityu @USTranshumanist @HumanityPlus '
#  'https://www.facebook.com/events/569237797161634/\xa0…',
#  'HIGHER SCHOOL OF ECONOMICS, RUSSIA: Foresight and STI Policy, November '
#  '20-22, @cordeiro @ibonzugasti @higherschoolE #TheDeathOfDeath',
#  'Бессмертие / IMMORTALITY, Москва / MOSCOW: 22 ноября 20:00–22:00, '
#  'Садовническая набережная, 9, #TheDeathOfDeath @cordeiro @dmedvedev @He11ya',
#  'DIARIO PROGRESISTA, ESPAÑA: La Asociación Española de la Singularidad '
#  'organiza hoy lunes una conferencia de la conocida María Estraigues-Abramson '
#  'sobre alargamiento de la vida @AntonioMiguelC @aesingularidad @aubreydegrey '
#  '@cordeiro #LaMuerteDeLaMuerte',
#  'MADRID SINGULARITY, ESPAÑA: Por que debemos acabar con la vejez, lunes 18 de '
#  'octubre, 7:00pm, @aesingularidad @AntonioMiguelC @aubreydegrey @cordeiro '
#  '#LaMuerteDeLaMuerte',
#  'МОСКВА, РОССИЯ: пятница, 22 ноября, 20:00 - 22:00, Бессмертие @cordeiro '
#  '@MoscowTimes @singularityu #Immortality #Singularity #TheDeathOfDeath',
#  'EL UNIVERSAL, VALENCIA: ¿Es estratégico el petróleo? @cordeiro @ElUniversal '
#  '@EUPolitica @EUEconomia @EUCaracas #LaMuerteDeLaMuerte']

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code    
def get_movie_data(soup):
    movie_data = list()
    movies_list = list()
    count = 0
    
    print("Scrapping ",url,"page")
    
    movies = soup.find_all("td", {"class": "titleColumn"})
    
    for movie in movies:
        movie_data = None
        try:
            movie_data = get_movie_text(movie)
            
        except Exception as e:
            continue
            #ignore if there is any loading or movie error

        if movie_data:
            movies_list.extend(movie_data)
            #forcing the printing of the "." by flushing the buffer. One point for every input
            print(".", end="")
            sys.stdout.flush()
            count +=1
        
        if count == 250: #Maximum of 250 movies scrapped
            break
    
    return movies_list

def get_movie_text(movie):
    movie_text = list()
    
    title = str((movie.find("a")).text).strip()
    release = str((movie.find('span',{'class','secondaryInfo'})).text).strip()
    director = str(movie.find("a")['title']).strip().split("(dir.), ")[0]
    stars = str(movie.find("a")['title']).strip().split("(dir.), ")[1]

    movie_text.append([title,release,director,stars])
    
    return movie_text  

def movies_scrap():    
    try:
        response = requests.get(url) 
    except Exception as e:
        print(repr(e))
        sys.exit(1)
    
    if response.status_code != 200:
        print("Non success status code returned "+str(response.status_code))
        sys.exit(1)

    soup = BeautifulSoup(response.text, 'lxml')

    if soup.find("a", {"class": "titleColumn"}):
        print("\n\n Error: Invalid page.")
        sys.exit(1)

    movies_list = get_movie_data(soup)

    df = pd.DataFrame(movies_list,columns=['TITLE','RELEASE','DIRECTOR','STARS'])
    df.index += 1
    
    return df

# %%
df = movies_scrap()
df.head()
# Out:
# Scrapping  http://www.imdb.com/chart/top page
# ..........................................................................................................................................................................................................................................................
#                    TITLE RELEASE               DIRECTOR  \
# 1        Cadena perpetua  (1994)        Frank Darabont
# 2             El padrino  (1972)  Francis Ford Coppola
# 3   El padrino: Parte II  (1974)  Francis Ford Coppola
# 4    El caballero oscuro  (2008)     Christopher Nolan
# 5  12 hombres sin piedad  (1957)          Sidney Lumet
#
#                           STARS
# 1   Tim Robbins, Morgan Freeman
# 2      Marlon Brando, Al Pacino
# 3     Al Pacino, Robert De Niro
# 4  Christian Bale, Heath Ledger
# 5      Henry Fonda, Lee J. Cobb

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code
# your code    
def get_movie_data(soup):
    movie_data = list()
    movies_list = list()
    
    print("Scrapping ",url,"page")
    
    movies = soup.find_all("td", {"class": "titleColumn"})
    
    for movie in movies:
        movie_data = None
        try:
            movie_data = get_movie_text(movie)
            
        except Exception as e:
            continue
            #ignore if there is any loading or movie error

        if movie_data:
            movies_list.extend(movie_data)
            #forcing the printing of the "." by flushing the buffer. One point for every input
            print(".", end="")
            sys.stdout.flush()
        
    return movies_list



def get_movie_text(movie):
    movie_text = list()
    
    title = str((movie.find("a")).text).strip()
    release = str((movie.find('span',{'class','secondaryInfo'})).text).strip()
    
    href= "http://www.imdb.com" + movie.find("a")['href']
    brief= brief_scrap(href)  

    movie_text.append([title,director,brief])
    
    return movie_text  

def movies_scrap():    
    try:
        response = requests.get(url) 
    except Exception as e:
        print(repr(e))
        sys.exit(1)
    
    if response.status_code != 200:
        print("Non success status code returned "+str(response.status_code))
        sys.exit(1)

    soup = BeautifulSoup(response.text, 'lxml')

    if soup.find("a", {"class": "titleColumn"}):
        print("\n\n Error: Invalid page.")
        sys.exit(1)

    movies_list = get_movie_data(soup)

    df = pd.DataFrame(movies_list,columns=['TITLE','RELEASE','BRIEF'])
    df.index += 1
    
    return df




def brief_scrap(url_brief):    
    try:
        response = requests.get(url_brief) 
    except Exception as e:
        print(repr(e))
        sys.exit(1)
    
    if response.status_code != 200:
        print("Non success status code returned "+str(response.status_code))
        sys.exit(1)

    soup_brief = BeautifulSoup(response.text, 'lxml')

    if soup.find("a", {"class": "titleColumn"}):
        print("\n\n Error: Invalid page.")
        sys.exit(1)

    movie_brief = get_movie_brief(soup_brief)
    
    return movie_brief


def get_movie_brief(soup_brief):
    brief = movie.find("div",{'class',"summary_text"}).text

    return brief

def get_movie_brief(soup_brief):
    movie_data = list()
    movies_list = list()
    
    print("Scrapping ",url,"page")
    
    movies = soup.find_all("td", {"class": "titleColumn"})
    
    for movie in movies:
        movie_data = None
        try:
            movie_data = get_movie_text(movie)
            
        except Exception as e:
            continue
            #ignore if there is any loading or movie error

        if movie_data:
            movies_list.extend(movie_data)
            #forcing the printing of the "." by flushing the buffer. One point for every input
            print(".", end="")
            sys.stdout.flush()
        
    return movies_list

# %%
df = movies_scrap()
df.head(10)
# Out:
# Scrapping  http://www.imdb.com/chart/top page
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-182-47bb27f6b213> in <module>
# ----> 1 df = movies_scrap()
#       2 df.head(10)
#
# <ipython-input-181-4d4930cae03d> in movies_scrap()
#     109         sys.exit(1)
#     110
# --> 111     movies_list = get_movie_data(soup)
#     112
#     113     df = pd.DataFrame(movies_list,columns=['TITLE','RELEASE','BRIEF'])
#
# <ipython-input-181-4d4930cae03d> in get_movie_data(soup)
#      12         movie_data = None
#      13         try:
# ---> 14             movie_data = get_movie_text(movie)
#      15
#      16         except Exception as e:
#
# <ipython-input-181-4d4930cae03d> in get_movie_text(movie)
#      58
#      59     href= "http://www.imdb.com" + movie.find("a")['href']
# ---> 60     brief= brief_scrap(href)
#      61
#      62     movie_text.append([title,director,brief])
#
# <ipython-input-181-4d4930cae03d> in brief_scrap(url_brief)
#      75         sys.exit(1)
#      76
# ---> 77     soup_brief = BeautifulSoup(response.text, 'lxml')
#      78
#      79     if soup.find("a", {"class": "titleColumn"}):
#
# /usr/local/lib/python3.7/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     279             self.reset()
#     280             try:
# --> 281                 self._feed()
#     282                 break
#     283             except ParserRejectedMarkup:
#
# /usr/local/lib/python3.7/site-packages/bs4/__init__.py in _feed(self)
#     340         self.builder.reset()
#     341
# --> 342         self.builder.feed(self.markup)
#     343         # Close out any unfinished strings and close all the open tags.
#     344         self.endData()
#
# /usr/local/lib/python3.7/site-packages/bs4/builder/_lxml.py in feed(self, markup)
#     285         try:
#     286             self.parser = self.parser_for(encoding)
# --> 287             self.parser.feed(markup)
#     288             self.parser.close()
#     289         except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed()
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxTargetStartNoNs()
#
# src/lxml/saxparser.pxi in lxml.etree._callTargetSaxStart()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# /usr/local/lib/python3.7/site-packages/bs4/builder/_lxml.py in start(self, name, attrs, nsmap)
#     176     def start(self, name, attrs, nsmap={}):
#     177         # Make sure attrs is a mutable dict--lxml may send an immutable dictproxy.
# --> 178         attrs = dict(attrs)
#     179         nsprefix = None
#     180         # Invert each namespace map as it comes in.
#
# KeyboardInterrupt:

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/Cellar/ipython/7.3.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# /usr/local/Cellar/ipython/7.3.0/libexec/vendor/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/Cellar/ipython/7.3.0/libexec/vendor/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     466         """
# --> 467         parts = [self.recv(flags, copy=copy, track=track)]
#     468         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/Cellar/ipython/7.3.0/libexec/vendor/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-784a0b919997> in <module>
#       1 #https://openweathermap.org/current
# ----> 2 city = city=input('Enter the city:')
#       3 url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'
#
# /usr/local/Cellar/ipython/7.3.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# /usr/local/Cellar/ipython/7.3.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
