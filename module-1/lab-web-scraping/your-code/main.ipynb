# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
#### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# This is the url you will scrape in this exercise
URL_DEVELOPERS = 'https://github.com/trending/developers'

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
URL_DEVELOPERS = 'https://github.com/trending/developers'

#your code
#search for   <a class="js-selected-navigation-item selected tabnav-tab" aria-current="page" data-selected-links="trending_developers /trending/developers" href="/trending/developers">Developers</a>
response = requests.get(URL_DEVELOPERS)
soup = BeautifulSoup(response.text, "html.parser")

# %%
developers_cont = soup.find_all('article',{'class','Box-row d-flex'})
print(developers_cont)
# Out:
# [<article class="Box-row d-flex" id="pa-kripken">
# <a class="text-gray f6 text-center" href="#pa-kripken" style="width: 16px;">
#     1
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=173661" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/kripken"><img alt="@kripken" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/173661?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/kripken">
#             Alon Zakai
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/kripken">
#               kripken
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/kripken/sql.js" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       sql.js
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       SQLite compiled to JavaScript through Emscripten
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-klauspost">
# <a class="text-gray f6 text-center" href="#pa-klauspost" style="width: 16px;">
#     2
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=5663952" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/klauspost"><img alt="@klauspost" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/5663952?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/klauspost">
#             Klaus Post
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/klauspost">
#               klauspost
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/klauspost/compress" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       compress
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Optimized compression packages
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-siddontang">
# <a class="text-gray f6 text-center" href="#pa-siddontang" style="width: 16px;">
#     3
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=1080370" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/siddontang"><img alt="@siddontang" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/1080370?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/siddontang">
#             siddontang
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/siddontang">
#               siddontang
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/siddontang/ledisdb" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       ledisdb
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       a high performance NoSQL powered by Go
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-knqyf263">
# <a class="text-gray f6 text-center" href="#pa-knqyf263" style="width: 16px;">
#     4
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=2253692" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/knqyf263"><img alt="@knqyf263" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/2253692?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/knqyf263">
#             Teppei Fukuda
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/knqyf263">
#               knqyf263
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/knqyf263/pet" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       pet
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Simple command-line snippet manager, written in Go.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-jstedfast">
# <a class="text-gray f6 text-center" href="#pa-jstedfast" style="width: 16px;">
#     5
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=338984" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/jstedfast"><img alt="@jstedfast" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/338984?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/jstedfast">
#             Jeffrey Stedfast
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/jstedfast">
#               jstedfast
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/jstedfast/MailKit" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       MailKit
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A cross-platform .NET library for IMAP, POP3, and SMTP.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-cpu">
# <a class="text-gray f6 text-center" href="#pa-cpu" style="width: 16px;">
#     6
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=292650" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/cpu"><img alt="@cpu" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/292650?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/cpu">
#             Daniel McCarney
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/cpu">
#               cpu
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/cpu/PromGuard" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       PromGuard
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Prometheus scraping over WireGuard: Example Terraform/Ansible for fully authenticated/encrypted stat scraping
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-piotrwitek">
# <a class="text-gray f6 text-center" href="#pa-piotrwitek" style="width: 16px;">
#     7
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=739075" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/piotrwitek"><img alt="@piotrwitek" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/739075?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/piotrwitek">
#             Piotrek Witek
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/piotrwitek">
#               piotrwitek
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/piotrwitek/react-redux-typescript-guide" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       react-redux-typescript-guide
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       The complete guide to static typing in "React &amp; Redux" apps using TypeScript
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-killme2008">
# <a class="text-gray f6 text-center" href="#pa-killme2008" style="width: 16px;">
#     8
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=14142" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/killme2008"><img alt="@killme2008" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/14142?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/killme2008">
#             dennis zhuang
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/killme2008">
#               killme2008
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/killme2008/aviator" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       aviator
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A high performance expression evaluator for java
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-pomber">
# <a class="text-gray f6 text-center" href="#pa-pomber" style="width: 16px;">
#     9
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=1911623" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/pomber"><img alt="@pomber" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/1911623?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/pomber">
#             Rodrigo Pombo
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/pomber">
#               pomber
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/pomber/git-history" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       git-history
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Quickly browse the history of a file from any git repository
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-seregazhuk">
# <a class="text-gray f6 text-center" href="#pa-seregazhuk" style="width: 16px;">
#     10
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=9959761" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/seregazhuk"><img alt="@seregazhuk" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/9959761?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/seregazhuk">
#             Sergey Zhuk
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/seregazhuk">
#               seregazhuk
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/seregazhuk/php-pinterest-bot" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       php-pinterest-bot
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       This PHP library will help you to work with your Pinterest account without using any API account credentials.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-samuela">
# <a class="text-gray f6 text-center" href="#pa-samuela" style="width: 16px;">
#     11
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=226872" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/samuela"><img alt="@samuela" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/226872?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/samuela">
#             samuela
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/samuela">
#               samuela
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/samuela/rustybox" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       rustybox
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A free-range, non-GMO fork of busybox in 100% Rust <g-emoji alias="crab" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f980.png">🦀</g-emoji>
# </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-saghul">
# <a class="text-gray f6 text-center" href="#pa-saghul" style="width: 16px;">
#     12
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=317464" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/saghul"><img alt="@saghul" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/317464?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/saghul">
#             Saúl Ibarra Corretgé
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/saghul">
#               saghul
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/saghul/pyuv" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       pyuv
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Python interface for libuv
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-bflad">
# <a class="text-gray f6 text-center" href="#pa-bflad" style="width: 16px;">
#     13
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=189114" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/bflad"><img alt="@bflad" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/189114?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/bflad">
#             Brian Flad
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/bflad">
#               bflad
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/bflad/chef-stash" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       chef-stash
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Chef Cookbook for Atlassian Stash
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-chrisbanes">
# <a class="text-gray f6 text-center" href="#pa-chrisbanes" style="width: 16px;">
#     14
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=227486" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/chrisbanes"><img alt="@chrisbanes" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/227486?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/chrisbanes">
#             Chris Banes
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/chrisbanes">
#               chrisbanes
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/chrisbanes/PhotoView" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       PhotoView
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Implementation of ImageView for Android that supports zooming, by various touch gestures.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-fitzgen">
# <a class="text-gray f6 text-center" href="#pa-fitzgen" style="width: 16px;">
#     15
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=74571" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/fitzgen"><img alt="@fitzgen" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/74571?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/fitzgen">
#             Nick Fitzgerald
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/fitzgen">
#               fitzgen
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/fitzgen/wu.js" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       wu.js
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       wu.js is a JavaScript library providing higher order functions for ES6 iterators.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-wenzhixin">
# <a class="text-gray f6 text-center" href="#pa-wenzhixin" style="width: 16px;">
#     16
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=2117018" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/wenzhixin"><img alt="@wenzhixin" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/2117018?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/wenzhixin">
#             文翼
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/wenzhixin">
#               wenzhixin
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/wenzhixin/bootstrap-table" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       bootstrap-table
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       An extended table to integration with some of the most widely used CSS frameworks. (Supports Bootstrap, Semantic UI, Bulma, Material Design, Foundation, Vue.js)
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-Keats">
# <a class="text-gray f6 text-center" href="#pa-Keats" style="width: 16px;">
#     17
# </a>
# <div class="mx-3">
# ...
#
#       J-I-C
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       J I C is a Javascript Image Compressor using HTML5 Canvas &amp; File API that allows you to compress your jpeg &amp; png images before uploading to the server (100% client-side and no extra libraries required!)
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-palkan">
# <a class="text-gray f6 text-center" href="#pa-palkan" style="width: 16px;">
#     21
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=1516722" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/palkan"><img alt="@palkan" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/1516722?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/palkan">
#             Vladimir Dementyev
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/palkan">
#               palkan
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/palkan/test-prof" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       test-prof
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Ruby Tests Profiling Toolbox
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-nschloe">
# <a class="text-gray f6 text-center" href="#pa-nschloe" style="width: 16px;">
#     22
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=181628" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/nschloe"><img alt="@nschloe" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/181628?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/nschloe">
#             Nico Schlömer
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/nschloe">
#               nschloe
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/nschloe/tikzplotlib" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       tikzplotlib
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Convert matplotlib figures to TikZ/PGFplots for smooth integration into LaTeX.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-anoadragon453">
# <a class="text-gray f6 text-center" href="#pa-anoadragon453" style="width: 16px;">
#     23
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=1342360" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/anoadragon453"><img alt="@anoadragon453" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/1342360?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/anoadragon453">
#             Andrew Morgan
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/anoadragon453">
#               anoadragon453
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/anoadragon453/ZeroLSTN" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       ZeroLSTN
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A p2p music streaming website
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-brson">
# <a class="text-gray f6 text-center" href="#pa-brson" style="width: 16px;">
#     24
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=147214" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/brson"><img alt="@brson" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/147214?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/brson">
#             Brian Anderson
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/brson">
#               brson
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/brson/stdx" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       stdx
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       The missing batteries of Rust
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-fatih">
# <a class="text-gray f6 text-center" href="#pa-fatih" style="width: 16px;">
#     25
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=438920" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/fatih"><img alt="@fatih" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/438920?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/fatih">
#             Fatih Arslan
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/fatih">
#               fatih
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/fatih/vim-go" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       vim-go
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Go development plugin for Vim
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"A065:8042:26E2592:3A84679:5DD18971","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="5c6e6cd1549ce898b543b6f6a4ba20cd5fc469ea662b908829e2196415e591cb" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>]

# %%
developers_info = [developers_cont[i]['id'].replace("pa-","") for i in range(len(developers_cont))]

pprint(developers_info)
# Out:
# ['kripken',
#  'klauspost',
#  'siddontang',
#  'knqyf263',
#  'jstedfast',
#  'cpu',
#  'piotrwitek',
#  'killme2008',
#  'pomber',
#  'seregazhuk',
#  'samuela',
#  'saghul',
#  'bflad',
#  'chrisbanes',
#  'fitzgen',
#  'wenzhixin',
#  'Keats',
#  'jshjohnson',
#  'clue',
#  'brunobar79',
#  'palkan',
#  'nschloe',
#  'anoadragon453',
#  'brson',
#  'fatih']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
URL_REPOSITORIES = 'https://github.com/trending/python?since=daily'

# %%
#your code
response = requests.get(URL_REPOSITORIES)
soup = BeautifulSoup(response.text, "html.parser")
"""
repositories_cont = soup.find_all('div', {'class', 'd-inline-block col-9 mb-1'})
#print(repositories_cont)

repositorie_list = [repositorie.text.replace('\n',"").replace('/',"/ Repositorie: ") for repositorie in repositories_cont]
pprint(repositorie_list)
"""

repositories_cont = soup.find_all('h1',{'class',"h3 lh-condensed"})


repositories_info = [repositories_cont[i].find('a')['href'] for i in range(len(repositories_cont))]
pprint(repositories_info)
# Out:
# ['/dragen1860/Deep-Learning-with-TensorFlow-book',
#  '/modin-project/modin',
#  '/ct-Open-Source/tuya-convert',
#  '/python/cpython',
#  '/ddbourgin/numpy-ml',
#  '/openai/gym',
#  '/swisskyrepo/PayloadsAllTheThings',
#  '/PeterWang512/FALdetector',
#  '/keras-team/keras',
#  '/axi0mX/ipwndfu',
#  '/Yelp/clusterman',
#  '/deezer/spleeter',
#  '/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi',
#  '/harismuneer/Ultimate-Facebook-Scraper',
#  '/deepfakes/faceswap',
#  '/XX-net/XX-Net',
#  '/django/django',
#  '/foosel/OctoPrint',
#  '/30-seconds/30-seconds-of-python',
#  '/deepjyoti30/ytmdl',
#  '/deepdrive/deepdrive',
#  '/zalandoresearch/fashion-mnist',
#  '/jiangxufeng/v2rayL',
#  '/quantopian/zipline',
#  '/aboul3la/Sublist3r']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
URL_WALTDISNEY = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
response = requests.get(URL_WALTDISNEY)
soup = BeautifulSoup(response.text, "html.parser")

images_cont = soup.find_all('img')

source = ["https:"+images.get('src') for images in images_cont]
pprint(source)
# Out:
# ['https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg/220px-Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/15/Disney_drawing_goofy.jpg/170px-Disney_drawing_goofy.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/13/DisneySchiphol1951.jpg/220px-DisneySchiphol1951.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/WaltDisneyplansDisneylandDec1954.jpg/220px-WaltDisneyplansDisneylandDec1954.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Walt_disney_portrait_right.jpg/170px-Walt_disney_portrait_right.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Walt_Disney_Grave.JPG/170px-Walt_Disney_Grave.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Roy_O._Disney_with_Company_at_Press_Conference.jpg/170px-Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Disney_Display_Case.JPG/170px-Disney_Display_Case.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Disney1968.jpg/170px-Disney1968.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/The_Walt_Disney_Company_Logo.svg/120px-The_Walt_Disney_Company_Logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Animation_disc.svg/30px-Animation_disc.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/6/69/P_vip.svg/29px-P_vip.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Magic_Kingdom_castle.jpg/24px-Magic_Kingdom_castle.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Video-x-generic.svg/30px-Video-x-generic.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a3/Flag_of_Los_Angeles_County%2C_California.svg/30px-Flag_of_Los_Angeles_County%2C_California.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Blank_television_set.svg/30px-Blank_television_set.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/30px-Flag_of_the_United_States.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/22px-Commons-logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/25px-Wikiquote-logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/30px-Wikidata-logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  'https://en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1',
#  'https:/static/images/wikimedia-button.png',
#  'https:/static/images/poweredby_mediawiki_88x31.png']

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
URL_PYTHON ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
linksPython = []

response = requests.get(URL_PYTHON)
soup = BeautifulSoup(response.text, "html.parser")

links = soup.find_all('a')
linksPython = [link.get('href') for link in links]
print("These are all kind of links on this page: \n",linksPython)
# Out:
# These are all kind of links on this page:
#  [None, '#mw-head', '#p-search', 'https://en.wiktionary.org/wiki/Python', 'https://en.wiktionary.org/wiki/python', '#Snakes', '#Ancient_Greece', '#Media_and_entertainment', '#Computing', '#Engineering', '#Roller_coasters', '#Vehicles', '#Weaponry', '#People', '#Other_uses', '#See_also', '/w/index.php?title=Python&action=edit&section=1', '/wiki/Pythonidae', '/wiki/Python_(genus)', '/w/index.php?title=Python&action=edit&section=2', '/wiki/Python_(mythology)', '/wiki/Python_of_Aenus', '/wiki/Python_(painter)', '/wiki/Python_of_Byzantium', '/wiki/Python_of_Catana', '/w/index.php?title=Python&action=edit&section=3', '/wiki/Python_(film)', '/wiki/Pythons_2', '/wiki/Monty_Python', '/wiki/Python_(Monty)_Pictures', '/w/index.php?title=Python&action=edit&section=4', '/wiki/Python_(programming_language)', '/wiki/CPython', '/wiki/CMU_Common_Lisp', '/wiki/PERQ#PERQ_3', '/w/index.php?title=Python&action=edit&section=5', '/w/index.php?title=Python&action=edit&section=6', '/wiki/Python_(Busch_Gardens_Tampa_Bay)', '/wiki/Python_(Coney_Island,_Cincinnati,_Ohio)', '/wiki/Python_(Efteling)', '/w/index.php?title=Python&action=edit&section=7', '/wiki/Python_(automobile_maker)', '/wiki/Python_(Ford_prototype)', '/w/index.php?title=Python&action=edit&section=8', '/wiki/Colt_Python', '/wiki/Python_(missile)', '/wiki/Python_(nuclear_primary)', '/w/index.php?title=Python&action=edit&section=9', '/wiki/Python_Anghelo', '/w/index.php?title=Python&action=edit&section=10', '/wiki/PYTHON', '/w/index.php?title=Python&action=edit&section=11', '/wiki/Cython', '/wiki/Pyton', '/wiki/File:Disambig_gray.svg', '/wiki/Help:Disambiguation', 'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Python&namespace=0', 'https://en.wikipedia.org/w/index.php?title=Python&oldid=924004650', '/wiki/Help:Category', '/wiki/Category:Disambiguation_pages', '/wiki/Category:Disambiguation_pages_with_short_description', '/wiki/Category:All_article_disambiguation_pages', '/wiki/Category:All_disambiguation_pages', '/wiki/Category:Animal_common_name_disambiguation_pages', '/wiki/Special:MyTalk', '/wiki/Special:MyContributions', '/w/index.php?title=Special:CreateAccount&returnto=Python', '/w/index.php?title=Special:UserLogin&returnto=Python', '/wiki/Python', '/wiki/Talk:Python', '/wiki/Python', '/w/index.php?title=Python&action=edit', '/w/index.php?title=Python&action=history', '/wiki/Main_Page', '/wiki/Main_Page', '/wiki/Wikipedia:Contents', '/wiki/Portal:Featured_content', '/wiki/Portal:Current_events', '/wiki/Special:Random', 'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en', '//shop.wikimedia.org', '/wiki/Help:Contents', '/wiki/Wikipedia:About', '/wiki/Wikipedia:Community_portal', '/wiki/Special:RecentChanges', '//en.wikipedia.org/wiki/Wikipedia:Contact_us', '/wiki/Special:WhatLinksHere/Python', '/wiki/Special:RecentChangesLinked/Python', '/wiki/Wikipedia:File_Upload_Wizard', '/wiki/Special:SpecialPages', '/w/index.php?title=Python&oldid=924004650', '/w/index.php?title=Python&action=info', 'https://www.wikidata.org/wiki/Special:EntityPage/Q747452', '/w/index.php?title=Special:CiteThisPage&page=Python&id=924004650', 'https://commons.wikimedia.org/wiki/Category:Python', '/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Python', '/w/index.php?title=Special:ElectronPdf&page=Python&action=show-download-screen', '/w/index.php?title=Python&printable=yes', 'https://af.wikipedia.org/wiki/Python', 'https://als.wikipedia.org/wiki/Python', 'https://az.wikipedia.org/wiki/Python', 'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)', 'https://be.wikipedia.org/wiki/Python', 'https://bg.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%BF%D0%BE%D1%8F%D1%81%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5)', 'https://cs.wikipedia.org/w ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
URL_CODE = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
count_codes = 0
input_codes = []

response = requests.get(URL_CODE)
soup = BeautifulSoup(response.text, "html.parser")

#print(soup)
uscitem_container = soup.find_all('div', {'class', 'uscitem'})#
#pprint(uscitem_container[:4])

for index, uscitem in enumerate(uscitem_container):
    #print(uscitem.text.find('Appendix'))
    if (index != 0 and uscitem.text.find('Appendix') == -1): #reject first item and all with text containing "Appendix"
        input_codes.append(uscitem.text.replace('\n','').replace('[XML]\xa0[XHTML]\xa0[PCC]\xa0[PDF]','').replace('[XML]\xa0','').replace('116-21',''))
        count_codes += 1
    
print("The total number of versions is ",count_codes)
pprint(input_codes[:9])
# Out:
# The total number of versions is  54
# ['          Title 1 - General Provisions ٭          116-68        ',
#  '          Title 2 - The Congress                  116-68        ',
#  '          Title 3 - The President ٭          116-68        ',
#  '          Title 4 - Flag and Seal, Seat of Government, and the States '
#  '٭          116-68        ',
#  '          Title 5 - Government Organization and Employees ٭          '
#  '116-68        ',
#  '          Title 6 - Domestic Security                  116-68        ',
#  '          Title 7 - Agriculture                  116-68        ',
#  '          Title 8 - Aliens and Nationality                  116-68        ',
#  '          Title 9 - Arbitration ٭          116-68        ']

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
URL_FBI = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
response = requests.get(URL_FBI)
soup = BeautifulSoup(response.text, "html.parser")

#print(soup)
wanted_container = soup.find_all('li', {'class', 'portal-type-person castle-grid-block-item'})#

items = [lines.find('h3', {'class','title'}) for lines in wanted_container]
list_of_wanteds = [wanted.text.replace('\n','') for wanted in items]

print("Top 10 most FBI wanted:\n", list_of_wanteds)
# Out:
# Top 10 most FBI wanted:
#  ['YASER ABDEL SAID', 'JASON DEREK BROWN', 'ALEXIS FLORES', 'EUGENE PALMER', 'SANTIAGO VILLALBA MEDEROS', 'RAFAEL CARO-QUINTERO', 'ROBERT WILLIAM FISHER', 'BHADRESHKUMAR CHETANBHAI PATEL', 'ARNOLDO JIMENEZ', 'ALEJANDRO ROSALES CASTILLO']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
URL_EARTHQUAKE = 'https://www.emsc-csem.org/Earthquake/'

# %%
# data is where the final information will be store
#Every td label has a datum, some positions are useful (3,4,6 and 11)
#Thus, we have to jump 13 positions till next useful datums
#jump allow to jump till the correct index, and them record the datum

data = []
temp = []
jump = 0
    
response = requests.get(URL_EARTHQUAKE)
soup = BeautifulSoup(response.text, 'html.parser')
container = soup.find('tbody',{'id':'tbody'})

readings = container.find_all('td') 

for index,reading in enumerate(readings):
    if(index == 3+jump):
        temp.append(reading.text[10:20])
        temp.append(reading.text[23:31])
    if(index == 4+jump):
        temp.append(reading.text.replace('\xa0',''))
    if(index == 6+jump):
        temp.append(reading.text.replace('\xa0',''))
    if(index == 11+jump):   
        temp.append(reading.text.replace('\xa0',''))
        jump+=13
        data.append(temp[0:5])
        temp = []

earthquake_df = pd.DataFrame(data, columns=['Date', 'Time', 'Lat', 'Long', 'Region'])
earthquake_df.head(20)
# Out:
#           Date      Time    Lat    Long                         Region
# 0   2019-11-17  17:21:17   9.31  123.19  NEGROS- CEBU REG, PHILIPPINES
# 1   2019-11-17  17:14:23  37.04   23.08                SOUTHERN GREECE
# 2   2019-11-17  17:02:25  36.03  117.32             CENTRAL CALIFORNIA
# 3   2019-11-17  16:48:11  12.91   88.65           OFFSHORE EL SALVADOR
# 4   2019-11-17  16:47:38   3.33  127.11    KEPULAUAN TALAUD, INDONESIA
# 5   2019-11-17  16:42:09   1.69  126.33                    MOLUCCA SEA
# 6   2019-11-17  16:41:16   4.52  140.62               PAPUA, INDONESIA
# 7   2019-11-17  16:39:45  21.71   69.98             ANTOFAGASTA, CHILE
# 8   2019-11-17  16:38:50  13.43  167.90                        VANUATU
# 9   2019-11-17  16:28:38  41.62   32.65                 CENTRAL TURKEY
# 10  2019-11-17  16:28:30  37.06  104.93                       COLORADO
# 11  2019-11-17  16:15:43  17.83  101.53               GUERRERO, MEXICO
# 12  2019-11-17  16:09:23  19.20  155.41       ISLAND OF HAWAII, HAWAII
# 13  2019-11-17  16:06:38  19.18  155.43       ISLAND OF HAWAII, HAWAII
# 14  2019-11-17  15:04:53  28.85   71.49        OFFSHORE ATACAMA, CHILE
# 15  2019-11-17  14:40:42  40.84   21.35                         GREECE
# 16  2019-11-17  14:39:08  32.65    4.32                        MOROCCO
# 17  2019-11-17  14:37:56  19.19  155.45       ISLAND OF HAWAII, HAWAII
# 18  2019-11-17  14:34:27  19.22  155.43       ISLAND OF HAWAII, HAWAII
# 19  2019-11-17  14:33:54  45.72   26.74                        ROMANIA

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
URL_HACKATHON ='https://hackevents.co/hackathons'
URL_CONSTRUCTOR = 'https://hackevents.co'

# %%
# All nesserary information about events should be gathered from the links of the events
# Thus, we find the lines that start with "/event", them we get the link stored in the label
# href in order to build the correct url adding the URL_CONSTRUCTOR (the root url)
# Them we have to interate through the correct links, and get the data

data = []
links = []
    
response = requests.get(URL_HACKATHON)
soup = BeautifulSoup(response.text, 'html.parser')
containers = soup.find_all('a')

# loop to get the links for all events
for container in containers:
    if (container.get('href')[0:6] == '/event'):
        links.append(URL_CONSTRUCTOR + container.get('href'))

# loop to scrap every event page
for link in links:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    container = soup.find('div',{'class','row'})

    #title
    title = container.find('h2').text
    
    #the rest of the datums
    datums = container.find_all('p')
    
    city = datums[0].text.replace('\u2003 ','').split(',')[0]        
    country = datums[0].text.replace('\u2003 ','').split(',')[2] 
    start_date = datums[1].text.split(' ')[-1]
    start_day = int(start_date.split('/')[1])

    end_date = datums[2].text.split(' ')[-1] 
    end_day = int(end_date.split('/')[1])
    gape = end_day - start_day
    days = [start_day+day for day in range(gape+1)]
    
    data.append([start_day,days,title,city,country])

hackathons_df = pd.DataFrame(data, columns=['start_day', 'days', 'title', 'city', 'country'])
hackathons_df.head(25)
# Out:
# Empty DataFrame
# Columns: [start_day, days, title, city, country]
# Index: []

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
URL_TWITTER_CONSTRUCTOR = 'https://twitter.com/'

# %%
import tweepy
import twitter

from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from twitter import Twitter, OAuth
from tweepy import OAuthHandler



# Authentication
key = '77IFGcGHEKVTjFt2AF5tDs3nF'
key_secret = '1uUq6LKES6MsZr7UMWrSCfuKhdC0M458ec47CnJ5YpOoQ0BRTH'
token = '1180090135372861442-9YMk9w6MY55AgvjJqn0pLraGJzNguR'
token_secret = '6VjEEFQZvjixJ34bpVo8r6NcWYmHBqtrhM5EwI7AAfVG5'
 
auth = OAuthHandler(key, key_secret)
auth.set_access_token(token, token_secret)
api = tweepy.API(auth)

# Read tweets from user
name = 'cordeiro'

count=0

# Using "Cursor" we can reed more than 200 tweets, the limit 3200
try:
    for tweet in tweepy.Cursor(api.user_timeline, id=name).items():
        #print(tweet.text,"\n")
        count+=1
    print("Total tweets:", count)
    
except:
    print("An exception occurred. The user does not exist")
# Out:
# Total tweets: 1156

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
import tweepy
import twitter

from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from twitter import Twitter, OAuth
from tweepy import OAuthHandler


# Authentication
key = '77IFGcGHEKVTjFt2AF5tDs3nF'
key_secret = '1uUq6LKES6MsZr7UMWrSCfuKhdC0M458ec47CnJ5YpOoQ0BRTH'
token = '1180090135372861442-9YMk9w6MY55AgvjJqn0pLraGJzNguR'
token_secret = '6VjEEFQZvjixJ34bpVo8r6NcWYmHBqtrhM5EwI7AAfVG5'
 
auth = OAuthHandler(key, key_secret)
auth.set_access_token(token, token_secret)
api = tweepy.API(auth)

# target to be check
account = 'cordeiro'

ids = []

# Using "Cursor" we can reed more than 200 tweets, the limit 3200
try:
    for page in api.followers_ids(screen_name=account):
        ids.append(page)

    print("Total folowers:", len(ids))
    
except:
    print("An exception occurred. The user does not exist")
# Out:
# Total folowers: 3117

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
URL_WIKIPEDIA = 'https://www.wikipedia.org/'

# %%
#your code
# All nesserary information about events should be gathered from the links of the events
# Thus, we find the lines that start with "/event", them we get the link stored in the label
# href in order to build the correct url adding the URL_CONSTRUCTOR (the root url)
# Them we have to interate through the correct links, and get the data

data = []
links = []
    
response = requests.get(URL_WIKIPEDIA)
soup = BeautifulSoup(response.text, 'html.parser')

#container = soup.find_all('div',{'class','central-featured'})
container = soup.find_all('a',{'class','link-box'})

for item in container:
    language=item.find("strong")
    print(language.text)
    article=item.find("small")
    pos=article.text.find('+')
    print(article.text[:pos])
# Out:
# English
# 5 964 000
# EspaÃ±ol
# 1 554 000
# æ¥æ¬èª
# 1 175 000
# Deutsch
# 2 361 000
# Ð ÑÑÑÐºÐ¸Ð¹
# 1 576 000
# FranÃ§ais
# 2 152 000
# Italiano
# 1 562 000
# ä¸­æ
# 1 080 000
# PortuguÃªs
# 1 014 000
# Polski
# 1 367 000

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
URL_DATAGOVUK = 'https://data.gov.uk/'

# %%
#your code 
data = []
links = []
    
response = requests.get(URL_DATAGOVUK)
soup = BeautifulSoup(response.text, 'html.parser')

#container = soup.find_all('div',{'class','central-featured'})
container = soup.find_all('div',{'class','column-one-third'})

#print(container)
receptacle= [framework.find_all('a') for framework in container]
pprint(receptacle)

"""links = soup.find_all('a')
linksPython = [link.get('href') for link in links]"""


links = [link.find('href') for link in receptacle]

# for link in container:
#     print(link.find("a").get('href'))
# Out:
# [[<a href="/search?filters%5Btopic%5D=Business+and+economy">Business and economy</a>,
#   <a href="/search?filters%5Btopic%5D=Crime+and+justice">Crime and justice</a>,
#   <a href="/search?filters%5Btopic%5D=Defence">Defence</a>,
#   <a href="/search?filters%5Btopic%5D=Education">Education</a>],
#  [<a href="/search?filters%5Btopic%5D=Environment">Environment</a>,
#   <a href="/search?filters%5Btopic%5D=Government">Government</a>,
#   <a href="/search?filters%5Btopic%5D=Government+spending">Government spending</a>,
#   <a href="/search?filters%5Btopic%5D=Health">Health</a>],
#  [<a href="/search?filters%5Btopic%5D=Mapping">Mapping</a>,
#   <a href="/search?filters%5Btopic%5D=Society">Society</a>,
#   <a href="/search?filters%5Btopic%5D=Towns+and+cities">Towns and cities</a>,
#   <a href="/search?filters%5Btopic%5D=Transport">Transport</a>]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-5e707bbac0b0> in <module>
#      17
#      18
# ---> 19 links = [link.find('href') for link in receptacle]
#      20
#      21 # for link in container:
#
# <ipython-input-125-5e707bbac0b0> in <listcomp>(.0)
#      17
#      18
# ---> 19 links = [link.find('href') for link in receptacle]
#      20
#      21 # for link in container:
#
# /usr/local/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
