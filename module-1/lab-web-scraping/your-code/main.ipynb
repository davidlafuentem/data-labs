# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
#### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# This is the url you will scrape in this exercise
URL_DEVELOPERS = 'https://github.com/trending/developers'

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
URL_DEVELOPERS = 'https://github.com/trending/developers'

#your code
#search for   <a class="js-selected-navigation-item selected tabnav-tab" aria-current="page" data-selected-links="trending_developers /trending/developers" href="/trending/developers">Developers</a>
response = requests.get(URL_DEVELOPERS)
soup = BeautifulSoup(response.text, "html.parser")

# %%
developers_cont = soup.find_all('article',{'class','Box-row d-flex'})
print(developers_cont)
# Out:
# [<article class="Box-row d-flex" id="pa-phil-opp">
# <a class="text-gray f6 text-center" href="#pa-phil-opp" style="width: 16px;">
#     1
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/phil-opp/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/phil-opp"><img alt="@phil-opp" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/1131315?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/phil-opp">
#             Philipp Oppermann
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/phil-opp">
#               phil-opp
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/phil-opp/blog_os" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       blog_os
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Writing an OS in Rust
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="mr-2">
# <a class="btn btn-sm btn-block" href="/sponsors/phil-opp">
# <svg aria-label="heart" class="octicon octicon-heart icon-sponsor v-align-middle" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12"><path d="M9 2c-.97 0-1.69.42-2.2 1-.51.58-.78.92-.8 1-.02-.08-.28-.42-.8-1-.52-.58-1.17-1-2.2-1-1.632.086-2.954 1.333-3 3 0 .52.09 1.52.67 2.67C1.25 8.82 3.01 10.61 6 13c2.98-2.39 4.77-4.17 5.34-5.33C11.91 6.51 12 5.5 12 5c-.047-1.69-1.342-2.913-3-3z" fill-rule="evenodd"></path></svg>
# <span class="ml-1">
#               Sponsor
# </span>
# </a>
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-philipperemy">
# <a class="text-gray f6 text-center" href="#pa-philipperemy" style="width: 16px;">
#     2
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/philipperemy/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/philipperemy"><img alt="@philipperemy" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/4516927?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/philipperemy">
#             Philippe Rémy
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/philipperemy">
#               philipperemy
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/philipperemy/keras-attention-mechanism" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       keras-attention-mechanism
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Attention mechanism Implementation for Keras.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-chrisbanes">
# <a class="text-gray f6 text-center" href="#pa-chrisbanes" style="width: 16px;">
#     3
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/chrisbanes/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/chrisbanes"><img alt="@chrisbanes" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/227486?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/chrisbanes">
#             Chris Banes
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/chrisbanes">
#               chrisbanes
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/chrisbanes/PhotoView" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       PhotoView
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Implementation of ImageView for Android that supports zooming, by various touch gestures.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-pranshuchittora">
# <a class="text-gray f6 text-center" href="#pa-pranshuchittora" style="width: 16px;">
#     4
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/pranshuchittora/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/pranshuchittora"><img alt="@pranshuchittora" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/32242596?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/pranshuchittora">
#             Pranshu Chittora
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/pranshuchittora">
#               pranshuchittora
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/pranshuchittora/autarky" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       autarky
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Liberating disk space from <g-emoji alias="file_folder" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f4c1.png">📁</g-emoji> node_modules
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-neuecc">
# <a class="text-gray f6 text-center" href="#pa-neuecc" style="width: 16px;">
#     5
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/neuecc/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/neuecc"><img alt="@neuecc" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/46207?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/neuecc">
#             Yoshifumi Kawai
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/neuecc">
#               neuecc
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/neuecc/UniRx" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       UniRx
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Reactive Extensions for Unity
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-fzaninotto">
# <a class="text-gray f6 text-center" href="#pa-fzaninotto" style="width: 16px;">
#     6
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/fzaninotto/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/fzaninotto"><img alt="@fzaninotto" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/99944?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/fzaninotto">
#             Francois Zaninotto
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/fzaninotto">
#               fzaninotto
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/fzaninotto/Faker" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       Faker
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Faker is a PHP library that generates fake data for you
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-jsternberg">
# <a class="text-gray f6 text-center" href="#pa-jsternberg" style="width: 16px;">
#     7
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/jsternberg/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/jsternberg"><img alt="@jsternberg" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/1212129?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/jsternberg">
#             Jonathan A. Sternberg
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/jsternberg">
#               jsternberg
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/jsternberg/ansible-agent" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       ansible-agent
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Alternative Ansible Transport
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-carllerche">
# <a class="text-gray f6 text-center" href="#pa-carllerche" style="width: 16px;">
#     8
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/carllerche/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/carllerche"><img alt="@carllerche" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/6180?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/carllerche">
#             Carl Lerche
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/carllerche">
#               carllerche
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/carllerche/tower-web" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       tower-web
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A fast, boilerplate free, web framework for Rust
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-manucorporat">
# <a class="text-gray f6 text-center" href="#pa-manucorporat" style="width: 16px;">
#     9
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/manucorporat/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/manucorporat"><img alt="@manucorporat" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/127379?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/manucorporat">
#             Manu MA
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/manucorporat">
#               manucorporat
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/manucorporat/sse" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       sse
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Server-Sent Events implementation in Go. Used by the Gin Framework.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-sdispater">
# <a class="text-gray f6 text-center" href="#pa-sdispater" style="width: 16px;">
#     10
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/sdispater/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/sdispater"><img alt="@sdispater" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/555648?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/sdispater">
#             Sébastien Eustace
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/sdispater">
#               sdispater
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/sdispater/poetry" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       poetry
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Python dependency management and packaging made easy.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-benoitc">
# <a class="text-gray f6 text-center" href="#pa-benoitc" style="width: 16px;">
#     11
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/benoitc/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/benoitc"><img alt="@benoitc" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/14498?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/benoitc">
#             Benoit Chesneau
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/benoitc">
#               benoitc
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/benoitc/gunicorn" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       gunicorn
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       gunicorn 'Green Unicorn' is a WSGI HTTP Server for UNIX, fast clients and sleepy applications.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-jdauphant">
# <a class="text-gray f6 text-center" href="#pa-jdauphant" style="width: 16px;">
#     12
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/jdauphant/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/jdauphant"><img alt="@jdauphant" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/1238254?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/jdauphant">
#             Julien DAUPHANT
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/jdauphant">
#               jdauphant
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/jdauphant/awesome-ansible" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       awesome-ansible
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A collaborative curated list of awesome Ansible resources
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-gcanti">
# <a class="text-gray f6 text-center" href="#pa-gcanti" style="width: 16px;">
#     13
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/gcanti/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/gcanti"><img alt="@gcanti" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/878912?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/gcanti">
#             Giulio Canti
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/gcanti">
#               gcanti
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/gcanti/tcomb-form-native" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       tcomb-form-native
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Forms library for react-native
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-rimusz">
# <a class="text-gray f6 text-center" href="#pa-rimusz" style="width: 16px;">
#     14
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/rimusz/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/rimusz"><img alt="@rimusz" class="rounded-1" height="48" src="https://avatars1.githubusercontent.com/u/5215395?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/rimusz">
#             Rimas Mocevicius
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/rimusz">
#               rimusz
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/rimusz/helm-tiller" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       helm-tiller
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Helm v2 Tiller plugin aka Tillerless Helm
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-arturbosch">
# <a class="text-gray f6 text-center" href="#pa-arturbosch" style="width: 16px;">
#     15
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/arturbosch/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/arturbosch"><img alt="@arturbosch" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/20924106?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/arturbosch">
#             Artur Bosch
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/arturbosch">
#               arturbosch
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/arturbosch/detekt" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       detekt
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Static code analysis for Kotlin
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-kevinpapst">
# <a class="text-gray f6 text-center" href="#pa-kevinpapst" style="width: 16px;">
#     16
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/kevinpapst/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/kevinpapst"><img alt="@kevinpapst" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/533162?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/kevinpapst">
#             Kevin Papst
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/kevinpapst">
#               kevinpapst
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/kevinpapst/kimai2" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       kimai2
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Kimai v2 is a web-based multiuser time-tracking application. Free for everyone: freelancers, agencies and companies track their employee working-times and generate invoices.
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="mr-2">
# <a class="btn btn-sm btn-block" href="/sponsors/kevinpapst">
# ...
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-jonahwilliams">
# <a class="text-gray f6 text-center" href="#pa-jonahwilliams" style="width: 16px;">
#     21
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/jonahwilliams/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/jonahwilliams"><img alt="@jonahwilliams" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/8975114?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/jonahwilliams">
#             Jonah Williams
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/jonahwilliams">
#               jonahwilliams
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/jonahwilliams/json_widget" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       json_widget
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Compile time conversion from json to widgets (For some reason...)
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-mitchellh">
# <a class="text-gray f6 text-center" href="#pa-mitchellh" style="width: 16px;">
#     22
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/mitchellh/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/mitchellh"><img alt="@mitchellh" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/1299?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/mitchellh">
#             Mitchell Hashimoto
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/mitchellh">
#               mitchellh
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/mitchellh/gox" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       gox
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       A dead simple, no frills Go cross compile tool
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-schmittjoh">
# <a class="text-gray f6 text-center" href="#pa-schmittjoh" style="width: 16px;">
#     23
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/schmittjoh/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/schmittjoh"><img alt="@schmittjoh" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/197017?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/schmittjoh">
#             Johannes
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/schmittjoh">
#               schmittjoh
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/schmittjoh/serializer" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       serializer
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       Library for (de-)serializing data of any complexity (supports JSON, and XML)
#     </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-mattn">
# <a class="text-gray f6 text-center" href="#pa-mattn" style="width: 16px;">
#     24
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/mattn/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/mattn"><img alt="@mattn" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/10111?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/mattn">
#             mattn
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/mattn">
#               mattn
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/mattn/emmet-vim" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       emmet-vim
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       emmet for vim: <a href="http://emmet.io/" rel="nofollow">http://emmet.io/</a>
# </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="mr-2">
# <a class="btn btn-sm btn-block" href="/sponsors/mattn">
# <svg aria-label="heart" class="octicon octicon-heart icon-sponsor v-align-middle" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12"><path d="M9 2c-.97 0-1.69.42-2.2 1-.51.58-.78.92-.8 1-.02-.08-.28-.42-.8-1-.52-.58-1.17-1-2.2-1-1.632.086-2.954 1.333-3 3 0 .52.09 1.52.67 2.67C1.25 8.82 3.01 10.61 6 13c2.98-2.39 4.77-4.17 5.34-5.33C11.91 6.51 12 5.5 12 5c-.047-1.69-1.342-2.913-3-3z" fill-rule="evenodd"></path></svg>
# <span class="ml-1">
#               Sponsor
# </span>
# </a>
# </div>
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>, <article class="Box-row d-flex" id="pa-alecthomas">
# <a class="text-gray f6 text-center" href="#pa-alecthomas" style="width: 16px;">
#     25
# </a>
# <div class="mx-3">
# <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/users/alecthomas/hovercard" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/alecthomas"><img alt="@alecthomas" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/41767?s=96&amp;v=4" width="48"/></a>
# </div>
# <div class="d-sm-flex flex-auto">
# <div class="col-sm-8 d-md-flex">
# <div class="col-md-6">
# <h1 class="h3 lh-condensed">
# <a href="/alecthomas">
#             Alec Thomas
# </a>
# </h1>
# <p class="f4 text-normal mb-1">
# <a class="link-gray" href="/alecthomas">
#               alecthomas
# </a>
# </p>
# </div>
# <div class="col-md-6">
# <div class="mt-2 mb-3 my-md-0">
# <article>
# <div class="f6 text-gray text-uppercase mb-1"><svg aria-hidden="true" class="octicon octicon-flame text-orange-light mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M5.05.31c.81 2.17.41 3.38-.52 4.31C3.55 5.67 1.98 6.45.9 7.98c-1.45 2.05-1.7 6.53 3.53 7.7-2.2-1.16-2.67-4.52-.3-6.61-.61 2.03.53 3.33 1.94 2.86 1.39-.47 2.3.53 2.27 1.67-.02.78-.31 1.44-1.13 1.81 3.42-.59 4.78-3.42 4.78-5.56 0-2.84-2.53-3.22-1.25-5.61-1.52.13-2.03 1.13-1.89 2.75.09 1.08-1.02 1.8-1.86 1.33-.67-.41-.66-1.19-.06-1.78C8.18 5.31 8.68 2.45 5.05.32L5.03.3l.02.01z" fill-rule="evenodd"></path></svg>Popular repo</div>
# <h1 class="h4 lh-condensed">
# <a class="css-truncate css-truncate-target" data-ga-click="Explore, go to repository, location:trending developers" href="/alecthomas/gometalinter" style="max-width: 175px;">
# <svg aria-hidden="true" class="octicon octicon-repo text-gray mr-1" height="16" version="1.1" viewbox="0 0 12 16" width="12"><path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd"></path></svg>
#
#       gometalinter
#     </a>
# </h1>
# <div class="f6 text-gray mt-1">
#       DEPRECATED: Use <a href="https://github.com/golangci/golangci-lint">https://github.com/golangci/golangci-lint</a>
# </div>
# </article>
# </div>
# </div>
# </div>
# <div class="col-sm-4 d-flex flex-sm-justify-end ml-sm-3">
# <div class="user-profile-following-container">
# <div class="user-following-container">
# <span class="user-following-container">
# <span class="follow">
# <a class="btn btn-sm btn-block" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"follow button","repository_id":null,"auth_type":"LOG_IN","client_id":null,"originating_request_id":"7D3E:1E602:1AE566F:27FFF25:5DDE7375","originating_url":"https://github.com/trending/developers","referrer":null,"user_id":null}}' data-hydro-click-hmac="cba0be854c8564f65376ef7f614e500622f6cbd24508535e945fc9980f073061" href="/login?return_to=%2Ftrending%2Fdevelopers">Follow</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </article>]

# %%
developers_info = [developers_cont[i]['id'].replace("pa-","") for i in range(len(developers_cont))]

pprint(developers_info)
# Out:
# ['phil-opp',
#  'philipperemy',
#  'chrisbanes',
#  'pranshuchittora',
#  'neuecc',
#  'fzaninotto',
#  'jsternberg',
#  'carllerche',
#  'manucorporat',
#  'sdispater',
#  'benoitc',
#  'jdauphant',
#  'gcanti',
#  'rimusz',
#  'arturbosch',
#  'kevinpapst',
#  'ornicar',
#  'vis2k',
#  'cpu',
#  'aelsabbahy',
#  'jonahwilliams',
#  'mitchellh',
#  'schmittjoh',
#  'mattn',
#  'alecthomas']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
URL_REPOSITORIES = 'https://github.com/trending/python?since=daily'

# %%
#your code
response = requests.get(URL_REPOSITORIES)
soup = BeautifulSoup(response.text, "html.parser")
"""
repositories_cont = soup.find_all('div', {'class', 'd-inline-block col-9 mb-1'})
#print(repositories_cont)

repositorie_list = [repositorie.text.replace('\n',"").replace('/',"/ Repositorie: ") for repositorie in repositories_cont]
pprint(repositorie_list)
"""

repositories_cont = soup.find_all('h1',{'class',"h3 lh-condensed"})


repositories_info = [repositories_cont[i].find('a')['href'] for i in range(len(repositories_cont))]
pprint(repositories_info)
# Out:
# ['/luka1199/geo-heatmap',
#  '/huggingface/transformers',
#  '/testerSunshine/12306',
#  '/sunainapai/makesite',
#  '/microsoft/nni',
#  '/bokeh/bokeh',
#  '/tensorflow/models',
#  '/readthedocs/readthedocs.org',
#  '/facebookresearch/SlowFast',
#  '/harismuneer/Ultimate-Facebook-Scraper',
#  '/OpenMined/PySyft',
#  '/edx/edx-platform',
#  '/demisto/content',
#  '/allenai/allennlp',
#  '/cloud-custodian/cloud-custodian',
#  '/jupyterhub/zero-to-jupyterhub-k8s',
#  '/pypa/setuptools',
#  '/Kozea/WeasyPrint',
#  '/samuelcolvin/pydantic',
#  '/elastic/elasticsearch-dsl-py',
#  '/anchore/anchore-engine',
#  '/aws/sagemaker-python-sdk',
#  '/matterport/Mask_RCNN',
#  '/yunjey/pytorch-tutorial',
#  '/davidsandberg/facenet']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
URL_WALTDISNEY = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
response = requests.get(URL_WALTDISNEY)
soup = BeautifulSoup(response.text, "html.parser")

images_cont = soup.find_all('img')

source = ["https:"+images.get('src') for images in images_cont]
pprint(source)
# Out:
# ['https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg/220px-Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/15/Disney_drawing_goofy.jpg/170px-Disney_drawing_goofy.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/13/DisneySchiphol1951.jpg/220px-DisneySchiphol1951.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/WaltDisneyplansDisneylandDec1954.jpg/220px-WaltDisneyplansDisneylandDec1954.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Walt_disney_portrait_right.jpg/170px-Walt_disney_portrait_right.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Walt_Disney_Grave.JPG/170px-Walt_Disney_Grave.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Roy_O._Disney_with_Company_at_Press_Conference.jpg/170px-Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Disney_Display_Case.JPG/170px-Disney_Display_Case.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Disney1968.jpg/170px-Disney1968.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/The_Walt_Disney_Company_Logo.svg/120px-The_Walt_Disney_Company_Logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Animation_disc.svg/30px-Animation_disc.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/6/69/P_vip.svg/29px-P_vip.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Magic_Kingdom_castle.jpg/24px-Magic_Kingdom_castle.jpg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Video-x-generic.svg/30px-Video-x-generic.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a3/Flag_of_Los_Angeles_County%2C_California.svg/30px-Flag_of_Los_Angeles_County%2C_California.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Blank_television_set.svg/30px-Blank_television_set.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/30px-Flag_of_the_United_States.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/22px-Commons-logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/25px-Wikiquote-logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/30px-Wikidata-logo.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  'https://en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1',
#  'https:/static/images/wikimedia-button.png',
#  'https:/static/images/poweredby_mediawiki_88x31.png']

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
URL_PYTHON ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
linksPython = []

response = requests.get(URL_PYTHON)
soup = BeautifulSoup(response.text, "html.parser")

links = soup.find_all('a')
linksPython = [link.get('href') for link in links]
print("These are all kind of links on this page: \n",linksPython)
# Out:
# These are all kind of links on this page:
#  [None, '#mw-head', '#p-search', 'https://en.wiktionary.org/wiki/Python', 'https://en.wiktionary.org/wiki/python', '#Snakes', '#Ancient_Greece', '#Media_and_entertainment', '#Computing', '#Engineering', '#Roller_coasters', '#Vehicles', '#Weaponry', '#People', '#Other_uses', '#See_also', '/w/index.php?title=Python&action=edit&section=1', '/wiki/Pythonidae', '/wiki/Python_(genus)', '/w/index.php?title=Python&action=edit&section=2', '/wiki/Python_(mythology)', '/wiki/Python_of_Aenus', '/wiki/Python_(painter)', '/wiki/Python_of_Byzantium', '/wiki/Python_of_Catana', '/w/index.php?title=Python&action=edit&section=3', '/wiki/Python_(film)', '/wiki/Pythons_2', '/wiki/Monty_Python', '/wiki/Python_(Monty)_Pictures', '/w/index.php?title=Python&action=edit&section=4', '/wiki/Python_(programming_language)', '/wiki/CPython', '/wiki/CMU_Common_Lisp', '/wiki/PERQ#PERQ_3', '/w/index.php?title=Python&action=edit&section=5', '/w/index.php?title=Python&action=edit&section=6', '/wiki/Python_(Busch_Gardens_Tampa_Bay)', '/wiki/Python_(Coney_Island,_Cincinnati,_Ohio)', '/wiki/Python_(Efteling)', '/w/index.php?title=Python&action=edit&section=7', '/wiki/Python_(automobile_maker)', '/wiki/Python_(Ford_prototype)', '/w/index.php?title=Python&action=edit&section=8', '/wiki/Colt_Python', '/wiki/Python_(missile)', '/wiki/Python_(nuclear_primary)', '/w/index.php?title=Python&action=edit&section=9', '/wiki/Python_Anghelo', '/w/index.php?title=Python&action=edit&section=10', '/wiki/PYTHON', '/w/index.php?title=Python&action=edit&section=11', '/wiki/Cython', '/wiki/Pyton', '/wiki/File:Disambig_gray.svg', '/wiki/Help:Disambiguation', 'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Python&namespace=0', 'https://en.wikipedia.org/w/index.php?title=Python&oldid=927409302', '/wiki/Help:Category', '/wiki/Category:Disambiguation_pages', '/wiki/Category:Disambiguation_pages_with_short_description', '/wiki/Category:All_article_disambiguation_pages', '/wiki/Category:All_disambiguation_pages', '/wiki/Category:Animal_common_name_disambiguation_pages', '/wiki/Special:MyTalk', '/wiki/Special:MyContributions', '/w/index.php?title=Special:CreateAccount&returnto=Python', '/w/index.php?title=Special:UserLogin&returnto=Python', '/wiki/Python', '/wiki/Talk:Python', '/wiki/Python', '/w/index.php?title=Python&action=edit', '/w/index.php?title=Python&action=history', '/wiki/Main_Page', '/wiki/Main_Page', '/wiki/Wikipedia:Contents', '/wiki/Portal:Featured_content', '/wiki/Portal:Current_events', '/wiki/Special:Random', 'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en', '//shop.wikimedia.org', '/wiki/Help:Contents', '/wiki/Wikipedia:About', '/wiki/Wikipedia:Community_portal', '/wiki/Special:RecentChanges', '//en.wikipedia.org/wiki/Wikipedia:Contact_us', '/wiki/Special:WhatLinksHere/Python', '/wiki/Special:RecentChangesLinked/Python', '/wiki/Wikipedia:File_Upload_Wizard', '/wiki/Special:SpecialPages', '/w/index.php?title=Python&oldid=927409302', '/w/index.php?title=Python&action=info', 'https://www.wikidata.org/wiki/Special:EntityPage/Q747452', '/w/index.php?title=Special:CiteThisPage&page=Python&id=927409302', 'https://commons.wikimedia.org/wiki/Category:Python', '/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Python', '/w/index.php?title=Special:ElectronPdf&page=Python&action=show-download-screen', '/w/index.php?title=Python&printable=yes', 'https://af.wikipedia.org/wiki/Python', 'https://als.wikipedia.org/wiki/Python', 'https://az.wikipedia.org/wiki/Python', 'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)', 'https://be.wikipedia.org/wiki/Python', 'https://bg.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%BF%D0%BE%D1%8F%D1%81%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5)', 'https://cs.wikipedia.org/w ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
URL_CODE = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
count_codes = 0
input_codes = []

response = requests.get(URL_CODE)
soup = BeautifulSoup(response.text, "html.parser")

#print(soup)
uscitem_container = soup.find_all('div', {'class', 'uscitem'})#
#pprint(uscitem_container[:4])

for index, uscitem in enumerate(uscitem_container):
    #print(uscitem.text.find('Appendix'))
    if (index != 0 and uscitem.text.find('Appendix') == -1): #reject first item and all with text containing "Appendix"
        input_codes.append(uscitem.text.replace('\n','').replace('[XML]\xa0[XHTML]\xa0[PCC]\xa0[PDF]','').replace('[XML]\xa0','').replace('116-21',''))
        count_codes += 1
    
print("The total number of versions is ",count_codes)
pprint(input_codes[:9])
# Out:
# The total number of versions is  54
# ['          Title 1 - General Provisions ٭          116-68u1        ',
#  '          Title 2 - The Congress                  116-68u1        ',
#  '          Title 3 - The President ٭          116-68u1        ',
#  '          Title 4 - Flag and Seal, Seat of Government, and the States '
#  '٭          116-68u1        ',
#  '          Title 5 - Government Organization and Employees ٭          '
#  '116-68u1        ',
#  '          Title 6 - Domestic Security                  116-68u1        ',
#  '          Title 7 - Agriculture                  116-68u1        ',
#  '          Title 8 - Aliens and Nationality                  116-68u1        ',
#  '          Title 9 - Arbitration ٭          116-68u1        ']

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
URL_FBI = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
response = requests.get(URL_FBI)
soup = BeautifulSoup(response.text, "html.parser")

#print(soup)
wanted_container = soup.find_all('li', {'class', 'portal-type-person castle-grid-block-item'})#

items = [lines.find('h3', {'class','title'}) for lines in wanted_container]
list_of_wanteds = [wanted.text.replace('\n','') for wanted in items]

print("Top 10 most FBI wanted:\n", list_of_wanteds)
# Out:
# Top 10 most FBI wanted:
#  ['ALEJANDRO ROSALES CASTILLO', 'YASER ABDEL SAID', 'JASON DEREK BROWN', 'ALEXIS FLORES', 'EUGENE PALMER', 'SANTIAGO VILLALBA MEDEROS', 'RAFAEL CARO-QUINTERO', 'ROBERT WILLIAM FISHER', 'BHADRESHKUMAR CHETANBHAI PATEL', 'ARNOLDO JIMENEZ']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
URL_EARTHQUAKE = 'https://www.emsc-csem.org/Earthquake/'

# %%
# data is where the final information will be store
#Every td label has a datum, some positions are useful (3,4,6 and 11)
#Thus, we have to jump 13 positions till next useful datums
#jump allow to jump till the correct index, and them record the datum

data = []
temp = []
jump = 0
    
response = requests.get(URL_EARTHQUAKE)
soup = BeautifulSoup(response.text, 'html.parser')
container = soup.find('tbody',{'id':'tbody'})

readings = container.find_all('td') 

for index,reading in enumerate(readings):
    if(index == 3+jump):
        temp.append(reading.text[10:20])
        temp.append(reading.text[23:31])
    if(index == 4+jump):
        temp.append(reading.text.replace('\xa0',''))
    if(index == 6+jump):
        temp.append(reading.text.replace('\xa0',''))
    if(index == 11+jump):   
        temp.append(reading.text.replace('\xa0',''))
        jump+=13
        data.append(temp[0:5])
        temp = []

earthquake_df = pd.DataFrame(data, columns=['Date', 'Time', 'Lat', 'Long', 'Region'])
earthquake_df.head(20)
# Out:
#           Date      Time    Lat    Long                            Region
# 0   2019-11-27  12:42:08  41.69   19.45                      ADRIATIC SEA
# 1   2019-11-27  12:34:19  19.50  101.35                              LAOS
# 2   2019-11-27  12:04:08  36.76   98.28                          OKLAHOMA
# 3   2019-11-27  12:02:58  41.64   19.55                      ADRIATIC SEA
# 4   2019-11-27  11:53:59   1.44  126.17                       MOLUCCA SEA
# 5   2019-11-27  11:47:52  18.01  105.94      OFF COAST OF JALISCO, MEXICO
# 6   2019-11-27  11:44:06  34.90   97.40                          OKLAHOMA
# 7   2019-11-27  11:32:44  46.90  122.02                        WASHINGTON
# 8   2019-11-27  11:28:21  41.55   19.63                           ALBANIA
# 9   2019-11-27  11:03:36  41.48   19.51                      ADRIATIC SEA
# 10  2019-11-27  10:59:32  41.53   19.58                           ALBANIA
# 11  2019-11-27  10:55:09  41.48   19.44                      ADRIATIC SEA
# 12  2019-11-27  10:46:54  38.62   29.12          AZORES ISLANDS, PORTUGAL
# 13  2019-11-27  10:00:40  22.17  179.47             SOUTH OF FIJI ISLANDS
# 14  2019-11-27  09:59:00  39.75  121.83               NORTHERN CALIFORNIA
# 15  2019-11-27  09:43:39  19.20  155.48          ISLAND OF HAWAII, HAWAII
# 16  2019-11-27  09:41:47  19.24   64.44             VIRGIN ISLANDS REGION
# 17  2019-11-27  09:28:56  37.31   73.71           OFFSHORE BIO-BIO, CHILE
# 18  2019-11-27  09:05:25  41.50   19.47                      ADRIATIC SEA
# 19  2019-11-27  09:04:42   2.60  134.37  NEAR N COAST OF PAPUA, INDONESIA

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
URL_HACKATHON ='https://hackevents.co/hackathons'
URL_CONSTRUCTOR = 'https://hackevents.co'

# %%
# All nesserary information about events should be gathered from the links of the events
# Thus, we find the lines that start with "/event", them we get the link stored in the label
# href in order to build the correct url adding the URL_CONSTRUCTOR (the root url)
# Them we have to interate through the correct links, and get the data

data = []
links = []
    
response = requests.get(URL_HACKATHON)
soup = BeautifulSoup(response.text, 'html.parser')
containers = soup.find_all('a')

# loop to get the links for all events
for container in containers:
    if (container.get('href')[0:6] == '/event'):
        links.append(URL_CONSTRUCTOR + container.get('href'))

# loop to scrap every event page
for link in links:
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    container = soup.find('div',{'class','row'})

    #title
    title = container.find('h2').text
    
    #the rest of the datums
    datums = container.find_all('p')
    
    city = datums[0].text.replace('\u2003 ','').split(',')[0]        
    country = datums[0].text.replace('\u2003 ','').split(',')[2] 
    start_date = datums[1].text.split(' ')[-1]
    start_day = int(start_date.split('/')[1])

    end_date = datums[2].text.split(' ')[-1] 
    end_day = int(end_date.split('/')[1])
    gape = end_day - start_day
    days = [start_day+day for day in range(gape+1)]
    
    data.append([start_day,days,title,city,country])

hackathons_df = pd.DataFrame(data, columns=['start_day', 'days', 'title', 'city', 'country'])
hackathons_df.head(25)
# Out:
# Empty DataFrame
# Columns: [start_day, days, title, city, country]
# Index: []

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
URL_TWITTER_CONSTRUCTOR = 'https://twitter.com/'

# %%
import tweepy
import twitter

from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from twitter import Twitter, OAuth
from tweepy import OAuthHandler



# Authentication
key = '77IFGcGHEKVTjFt2AF5tDs3nF'
key_secret = '1uUq6LKES6MsZr7UMWrSCfuKhdC0M458ec47CnJ5YpOoQ0BRTH'
token = '1180090135372861442-9YMk9w6MY55AgvjJqn0pLraGJzNguR'
token_secret = '6VjEEFQZvjixJ34bpVo8r6NcWYmHBqtrhM5EwI7AAfVG5'
 
auth = OAuthHandler(key, key_secret)
auth.set_access_token(token, token_secret)
api = tweepy.API(auth)

# Read tweets from user
name = 'cordeiro'

count=0

# Using "Cursor" we can reed more than 200 tweets, the limit 3200
try:
    for tweet in tweepy.Cursor(api.user_timeline, id=name).items():
        #print(tweet.text,"\n")
        count+=1
    print("Total tweets:", count)
    
except:
    print("An exception occurred. The user does not exist")
# Out:
# Total tweets: 1163

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
import tweepy
import twitter

from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from twitter import Twitter, OAuth
from tweepy import OAuthHandler


# Authentication
key = '77IFGcGHEKVTjFt2AF5tDs3nF'
key_secret = '1uUq6LKES6MsZr7UMWrSCfuKhdC0M458ec47CnJ5YpOoQ0BRTH'
token = '1180090135372861442-9YMk9w6MY55AgvjJqn0pLraGJzNguR'
token_secret = '6VjEEFQZvjixJ34bpVo8r6NcWYmHBqtrhM5EwI7AAfVG5'
 
auth = OAuthHandler(key, key_secret)
auth.set_access_token(token, token_secret)
api = tweepy.API(auth)

# target to be check
account = 'cordeiro'

ids = []

# Using "Cursor" we can reed more than 200 tweets, the limit 3200
try:
    for page in api.followers_ids(screen_name=account):
        ids.append(page)

    print("Total folowers:", len(ids))
    
except:
    print("An exception occurred. The user does not exist")
# Out:
# Total folowers: 3120

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
URL_WIKIPEDIA = 'https://www.wikipedia.org/'

# %%
#your code
# All nesserary information about events should be gathered from the links of the events
# Thus, we find the lines that start with "/event", them we get the link stored in the label
# href in order to build the correct url adding the URL_CONSTRUCTOR (the root url)
# Them we have to interate through the correct links, and get the data

data = []
links = []
    
response = requests.get(URL_WIKIPEDIA)
soup = BeautifulSoup(response.text, 'html.parser')

#container = soup.find_all('div',{'class','central-featured'})
container = soup.find_all('a',{'class','link-box'})

for item in container:
    language=item.find("strong")
    print(language.text)
    article=item.find("small")
    pos=article.text.find('+')
    print(article.text[:pos])
# Out:
# English
# 5 964 000
# EspaÃ±ol
# 1 554 000
# æ¥æ¬èª
# 1 175 000
# Deutsch
# 2 361 000
# Ð ÑÑÑÐºÐ¸Ð¹
# 1 576 000
# FranÃ§ais
# 2 152 000
# Italiano
# 1 562 000
# ä¸­æ
# 1 080 000
# PortuguÃªs
# 1 014 000
# Polski
# 1 367 000

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
URL_DATAGOVUK = 'https://data.gov.uk'

# %%
#your code 
data = []
links = []

response = requests.get(URL_DATAGOVUK)
soup = BeautifulSoup(response.text, 'html.parser')

container = soup.find_all('div',{'class','column-one-third'})

# There are three "column-one-third", so we go through and concatenate with extend to have a one dimension list
for index, item in enumerate(container):
    data.extend(item.find_all('a'))

links = [URL_DATAGOVUK+item.get('href') for item in data]

pprint(links)
# Out:
# ['https://data.gov.uk/search?filters%5Btopic%5D=Business+and+economy',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Crime+and+justice',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Defence',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Education',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Environment',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Government',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Government+spending',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Health',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Mapping',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Society',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Towns+and+cities',
#  'https://data.gov.uk/search?filters%5Btopic%5D=Transport']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
URL_SPEAKERS = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code
#your code 
data = []
links = []

response = requests.get(URL_SPEAKERS)
soup = BeautifulSoup(response.text, 'html.parser')

container = soup.find_all('tbody')

data = []
data = [item.find_all('a') for item in container]

# Find languages and avoid to get the language family
forget = ['languages','Varieties']
languages = [item.text for item in data[0] \
    if ((str(item.get('href')).find('languages') == -1) \
    and (str(item.get('href')).find('Varieties') == -1) \
    and (str(item.get('href')).find('#') == -1) )]

pprint(languages)
# Out:
# ['Mandarin Chinese',
#  'Spanish',
#  'English',
#  'Hindi',
#  'Hindustani',
#  'Bengali',
#  'Portuguese',
#  'Russian',
#  'Japanese',
#  'Japanese',
#  'Western Punjabi',
#  'Marathi',
#  'Telugu',
#  'Wu Chinese',
#  'Turkish',
#  'Korean',
#  'language isolate',
#  'French',
#  'German',
#  'Vietnamese',
#  'Tamil',
#  'Yue Chinese',
#  'Urdu',
#  'Hindustani',
#  'Javanese',
#  'Italian',
#  'Egyptian Arabic',
#  'Gujarati',
#  'Iranian Persian',
#  'Bhojpuri',
#  'Min Nan Chinese',
#  'Hakka Chinese',
#  'Jin Chinese',
#  'Hausa',
#  'Kannada',
#  'Indonesian',
#  'Malay',
#  'Polish',
#  'Yoruba',
#  'Xiang Chinese',
#  'Malayalam',
#  'Odia',
#  'Maithili',
#  'Burmese',
#  'Eastern Punjabi',
#  'Sunda',
#  'Sudanese Arabic',
#  'Algerian Arabic',
#  'Moroccan Arabic',
#  'Ukrainian',
#  'Igbo',
#  'Northern Uzbek',
#  'Sindhi',
#  'North Levantine Arabic',
#  'Romanian',
#  'Tagalog',
#  'Dutch',
#  'Saʽidi Arabic',
#  'Gan Chinese',
#  'Amharic',
#  'Northern Pashto',
#  'Magahi',
#  'Thai',
#  'Saraiki',
#  'Khmer',
#  'Khmer',
#  'Chhattisgarhi',
#  'Somali',
#  'Malay',
#  'Malay',
#  'Cebuano',
#  'Nepali',
#  'Mesopotamian Arabic',
#  'Assamese',
#  'Sinhala',
#  'Northern Kurdish',
#  'Hejazi Arabic',
#  'Nigerian Fulfulde',
#  'Bavarian',
#  'Greek',
#  'Chittagonian',
#  'Kazakh',
#  'Deccan',
#  'Hungarian',
#  'Kinyarwanda',
#  'Zulu',
#  'South Levantine Arabic',
#  'Tunisian Arabic',
#  'Sanaani Spoken Arabic',
#  'Min Bei Chinese',
#  'Southern Pashto',
#  'Rundi',
#  'Czech',
#  'Taʽizzi-Adeni Arabic',
#  'Uyghur',
#  'Min Dong Chinese',
#  'Sylheti']

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
