# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# import reduce from functools, numpy and pandas

import functools, numpy, pandas

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up a words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

print(prophet)
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'EBook', 'of', 'The', 'Prophet,', 'by', 'Kahlil', 'Gibran\n\nThis', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and\nmost', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions\nwhatsoever.', '', 'You', 'may', 'copy', 'it,', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms\nof', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at\nwww.gutenberg.org.', '', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States,', "you'll\nhave", 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using\nthis', 'ebook.\n\n\n\nTitle:', 'The', 'Prophet\n\nAuthor:', 'Kahlil', 'Gibran\n\nRelease', 'Date:', 'January', '1,', '2019', '[EBook', '#58585]\nLast', 'Updated:', 'January', '3,', '2018\n\n\nLanguage:', 'English\n\nCharacter', 'set', 'encoding:', 'UTF-8\n\n***', 'START', 'OF', 'THIS', 'PROJECT', 'GUTENBERG', 'EBOOK', 'THE', 'PROPHET', '***\n\n\n\n\nProduced', 'by', 'David', 'Widger', 'from', 'page', 'images', 'generously\nprovided', 'by', 'the', 'Internet', "Archive\n\n\nTranscriber's", 'Note:', 'Page', 'numbers,', 'ie:', '{20},', 'are', 'included', 'in', 'this\nutf-8', 'text', 'file.', 'For', 'those', 'wishing', 'to', 'use', 'a', 'text', 'file', 'unencumbered\nwith', 'page', 'numbers', 'open', 'or', 'download', 'the', 'Latin-1', 'file', '58585-8.txt.\n\n\n\n\n\n\n\nTHE', 'PROPHET\n\nBy', 'Kahlil', 'Gibran\n\nNew', 'York:', 'Alfred', 'A.', 'Knopf\n\n1923\n\n_The', 'Twelve', 'Illustrations', 'In', 'This', 'Volume\nAre', 'Reproduced', 'From', 'Original', 'Drawings', 'By\nThe', 'Author_\n\n\n“His', 'power', 'came', 'from', 'some', 'great', 'reservoir\nof', 'spiritual', 'life', 'else', 'it', 'could', 'not', 'have\nbeen', 'so', 'universal', 'and', 'so', 'potent,', 'but', 'the\nmajesty', 'and', 'beauty', 'of', 'the', 'language', 'with\nwhich', 'he', 'clothed', 'it', 'were', 'all', 'his', 'own?”\n\n--Claude', 'Bragdon\n\n\nTHE', 'BOOKS', 'OF', 'KAHLIL', 'GIBRAN\n\nThe', 'Madman.', '1918', 'Twenty', 'Drawings.', '1919\nThe', 'Forerunner.', '1920', 'The', 'Prophet.', '1923\nSand', 'and', 'Foam.', '1926', 'Jesus', 'the', 'Son', 'of\nMan.', '1928', 'The', 'Forth', 'Gods.', '1931', 'The\nWanderer.', '1932', 'The', 'Garden', 'of', 'the', 'Prophet\n1933', 'Prose', 'Poems.', '1934', 'Nymphs', 'of', 'the\nValley.', '1948\n\n\n\n\nCONTENTS\n\n', '', '', '', '', '', '', '', '', '', 'The', 'Coming', 'of', 'the', 'Ship.......7\n', '', '', '', '', '', '', '', '', '', 'On', 'Love.....................15\n', '', '', '', '', '', '', '', '', '', 'On', 'Marriage.................19\n', '', '', '', '', '', '', '', '', '', 'On', 'Children.................21\n', '', '', '', '', '', '', '', '', '', 'On', 'Giving...................23\n', '', '', '', '', '', '', '', '', '', 'On', 'Eating', 'and', 'Drinking......27\n', '', '', '', '', '', '', '', '', '', 'On', 'Work.....................31\n', '', '', '', '', '', '', '', '', '', 'On', 'Joy', 'and', 'Sorrow...........33\n', '', '', '', '', '', '', '', '', '', 'On', 'Houses...................37\n', '', '', '', '', '', '', '', '', '', 'On', 'Clothes..................41\n', '', '', '', '', '', '', '', '', '', 'On', 'Buying', 'and', 'Selling.......43\n', '', '', '', '', '', '', '', '', '', 'On', 'Crime', 'and', 'Punishment.....45\n', '', '', '', '', '', '', '', '', '', 'On', 'Laws.....................51\n', '', '', '', '', '', '', '', '', '', 'On', 'Freedom..................55\n', '', '', '', '', '', '', '', '', '', 'On', 'Reason', 'and', 'Passion.......57\n', '', '', '', '', '', '', '', '', '', 'On', 'Pain.....................60\n', '', '', '', '', '', '', '', '', '', 'On', 'Self-Knowledge...........62\n', '', '', '', '', '', '', '', '', '', 'On', 'Teaching.................64\n', '', '', '', '', '', '', '', '', '', 'On', 'Friendship...............66\n', '', '', '', '', ...

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# Your code here:
index = 0

for element in prophet:
    prophet.remove(element)
    index += index +1
    if index == 566:
        break
    
print(prophet)
# Out:
# ['Gibran\n\nThis', 'restrictions\nwhatsoever.', 're-use', 'terms\nof', "you'll\nhave", 'ebook.\n\n\n\nTitle:', 'Prophet\n\nAuthor:', 'Gibran\n\nRelease', 'January', '2019', '#58585]\nLast', 'January', '2018\n\n\nLanguage:', 'UTF-8\n\n***', "Archive\n\n\nTranscriber's", 'Page', 'ie:', 'text', 'wishing', 'text', 'unencumbered\nwith', 'numbers', 'file', 'PROPHET\n\nBy', 'Gibran\n\nNew', 'Alfred', 'Knopf\n\n1923\n\n_The', 'Illustrations', 'Reproduced', 'Original', 'By\nThe', 'spiritual', 'have\nbeen', 'universal', 'language', 'own?”\n\n--Claude', 'BOOKS', 'KAHLIL', 'Madman.', 'Twenty', '1919\nThe', '1920', 'Prophet.', '1926', 'of\nMan.', 'Gods.', 'The\nWanderer.', 'Prophet\n1933', 'Poems.', 'Nymphs', 'the\nValley.', 'Coming', 'Love.....................15\n', 'Children.................21\n', 'Eating', 'Drinking......27\n', 'Joy', 'Sorrow...........33\n', 'Clothes..................41\n', 'Crime', 'Punishment.....45\n', 'Freedom..................55\n', 'On', 'On', 'Pain.....................60\n', '', '', '', '', '', 'On', '', '', '', '', '', '', '', '', '', 'On', 'Teaching.................64\n', '', '', '', '', '', '', '', '', '', 'On', '', '', '', '', '', '', '', '', '', 'On', 'Talking..................68\n', '', '', '', '', '', '', '', '', '', 'On', '', '', '', '', '', '', '', '', '', 'On', 'Good', 'Evil............72\n', '', '', '', '', '', '', '', '', '', 'On', '', '', '', '', '', '', '', '', '', 'On', 'Pleasure.................79\n', '', '', '', '', '', '', '', '', '', 'On', '', '', '', '', '', '', '', '', '', 'On', 'Religion.................87\n', '', '', '', '', '', '', '', '', '', 'On', '', '', '', '', '', '', '', '', '', 'Farewell................92\n\n\n\n\nTHE', 'the{7}', 'own\nday,', 'waited', 'Orphalese', 'to\nreturn', 'bear', 'of\nhis', 'twelfth', 'seventh\nday', 'Ielool,', 'month', 'reaping,', 'beheld', 'flung\nopen,', 'flew', 'over', 'sea.\nAnd', 'closed', 'prayed', 'the\nsilences', 'descended', 'hill,', 'sadness\ncame', 'without\nsorrow?', 'spent\nwithin', 'walls,', 'long', 'the\nnights', 'aloneness;', 'depart\nfrom', 'without\nregret?\n\nToo', 'walk\nnaked', 'cannot\nwithdraw', 'and\nan', 'off', 'skin', 'own\nhands.\n\nNor', 'thought', 'me,\nbut', 'sweet', 'thirst.\n\n*****\n\nYet', 'longer.\n\nThe', 'embark.\n\nFor', 'stay,', 'burn', 'mould.\n\nFain', 'is\nhere.', 'I?\n\nA', 'and\n{9}the', 'Alone\nmust', 'ether.\n\nAnd', 'fly', 'foot', 'the\nhill,', 'sea,\nand', 'the\nharbour,', 'prow', 'mariners,\nthe', 'cried', 'ancient', 'dreams.\nAnd', 'awakening,', 'dream.\n\nReady', 'go,', 'with\nsails', 'backward,\n\nAnd', '{10}And', 'mother,\n\nWho', 'peace', 'stream,\n\nOnly', 'winding', 'murmur', 'a\nboundless', 'afar', 'women', 'towards', 'city\ngates.\n\nAnd', 'his\nname,', 'shouting', 'field\ntelling', 'coming', 'eve', 'in\ntruth', 'dawn?\n\nAnd', 'has\nleft', 'plough', 'midfurrow,', 'to\nhim', '{11}Shall', 'a\ntree', 'may\ngather', 'them?\n\nAnd', 'flow', 'a\nfountain', 'cups?\n\nAm', 'flute', 'me?\n\nA', 'silences', 'I\nmay', 'sowed', 'seed,', 'in\nwhat', 'seasons?\n\nIf', 'I\nlift', 'flame\nthat', 'burn', 'raise', 'lantern,\n\nAnd', 'guardian', 'words.', 'much\nin', 'unsaid.', '{12}he\nhimself', '0020]\n\nAnd', 'him,', 'they\nwere', 'forth\nand', 'away', 'us.\n\nA', 'our\ntwilight,', 'us\ndreams', 'dream.\n\nNo', 'nor\na', 'son', 'hunger', 'priestesses', 'him:\n\nLet', 'us\nnow,', 'years', 'spent', 'our\nmidst', 'walked', 'loved', 'But', 'veils', 'cries', 'and\nwould', 'of\nseparation.\n\n*****\n\nAnd', 'him.\nBut', 'not.', 'head;', 'saw\nhis', 'falling', 'proceeded', 'temple.\n\nAnd', 'sanctuary', 'And', 'first\nsought', 'believed', 'city.', '{14}And\nshe', 'him,', 'long', 'the\ndistances', 'now', 'come,', 'go.\n\nDeep', 'memories', 'place\nof', 'love\nwould', 'bind', 'us,', 'children,\nand', 'children,', 'it\nshall', 'perish.\n\nIn', 'aloneness', 'with\nour', 'weeping', 'the\nlaughter', 'therefore', 'ourselves,\nand', 'and\ndeath.\n\n*****\n\nAnd', 'answered,\n\nPeople', 'I\n{15}speak', 'souls?\n\n*****', 'looked', ...

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# Your code here:

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''

    # Your code here:
    if x.find('{') != -1:
        return(x.split('{')[0])
    else:
        return [element]

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`

# %%
# Your code here:
prophet_reference = []

for element in prophet:
    prophet_reference.append(reference(element))
    
print(prophet_reference)
# Out:
# [['Gibran\n\nThis'], ['restrictions\nwhatsoever.'], ['re-use'], ['terms\nof'], ["you'll\nhave"], ['ebook.\n\n\n\nTitle:'], ['Prophet\n\nAuthor:'], ['Gibran\n\nRelease'], ['January'], ['2019'], ['#58585]\nLast'], ['January'], ['2018\n\n\nLanguage:'], ['UTF-8\n\n***'], ["Archive\n\n\nTranscriber's"], ['Page'], ['ie:'], ['text'], ['wishing'], ['text'], ['unencumbered\nwith'], ['numbers'], ['file'], ['PROPHET\n\nBy'], ['Gibran\n\nNew'], ['Alfred'], ['Knopf\n\n1923\n\n_The'], ['Illustrations'], ['Reproduced'], ['Original'], ['By\nThe'], ['spiritual'], ['have\nbeen'], ['universal'], ['language'], ['own?”\n\n--Claude'], ['BOOKS'], ['KAHLIL'], ['Madman.'], ['Twenty'], ['1919\nThe'], ['1920'], ['Prophet.'], ['1926'], ['of\nMan.'], ['Gods.'], ['The\nWanderer.'], ['Prophet\n1933'], ['Poems.'], ['Nymphs'], ['the\nValley.'], ['Coming'], ['Love.....................15\n'], ['Children.................21\n'], ['Eating'], ['Drinking......27\n'], ['Joy'], ['Sorrow...........33\n'], ['Clothes..................41\n'], ['Crime'], ['Punishment.....45\n'], ['Freedom..................55\n'], ['On'], ['On'], ['Pain.....................60\n'], [''], [''], [''], [''], [''], ['On'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['On'], ['Teaching.................64\n'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['On'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['On'], ['Talking..................68\n'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['On'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['On'], ['Good'], ['Evil............72\n'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['On'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['On'], ['Pleasure.................79\n'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['On'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['On'], ['Religion.................87\n'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['On'], [''], [''], [''], [''], [''], [''], [''], [''], [''], ['Farewell................92\n\n\n\n\nTHE'], 'the', ['own\nday,'], ['waited'], ['Orphalese'], ['to\nreturn'], ['bear'], ['of\nhis'], ['twelfth'], ['seventh\nday'], ['Ielool,'], ['month'], ['reaping,'], ['beheld'], ['flung\nopen,'], ['flew'], ['over'], ['sea.\nAnd'], ['closed'], ['prayed'], ['the\nsilences'], ['descended'], ['hill,'], ['sadness\ncame'], ['without\nsorrow?'], ['spent\nwithin'], ['walls,'], ['long'], ['the\nnights'], ['aloneness;'], ['depart\nfrom'], ['without\nregret?\n\nToo'], ['walk\nnaked'], ['cannot\nwithdraw'], ['and\nan'], ['off'], ['skin'], ['own\nhands.\n\nNor'], ['thought'], ['me,\nbut'], ['sweet'], ['thirst.\n\n*****\n\nYet'], ['longer.\n\nThe'], ['embark.\n\nFor'], ['stay,'], ['burn'], ['mould.\n\nFain'], ['is\nhere.'], ['I?\n\nA'], 'and\n', ['Alone\nmust'], ['ether.\n\nAnd'], ['fly'], ['foot'], ['the\nhill,'], ['sea,\nand'], ['the\nharbour,'], ['prow'], ['mariners,\nthe'], ['cried'], ['ancient'], ['dreams.\nAnd'], ['awakening,'], ['dream.\n\nReady'], ['go,'], ['with\nsails'], ['backward,\n\nAnd'], '', ['mother,\n\nWho'], ['peace'], ['stream,\n\nOnly'], ['winding'], ['murmur'], ['a\nboundless'], ['afar'], ['women'], ['towards'], ['city\ngates.\n\nAnd'], ['his\nname,'], ['shouting'], ['field\ntelling'], ['coming'], ['eve'], ['in\ntruth'], ['dawn?\n\nAnd'], ['has\nleft'], ['plough'], ['midfurrow,'], ['to\nhim'], '', ['a\ntree'], ['may\ngather'], ['them?\n\nAnd'], ['flow'], ['a\nfountain'], ['cups?\n\nAm'], ['flute'], ['me?\n\nA'], ['silences'], ['I\nmay'], ['sowed'], ['seed,'], ['in\nwhat'], ['seasons?\n\nIf'], ['I\nlift'], ['flame\nthat'], ['burn'], ['raise'], ['lantern,\n\nAnd'], ['guardian'], ['words.'], ['much\nin'], ['unsaid.'], '', ['0020]\n\nAnd'], ['him,'], ['they\nwere'], ['forth\nand'], ['away'], ['us.\n\nA'], ['our\ntwilight,'], ['us\ndreams'], ['dream.\n\nNo'], ['nor\na'], ['son'], ['hunger'], ['priestesses'], ['him:\n\nLet'], ['us\nnow,'], ['years'], ['spent'], ['our\nmidst'], ['walked'], ['loved'], ['But'] ...

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # Your code here:
    if x.find('\n') != -1:
        return x.split('\n')
    return [x]

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# Your code here:
prophet_line = []

for element in prophet_reference:
    prophet_line.append(line_break(str(element)))
print(prophet_line)
# Out:
# [["['Gibran\\n\\nThis']"], ["['restrictions\\nwhatsoever.']"], ["['re-use']"], ["['terms\\nof']"], ['["you\'ll\\nhave"]'], ["['ebook.\\n\\n\\n\\nTitle:']"], ["['Prophet\\n\\nAuthor:']"], ["['Gibran\\n\\nRelease']"], ["['January']"], ["['2019']"], ["['#58585]\\nLast']"], ["['January']"], ["['2018\\n\\n\\nLanguage:']"], ["['UTF-8\\n\\n***']"], ['["Archive\\n\\n\\nTranscriber\'s"]'], ["['Page']"], ["['ie:']"], ["['text']"], ["['wishing']"], ["['text']"], ["['unencumbered\\nwith']"], ["['numbers']"], ["['file']"], ["['PROPHET\\n\\nBy']"], ["['Gibran\\n\\nNew']"], ["['Alfred']"], ["['Knopf\\n\\n1923\\n\\n_The']"], ["['Illustrations']"], ["['Reproduced']"], ["['Original']"], ["['By\\nThe']"], ["['spiritual']"], ["['have\\nbeen']"], ["['universal']"], ["['language']"], ["['own?”\\n\\n--Claude']"], ["['BOOKS']"], ["['KAHLIL']"], ["['Madman.']"], ["['Twenty']"], ["['1919\\nThe']"], ["['1920']"], ["['Prophet.']"], ["['1926']"], ["['of\\nMan.']"], ["['Gods.']"], ["['The\\nWanderer.']"], ["['Prophet\\n1933']"], ["['Poems.']"], ["['Nymphs']"], ["['the\\nValley.']"], ["['Coming']"], ["['Love.....................15\\n']"], ["['Children.................21\\n']"], ["['Eating']"], ["['Drinking......27\\n']"], ["['Joy']"], ["['Sorrow...........33\\n']"], ["['Clothes..................41\\n']"], ["['Crime']"], ["['Punishment.....45\\n']"], ["['Freedom..................55\\n']"], ["['On']"], ["['On']"], ["['Pain.....................60\\n']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['Teaching.................64\\n']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['Talking..................68\\n']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['Good']"], ["['Evil............72\\n']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['Pleasure.................79\\n']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['Religion.................87\\n']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['On']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['']"], ["['Farewell................92\\n\\n\\n\\n\\nTHE']"], ['the'], ["['own\\nday,']"], ["['waited']"], ["['Orphalese']"], ["['to\\nreturn']"], ["['bear']"], ["['of\\nhis']"], ["['twelfth']"], ["['seventh\\nday']"], ["['Ielool,']"], ["['month']"], ["['reaping,']"], ["['beheld']"], ["['flung\\nopen,']"], ["['flew']"], ["['over']"], ["['sea.\\nAnd']"], ["['closed']"], ["['prayed']"], ["['the\\nsilences']"], ["['descended']"], ["['hill,']"], ["['sadness\\ncame']"], ["['without\\nsorrow?']"], ["['spent\\nwithin']"], ["['walls,']"], ["['long']"], ["['the\\nnights']"], ["['aloneness;']"], ["['depart\\nfrom']"], ["['without\\nregret?\\n\\nToo']"], ["['walk\\nnaked']"], ["['cannot\\nwithdraw']"], ["['and\\nan']"], ["['off']"], ["['skin']"], ["['own\\nhands.\\n\\nNor']"], ["['thought']"], ["['me,\\nbut']"], ["['sweet']"], ["['thirst.\\n\\n*****\\n\\nYet']"], ["['longer.\\n\\nThe']"], ["['embark.\\n\\nFor']"], ["['stay,']"], ["['burn']"], ["['mould.\\n\\nFain']"], ["['is\\nhere.']"], ["['I?\\n\\nA']"], ['and', ''], ["['Alone\\nmust']"], ["['ether.\\n\\nAnd']"], ["['fly']"], ["['foot']"], ["['the\\nhill,']"], ["['sea,\\nand']"], ["['the\\nharbour,']"], ["['prow']"], ["['marin ...

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
# Your code here:

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: true if the word is not in the specified list and false if the word is in the list
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an']
    
    # Your code here:

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %% [markdown]
# # Bonus Challenge - Part 1
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # Your code here:

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # Your code here:

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# Your code here:

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will load a dataset below and then write a function that will perform the transformation.

# %%
# Run this code:

# The dataset below contains information about pollution from PM2.5 particles in Beijing 

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"
pm25 = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4269087ebf87> in <module>
#       4
#       5 url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"
# ----> 6 pm25 = pd.read_csv(url)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# Your code here:

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''
    
    # Your code here:

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
# Your code here:

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # Your code here:
